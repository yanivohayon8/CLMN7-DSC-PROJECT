# %%
import pandas as pd
import glob

# %%
experiments_path = '../data/processed/'
csv_files = glob.glob(experiments_path + '/**/*.csv',recursive=True)

# %%
dfs = [pd.read_csv(csv) for csv in csv_files]

# %%
all_dfs = pd.concat(dfs)
# Out:
# C:\Users\yaniv\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.

# %%
all_dfs
# Out:
#    ACCURECYSECONDS  BLOCKSIZE  \
# 0             15.0       40.0
# 1             15.0       40.0
# 2             15.0       40.0
# 3             15.0       40.0
# 0             15.0       40.0
# 1             15.0       40.0
# 2             15.0       40.0
# 3             15.0       40.0
# 0             15.0      120.0
# 1             15.0      120.0
# 2             15.0       40.0
# 3             15.0      120.0
# 0             15.0      120.0
# 1             15.0      120.0
# 2             15.0       40.0
# 3             15.0      120.0
# 0             15.0       50.0
# 1             15.0       50.0
# 2             15.0       40.0
# 3             15.0      150.0
# 0             15.0       40.0
# 1             15.0       40.0
# 2             15.0       40.0
# 3             15.0       40.0
# 0             15.0      120.0
# 1             15.0      120.0
# 2             15.0       40.0
# 3             15.0      120.0
# 0             15.0      120.0
# 1             15.0      120.0
# 2             15.0       40.0
# 3             15.0      120.0
# 0             15.0      150.0
# 1             15.0      120.0
# 2             15.0       40.0
# 3             15.0       40.0
# 0             15.0      120.0
# 1             15.0      120.0
# 2             15.0       40.0
# 3             15.0      120.0
#
#                                       FAILUREMESSAGE              FILTER  \
# 0  label 8 has done already cannot evaluate unseq...                None
# 1  label 7 has done already cannot evaluate unseq...                None
# 2                                                NaN                None
# 3  label 11 has done already cannot evaluate unse...                None
# 0  label 8 has done already cannot evaluate unseq...                None
# 1  label 7 has done already cannot evaluate unseq...                None
# 2                                                NaN                None
# 3  label 11 has done already cannot evaluate unse...                None
# 0                                                NaN                None
# 1                                                NaN  ['median', (2, 2)]
# 2                                                NaN                None
# 3                                                NaN  ['median', (4, 4)]
# 0                                                NaN                None
# 1                                                NaN                None
# 2                                                NaN                None
# 3                                                NaN                None
# 0  label 7 has done already cannot evaluate unseq...                None
# 1  label 1 has done already cannot evaluate unseq...  ['median', (2, 2)]
# 2                                                NaN                None
# 3                                                NaN  ['median', (4, 4)]
# 0  label 8 has done already cannot evaluate unseq...                None
# 1  label 0 has done already cannot evaluate unseq...                None
# 2                                                NaN                None
# 3  label 2 has done already cannot evaluate unseq...                None
# 0                                                NaN                None
# 1                                                NaN                None
# 2                                                NaN                None
# 3                                                NaN  ['median', (2, 2)]
# 0                                                NaN                None
# 1                                                NaN                None
# 2                                                NaN                None
# 3                                                NaN  ['median', (2, 2)]
# 0                                                NaN                None
# 1                                                NaN  ['median', (2, 2)]
# 2                                                NaN                None
# 3  label 5 has done already cannot evaluate unseq...  ['median', (4, 4)]
# 0                                                NaN                None
# 1                                                NaN                None
# 2                                                NaN                None
# 3                                                NaN                None
#
#      FN    FP  ISFAILED                                             METHOD  \
# 0   0.0   0.0       1.0  chunking_tfidf_cosine_threshold_spectral_clust...
# 1   0.0   0.0       1.0  chunking_tfidf_cosine_threshold_spectral_clust...
# 2   9.0  10.0       0.0  chunking_tfidf_cosine_threshold_spectral_clust...
# 3   0.0   0.0       1.0  chunking_tfidf_cosine_threshold_spectral_clust...
# 0   0.0   0.0       1.0  chunking_tfidf_cosine_threshold_spectral_clust...
# 1   0.0   0.0       1.0  chunking_tfidf_cosine_threshold_spectral_clust...
# 2   9.0  10.0       0.0  chunking_tfidf_cosine_threshold_spectral_clust...
# 3   0.0   0.0       1.0  chunking_tfidf_cosine_threshold_spectral_clust...
# 0   9.0  11.0       0.0  chunking_tfidf_cosine_threshold_spectral_clust...
# 1  15.0  16.0       0.0  chunking_tfidf_cosine_threshold_filter_spectra...
# 2   8.0   9.0       0.0  chunking_tfidf_cosine_threshold_spectral_clust...
# 3   9.0  11.0       0.0  chunking_tf_cosine_threshold_filter_spectral_c...
# 0   9.0  11.0       0.0  chunking_tfidf_cosine_threshold_spectral_clust...
# 1  16.0  16.0       0.0  chunking_tfidf_cosine_threshold_spectral_clust...
# 2   8.0   9.0       0.0  chunking_tfidf_cosine_threshold_spectral_clust...
# 3  11.0  12.0       0.0   chunking_tf_cosine_threshold_spectral_clustering
# 0   0.0   0.0       1.0  slidingwindow_tfidf_cosine_threshold_spectral_...
# 1   0.0   0.0       1.0  slidingwindow_tfidf_cosine_threshold_filter_sp...
# 2   7.0   9.0       0.0  chunking_tfidf_cosine_threshold_spectral_clust...
# 3   7.0   9.0       0.0  chunking_tf_cosine_threshold_filter_spectral_c...
# 0   0.0   0.0       1.0  chunking_tfidf_cosine_threshold_spectral_clust...
# 1   0.0   0.0       1.0  chunking_tfidf_cosine_threshold_spectral_clust...
# 2   6.0   7.0       0.0  chunking_tfidf_cosine_threshold_spectral_clust...
# 3   0.0   0.0       1.0  chunking_tfidf_cosine_threshold_spectral_clust...
# 0   9.0  11.0       0.0  chunking_tfidf_cosine_threshold_spectral_clust...
# 1  16.0  16.0       0.0  chunking_tfidf_cosine_threshold_spectral_clust...
# 2   8.0  10.0       0.0  chunking_tfidf_cosine_threshold_spectral_clust...
# 3  10.0  12.0       0.0  chunking_tf_cosine_threshold_filter_spectral_c...
# 0   9.0  11.0       0.0  chunking_tfidf_cosine_threshold_spectral_clust...
# 1  16.0  16.0       0.0  chunking_tfidf_cosine_threshold_spectral_clust...
# 2   8.0  10.0       0.0  chunking_tfidf_cosine_threshold_spectral_clust...
# 3   9.0  11.0       0.0  chunking_tf_cosine_threshold_filter_spectral_c...
# 0   8.0  10.0       0.0  chunking_tfidf_cosine_threshold_spectral_clust...
# 1  16.0  17.0       0.0  chunking_tfidf_cosine_threshold_filter_spectra...
# 2   9.0  10.0       0.0  chunking_tfidf_cosine_threshold_spectral_clust...
# 3   0.0   0.0       1.0  slidingwindow_tf_cosine_threshold_filter_spect...
# 0   9.0  12.0       0.0  chunking_tfidf_cosine_threshold_spectral_clust...
# 1  11.0  16.0       0.0  chunking_tfidf_cosine_threshold_spectral_clust...
# 2   7.0   9.0       0.0  chunking_tfidf_cosine_threshold_spectral_clust...
# 3  11.0  11.0       0.0  chunking_tfidf_cosine_threshold_spectral_clust...
#
#    NUMOFCLUSTERSFORSC  NUMTOPICS  PRECISION    RECALL  STEPSIZE  THERSHOLD  \
# 0                13.0       15.0   0.000000  0.000000      20.0        0.4
# 1                13.0       18.0   0.000000  0.000000      20.0        0.4
# 2                13.0       14.0   0.285714  0.307692      20.0        0.4
# 3                13.0       13.0   0.000000  0.000000      20.0        0.4
# 0                13.0       15.0   0.000000  0.000000      20.0        0.4
# 1                13.0       18.0   0.000000  0.000000      20.0        0.4
# 2                13.0       14.0   0.285714  0.307692      20.0        0.4
# 3                13.0       13.0   0.000000  0.000000      20.0        0.4
# 0                14.0       15.0   0.266667  0.307692      45.0        0.4
# 1                18.0       18.0   0.111111  0.117647      50.0        0.4
# 2                13.0       14.0   0.357143  0.384615      20.0        0.4
# 3                12.0       13.0   0.153846  0.181818      30.0        0.4
# 0                14.0       15.0   0.266667  0.307692      50.0        0.4
# 1                18.0       18.0   0.111111  0.111111      50.0        0.4
# 2                13.0       14.0   0.357143  0.384615      20.0        0.4
# 3                12.0       13.0   0.076923  0.083333      30.0        0.4
# 0                14.0       15.0   0.000000  0.000000      50.0        0.4
# 1                18.0       18.0   0.000000  0.000000      50.0        0.4
# 2                13.0       14.0   0.357143  0.416667      20.0        0.4
# 3                12.0       13.0   0.307692  0.363636      40.0        0.4
# 0                13.0       15.0   0.000000  0.000000      20.0        0.4
# 1                13.0       18.0   0.000000  0.000000      20.0        0.4
# 2                13.0       14.0   0.500000  0.538462      20.0        0.4
# 3                13.0       13.0   0.000000  0.000000      20.0        0.4
# 0                14.0       15.0   0.266667  0.307692      50.0        0.4
# 1                18.0       18.0   0.111111  0.111111      50.0        0.4
# 2                13.0       14.0   0.285714  0.333333      20.0        0.4
# 3                12.0       13.0   0.076923  0.090909      30.0        0.4
# 0                14.0       15.0   0.266667  0.307692      50.0        0.4
# 1                18.0       18.0   0.111111  0.111111      50.0        0.4
# 2                13.0       14.0   0.285714  0.333333      20.0        0.4
