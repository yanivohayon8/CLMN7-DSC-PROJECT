# %%
from youtube_transcript_api import YouTubeTranscriptApi

# %%
bla = YouTubeTranscriptApi.get_transcript('LmIjgmijyiI')

# %%
print(bla)
# Out:
# [{'text': 'on welcome to 11 785 introduction to', 'start': 0.03, 'duration': 4.65}, {'text': 'deep neural networks', 'start': 3.36, 'duration': 4.019}, {'text': 'I am aishwarya one of the TAS for this', 'start': 4.68, 'duration': 4.98}, {'text': 'course and today I will be covering up', 'start': 7.379, 'duration': 5.311}, {'text': 'for Professor bigshot this will be a', 'start': 9.66, 'duration': 6.84}, {'text': 'very brief lecture about the logistics', 'start': 12.69, 'duration': 5.849}, {'text': 'of the course we will first give you', 'start': 16.5, 'duration': 4.32}, {'text': 'some motivation about how neural', 'start': 18.539, 'duration': 5.851}, {'text': 'networks have revolutionized many tasks', 'start': 20.82, 'duration': 5.58}, {'text': 'and have become dating in the tech', 'start': 24.39, 'duration': 4.59}, {'text': 'industry right now later we will go over', 'start': 26.4, 'duration': 4.44}, {'text': 'the structure of the course we will', 'start': 28.98, 'duration': 4.59}, 
# ...

# %%
text_array  = [myjson['text'] for myjson in bla]
text_array
# Out:
# ['on welcome to 11 785 introduction to',
#  'deep neural networks',
#  'I am aishwarya one of the TAS for this',
#  'course and today I will be covering up',
#  'for Professor bigshot this will be a',
#  'very brief lecture about the logistics',
#  'of the course we will first give you',
#  'some motivation about how neural',
#  'networks have revolutionized many tasks',
#  'and have become dating in the tech',
#  'industry right now later we will go over',
#  'the structure of the course we will',
#  'speak a bit about the homeworks the',
#  'quizzes the grading scheme and the',
#  'course and finally we will end up with',
#  'some important information that you will',
#  'love required in order to successfully',
#  "complete the course the fact that you've",
#  'all enrolled in this course suggests',
#  'that you at least know a bit about our',
#  'new networks are taking over',
#  "they've become one of the major thrust",
#  'areas in various problems that involve',
# ...

# %%
duration_array  = [myjson['duration'] for myjson in bla]

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(duration_array,bins=30)
plt.show()
