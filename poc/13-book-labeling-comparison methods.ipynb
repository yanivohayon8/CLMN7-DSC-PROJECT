# %%
import sys
sys.path.append('..')
from src.data.docx  import read_docx,process_docx,find_content
import glob
import json
import os
import pandas as pd
import ast
import warnings
warnings.filterwarnings("ignore")
from src.models.pipeline import pipeline
from functools import reduce
import heapq
from gensim.corpora import Dictionary
from gensim import models
from gensim import similarities
import re
import statistics
import numpy as np
import seaborn as sns; sns.set()
# %matplotlib inline
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer

# %% [markdown]
# # READ BOOKS OF VIDEOS

# %%
'''Defining CONSTS'''
docx_path = '../data/raw/docx'
groundbase_dir = '../data/raw/groundbase'
transcripts_dir = os.path.join(groundbase_dir,'transcripts')
topic_dataset_path = os.path.join(groundbase_dir,'dataset.csv')
transcript_filespath = glob.glob(groundbase_dir + '/transcripts/*.json')

# %%
videos_ids = list(map(lambda fl: fl.split('\\')[-1].split('.')[0],glob.glob(docx_path + '/*')))

# %%
desired_videos =['7kLHJ-F33GI','RIawrYLVdIw','7snJ1mx1EMQ','zWg7U0OEAoE','tORLeHHtazM'] #['zWg7U0OEAoE','tORLeHHtazM'] #['7kLHJ-F33GI','RIawrYLVdIw','7snJ1mx1EMQ']
videos_ids = list(filter(lambda x: x in desired_videos,videos_ids))

# %%
#video_docx = [glob.glob(os.path.join(docx_path,vid + '/*.docx'))[0] for vid in videos_ids]
#docx_db =[read_docx(path) for path in video_docx]

# %%
f_read = {
    'statbook':'statbook',
    'Dsa':'Dsa'
}

docxs_chapter_keyword = {
    'statbook':'Topic',
    'Dsa': 'Chapter'
}

# %%
video_to_paper = {}
paper_content ={}
for vid in videos_ids:
    doc_path = glob.glob(os.path.join(docx_path,vid + '/*.docx'))[0]
    doc_name = doc_path.split('\\')[-1].split('.')[0]
    video_to_paper[vid] = doc_name    
    if doc_name not in paper_content.keys():    
        full_text,font_sizes = read_docx(doc_path)
        paper_content[doc_name] = find_content(f_read[doc_name],
                                               full_text,
                                               font_sizes,
                                               docxs_chapter_keyword[doc_name])

# %%
"""#transcript_filespath
#videos_ids
from docx import *
word_document = Document(doc_path)
p_sent = re.compile('\w+')
full_text = []
font_sizes = []
for para in word_document.paragraphs:
    for i,run in enumerate(para.runs):        
        matching = p_sent.match(run.text)

        # see if there is a number or letter ( it is not a trash)
        if matching is not None and run.text is not None and run.font.size is not None:
                full_text.append(re.sub('[\t\n\b\r]','',run.text))
"""
# Out:
# "#transcript_filespath\n#videos_ids\nfrom docx import *\nword_document = Document(doc_path)\np_sent = re.compile('\\w+')\nfull_text = []\nfont_sizes = []\nfor para in word_document.paragraphs:\n    for i,run in enumerate(para.runs):        \n        matching = p_sent.match(run.text)\n\n        # see if there is a number or letter ( it is not a trash)\n        if matching is not None and run.text is not None and run.font.size is not None:\n                full_text.append(re.sub('[\t\n\x08\r]','',run.text))\n"

# %% [markdown]
# # RESTORE RESULTS FROM TRAINING

# %%
'''Select transcript for only wanted videos'''
transcript_filespath = list(filter(lambda x: x.split('\\')[-1].split('.')[0] in videos_ids,transcript_filespath))

'''Read the transcript'''
transcripts_jsons = {}
for fl in transcript_filespath:
    with open(fl,encoding="utf8") as f:
        transcript =ast.literal_eval(f.read()) #json.load(f)
        vid = fl.split('\\')[-1].split('.')[0]
        #print(vid)
        transcripts_jsons[vid] = transcript
#print(transcripts_jsons)

'''Read the videos metadata to perform on them the segmentation'''
df_videos = pd.read_csv(topic_dataset_path)

''' Transfer topic shifts time to seconds units instead HH:MM:SS'''
def topic_shifts_seconds(topic_shifts):
    tp_shift_sec=[]
    for tp in topic_shifts:
        intervals = tp.split(':')
        seconds = int(intervals[2])
        minutes = int(intervals[1]) * 60
        hours = int(intervals[0]) * 60 *60
        tp_shift_sec.append(seconds + minutes + hours)
    return tp_shift_sec
for video_id in transcripts_jsons.keys():    
    df_videos.at[df_videos['video id'] == video_id,'topic shifts(ends)'] =\
    topic_shifts_seconds(\
                         df_videos[df_videos['video id'] == \
                                   video_id]['topic shifts(ends)'])
    
    
'''Get parameters from training'''
df_results = pd.read_csv('../data/processed/bayesian_opt/results.csv')
n_largest_res = 3
pipeline_results = df_results[df_results['video'].isin(videos_ids)]\
                .groupby('video')[['video','workflow','params','max_target']]\
                .apply(lambda grp: grp.nlargest(n_largest_res,'max_target')).values.tolist()
#pipeline_results = pipeline_results[2:]

# %%
transcripts_jsons['zWg7U0OEAoE']
# Out:
# [{'text': 'Welcome \nto data structures and algorithms. We are',
#   'start': 64.07,
#   'duration': 12.2},
#  {'text': 'going to learn today some basic terminology\nregarding data structures and the notations',
#   'start': 76.27,
#   'duration': 7.51},
#  {'text': 'that you would be following in the rest of\nthis course. We will begin with some very',
#   'start': 83.78,
#   'duration': 5.22},
#  {'text': 'simple definitions. An algorithm which is\nan outline of the steps that a program has',
#   'start': 89.0,
#   'duration': 7.05},
#  {'text': 'to take or any computational procedure has\nto take. A program on the other hand is an',
#   'start': 96.05,
#   'duration': 6.44},
#  {'text': 'implementation of an algorithm and it could\nbe in any programming language. Data structure',
#   'start': 102.49,
#   'duration': 9.21},
#  {'text': 'is the way we need to organize the data, so\nthat it can be used effectively by the program.',
#   'start': 111.7,
#   'duration': 7.07},
#  {'text': 'So you are all familiar with certain data\nstructures, an array or a list for instance.',
#   'start': 118.77,
#   'duration': 7.11},
#  {'text': 'In this course you will be seeing a lot more\ndata structures in this course and you will',
#   'start': 125.88,
#   'duration': 4.859},
#  {'text': 'see how to use them in various algorithms.\nWe will take a particular problem, try to',
#   'start': 130.739,
#   'duration': 4.461},
#  {'text': 'solve that problem and in the process develop\ndata structures, the best way of organizing',
#   'start': 135.2,
#   'duration': 5.13},
#  {'text': 'the data, associated with that problem. What\nis an algorithmic problem? An algorithmic',
#   'start': 140.33,
#   'duration': 7.84},
#  {'text': 'problem is essentially, that you have a certain\nspecifications of an input as is given here',
#   'start': 148.17,
#   'duration': 6.26},
#  {'text': 'and you specify what the output should be\nlike. And a specification of an input could',
#   'start': 154.43,
#   'duration': 5.0},
#  {'text': 'be, here is one specification, a sorted, non\ndecreasing sequence of natural numbers of',
#   'start': 159.43,
#   'duration': 6.99},
#  {'text': "non-zero, finite length. That's an input,\nthat's a completely specified input. I have",
#   'start': 166.42,
#   'duration': 6.21},
#  {'text': 'given 2 examples here of inputs which meet\nthe specification and I have not given any',
#   'start': 172.63,
#   'duration': 4.829},
#  {'text': 'output specification yet here.',
#   'start': 177.459,
#   'duration': 2.501},
#  {'text': 'Now what is an instance? These are 2 instances\nof the input. This is the specification for',
#   'start': 179.96,
#   'duration': 8.17},
#  {'text': 'the input and you can have any possible instance,\nyou can take any sequence of sorted, non-decreasing',
#   'start': 188.13,
#   'duration': 8.319},
#  {'text': 'numbers and that would form an input instance.\nSo there are many input instances possible',
#   'start': 196.449,
#   'duration': 5.751},
#  {'text': 'here.', 'start': 202.2, 'duration': 5.189},
#  {'text': 'An algorithm is essentially, describing the\nactions that one should take on the input',
#   'start': 207.389,
#   'duration': 4.581},
#  {'text': 'instance to get the output as desired, as\nis specified. And again there can be infinitely',
#   'start': 211.97,
#   'duration': 6.54},
#  {'text': 'many input instances and there can be infinitely\nmany algorithms for solving certain problem.',
#   'start': 218.51,
#   'duration': 9.28},
#  {'text': 'Each one of you could do it in a slightly\ndifferent way.',
#   'start': 227.79,
#   'duration': 5.83},
#  {'text': 'That brings the notion of good algorithm.\nIf there are so many different algorithms',
#   'start': 233.62,
#   'duration': 3.57},
#  {'text': 'for solving a certain problem, what is a good\nalgorithm? Good algorithm for us is an efficient',
#   'start': 237.19,
#   'duration': 8.59},
#  {'text': 'algorithm. Anything that is efficient is good.\nWhat is efficient? Efficient is something,',
#   'start': 245.78,
#   'duration': 6.44},
#  {'text': 'which has small running time and takes less\nmemory. These will be the two measures of',
#   'start': 252.22,
#   'duration': 5.84},
#  {'text': 'efficiency that we will be working with. There\ncould also be other measures of efficiency.',
#   'start': 258.06,
#   'duration': 3.85},
#  {'text': 'But these are the only two things we would\nbe considering in this course. And most of',
#   'start': 261.91,
#   'duration': 3.9},
#  {'text': 'our time we would be spending with the running\ntime really. Space, of course we will be analyzing',
#   'start': 265.81,
#   'duration': 5.95},
#  {'text': 'the space and most of the time would be spent\nin worrying about the running time of an algorithm.',
#   'start': 271.76,
#   'duration': 6.57},
#  {'text': 'And we would be interested in the efficiency\nof algorithms, as a function of the input',
#   'start': 278.33,
#   'duration': 5.86},
#  {'text': 'size.', 'start': 284.19, 'duration': 1.0},
#  {'text': 'So clearly you can imagine that, if I have\na small input and my algorithm running on',
#   'start': 285.19,
#   'duration': 5.85},
#  {'text': 'that input or my program running on that input\nwill take less amount of time. If the input',
#   'start': 291.04,
#   'duration': 4.849},
#  {'text': 'becomes 10 times larger, then the time taken\nby the program would also grow. It may it',
#   'start': 295.889,
#   'duration': 4.843},
#  {'text': 'becomes 10 times, may be it becomes 20 times\nor may be it becomes 100 times, I do not know.',
#   'start': 300.732,
#   'duration': 3.948},
#  {'text': 'It is this behavior of the increase in the\nrunning time, with the increase in the size',
#   'start': 304.68,
#   'duration': 7.05},
#  {'text': 'of input that would also be of our interest\nto us. We will come to all of these in a short',
#   'start': 311.73,
#   'duration': 6.999},
#  {'text': 'while as we go through these slides.',
#   'start': 318.729,
#   'duration': 4.931},
#  {'text': 'How does one measure running time? So I said\nefficiency, running time, very important.',
#   'start': 323.66,
#   'duration': 4.88},
#  {'text': 'How does one measure the running time of an\nalgorithm? One way would be, I have put down',
#   'start': 328.54,
#   'duration': 6.71},
#  {'text': 'here as an experimental study. You have a\ncertain algorithm and you have to implement',
#   'start': 335.25,
#   'duration': 4.84},
#  {'text': 'that algorithm, which means you have to write\na program in a certain programming language.',
#   'start': 340.09,
#   'duration': 5.23},
#  {'text': 'You run the program with varying data sets,\nsome smaller, some larger data sets, some',
#   'start': 345.32,
#   'duration': 6.641},
#  {'text': 'would be of some kinds and some would be of\ndifferent kinds, so varying composition. And',
#   'start': 351.961,
#   'duration': 4.639},
#  {'text': 'then you clock the time that the program takes\nand clock does not mean that you should sit',
#   'start': 356.6,
#   'duration': 5.06},
#  {'text': "down near stopwatch. Perhaps you can use the\nsystem utility like let's say System. Current",
#   'start': 361.66,
#   'duration': 3.57},
#  {'text': 'Time Millis (), to clock the time that the\nprogram takes and then from that you try and',
#   'start': 365.23,
#   'duration': 6.67},
#  {'text': 'figure out, how good your algorithms is, so\nthat is what one would call an experimental',
#   'start': 371.9,
#   'duration': 6.53},
#  {'text': 'study of the algorithm.', 'start': 378.43, 'duration': 4.44},
#  {'text': 'This has certain limitations. So I put them\ndown. First you have to implement the algorithm',
#   'start': 382.87,
#   'duration': 6.91},
#  {'text': 'to be able to determine how good your algorithm\nis you have to Implement it and that is already',
#   'start': 389.78,
#   'duration': 3.38},
#  {'text': 'a huge overhead, considerable amount of time\nhas to be spent in doing this. When your experiments',
#   'start': 393.16,
#   'duration': 9.02},
#  {'text': 'can be done only on a limited set of inputs.\nAfter all I said the number of instances is',
#   'start': 402.18,
#   'duration': 4.44},
#  {'text': 'infinitely large and you can run your experiment\nonly on a small set of instances and that',
#   'start': 406.62,
#   'duration': 6.13},
#  {'text': 'might not be really indicative of the time\nthat your algorithm is taking for other inputs,',
#   'start': 412.75,
#   'duration': 4.77},
#  {'text': 'which you have not considered in your experiment.',
#   'start': 417.52,
#   'duration': 4.23},
#  {'text': 'Further if you have two algorithms and you\nhave to decide, which one is better you have',
#   'start': 421.75,
#   'duration': 5.52},
#  {'text': 'to use exactly the same platforms to do the\ncomparison. Platform I mean both the hardware',
#   'start': 427.27,
#   'duration': 5.66},
#  {'text': 'and software environment. Because as you can\nimagine, different machines would make a difference,',
#   'start': 432.93,
#   'duration': 6.29},
#  {'text': 'not just different machines in fact even the\nusers who are working on that system at that',
#   'start': 439.22,
#   'duration': 4.33},
#  {'text': 'particular point would make a difference on\nthe running time of an algorithm. It becomes',
#   'start': 443.55,
#   'duration': 4.62},
#  {'text': 'very messy, if you have to do it this way.',
#   'start': 448.17,
#   'duration': 4.13},
#  {'text': 'What we are going to do in the part of this\ncourse, in fact in this very first lecture',
#   'start': 452.3,
#   'duration': 4.23},
#  {'text': 'is to develop the general methodology, which\nwill help us to analyze running time of algorithms.',
#   'start': 456.53,
#   'duration': 5.39},
#  {'text': 'We are going to do it as follows: we are going\nto first develop a high level description',
#   'start': 461.92,
#   'duration': 7.12},
#  {'text': 'of an algorithm, a way of describing an algorithm\nand we are going to use this description to',
#   'start': 469.04,
#   'duration': 6.34},
#  {'text': 'figure out the running time and not to implement\nit to any system.',
#   'start': 475.38,
#   'duration': 7.039},
#  {'text': 'A methodology would help us take into account\nof all possible input instances and it would',
#   'start': 482.419,
#   'duration': 6.481},
#  {'text': 'help us and also it will allow us to evaluate\nthe efficiency of the algorithm in a way that',
#   'start': 488.9,
#   'duration': 5.67},
#  {'text': 'it is independent of the environment, independent\nof the platform that we are using.',
#   'start': 494.57,
#   'duration': 9.65},
#  {'text': 'I said we will give the high level description\nof the algorithm. This very first point here,',
#   'start': 504.22,
#   'duration': 3.91},
#  {'text': 'we will give a high level description. So,\nwhat is this? So this brings me to what? We',
#   'start': 508.13,
#   'duration': 3.19},
#  {'text': 'will call this Pseudo-code.', 'start': 511.32, 'duration': 1.3},
#  {'text': 'And this is how we are going to be specifying\nall our algorithms for the purposes of this',
#   'start': 512.62,
#   'duration': 5.83},
#  {'text': 'course.', 'start': 518.45, 'duration': 1.44},
#  {'text': 'Here is an example of pseudo code and you\nmight have seen this in your earlier courses',
#   'start': 519.89,
#   'duration': 4.79},
#  {'text': 'also. What is this algorithm doing? This algorithm\ntakes an array A, which stores an integer',
#   'start': 524.68,
#   'duration': 9.589},
#  {'text': 'in it and it is trying to find the maximum\nelement in this array. What I have written',
#   'start': 534.269,
#   'duration': 6.161},
#  {'text': 'here is not a program because I think the\nsyntax is all wrong. But it is pseudo-code;',
#   'start': 540.43,
#   'duration': 11.12},
#  {'text': 'it is a mixture of natural language and some\nhigh-level programming concepts.',
#   'start': 551.55,
#   'duration': 8.06},
#  {'text': 'I am going to use a for loop, do loop, I am\ngoing to use if-then-else statement and I',
#   'start': 559.61,
#   'duration': 3.96},
#  {'text': 'am going to use a while loop. But I will not\nbother about whether there should be a semicolon',
#   'start': 563.57,
#   'duration': 6.23},
#  {'text': 'here or there should be colon here and I am\nnot going to bother about those are things',
#   'start': 569.8,
#   'duration': 3.92},
#  {'text': 'are required by the compiler but for our understanding\nthis is completely clear what this program',
#   'start': 573.72,
#   'duration': 4.97},
#  {'text': 'is doing. So what it is doing? It is keeping\ntrack of the maximum variable in a variable',
#   'start': 578.69,
#   'duration': 7.87},
#  {'text': 'called current max which is initialized to\nthe first element of the array. And Then it',
#   'start': 586.56,
#   'duration': 5.34},
#  {'text': 'is going to run through the remaining element\nof the array, compare them with the current',
#   'start': 591.9,
#   'duration': 4.67},
#  {'text': 'maximum element. Current Max ← A [0]. If\nthe current maximum element is less than the',
#   'start': 596.57,
#   'duration': 5.519},
#  {'text': 'current element, then it would update the\ncurrent max. A[i] becomes the new max and',
#   'start': 602.089,
#   'duration': 10.291},
#  {'text': 'then when the loop terminates we would just\nreturn current max.',
#   'start': 612.38,
#   'duration': 2.74},
#  {'text': 'If current Max < A[i] then current Max ← A[i]\nreturn current Max',
#   'start': 615.12,
#   'duration': 1.0},
#  {'text': 'It is a very simple algorithm but just with\nthis pseudo-code, you are able to understand',
#   'start': 616.12,
#   'duration': 5.12},
#  {'text': 'what it is doing. This will not run on any\ncomputer since it is the pseudo-code, but',
#   'start': 621.24,
#   'duration': 4.99},
#  {'text': 'it conveys the idea or the concepts any question\nup to this point? That is what I saying most',
#   'start': 626.23,
#   'duration': 10.91},
#  {'text': 'structured pseudo code, most structured than\nusual course but it is less for than formal',
#   'start': 637.14,
#   'duration': 6.84},
#  {'text': 'programming.', 'start': 643.98, 'duration': 1.0},
#  {'text': 'And How pseudo-code will look like? We will\nuse standard numeric and Boolean expressions',
#   'start': 644.98,
#   'duration': 5.81},
#  {'text': 'in it.', 'start': 650.79, 'duration': 2.29},
#  {'text': "Instead of the assignment operator which is\n'=' in java, I will use ← and instead of",
#   'start': 653.08,
#   'duration': 11.43},
#  {'text': "the equality operator, an equality relationship\nin java which is '= =' the same in C, I will",
#   'start': 664.51,
#   'duration': 6.57},
#  {'text': "just use '='. I will declare methods with\nthe algorithmic name and the parameter it",
#   'start': 671.08,
#   'duration': 8.67},
#  {'text': 'takes. Algorithm name (param 1, param2)',
#   'start': 679.75,
#   'duration': 3.09},
#  {'text': 'I will use all kinds of programming construct\nlike if ...then statement, if ...then... [else]',
#   'start': 682.84,
#   'duration': 5.04},
#  {'text': 'statement, while ... do, repeat ...until,\nfor ... do and to index array I will say A[i],',
#   'start': 687.88,
#   'duration': 6.78},
#  {'text': 'A [i, j]. It should be clear in what it is\ndoing.',
#   'start': 694.66,
#   'duration': 3.84},
#  {'text': 'I will use return when the procedure terminates\nand return value will tell, what the value',
#   'start': 698.5,
#   'duration': 6.64},
#  {'text': 'returned by the particular procedure or a\nfunction. When I have to make a call to a',
#   'start': 705.14,
#   'duration': 5.93},
#  {'text': 'method, I will specify that with the name\nof the method and the argument and what is',
#   'start': 711.07,
#   'duration': 4.51},
#  {'text': 'the object that is used. Any question to this\npoint. What was the object?',
#   'start': 715.58,
#   'duration': 13.84},
#  {'text': 'This is specifies the type of the value returned\nby the particular method. You will see more',
#   'start': 729.42,
#   'duration': 11.88},
#  {'text': 'of this, when we come across more pseudo-code.\nHow do we analyze algorithms? First we identify',
#   'start': 741.3,
#   'duration': 11.91},
#  {'text': 'what are the primitive operations in our pseudo-code.\nWhat is a primitive operation? It is a low',
#   'start': 753.21,
#   'duration': 7.3},
#  {'text': 'level operation. Example is a data movement\nin ,I do an assignment from one to another,',
#   'start': 760.51,
#   'duration': 5.22},
#  {'text': 'I do a control statement which is a branch\n(if... then ...else) subroutine call or return.',
#   'start': 765.73,
#   'duration': 6.12},
#  {'text': 'I do arithmetic operations or logical operations\nthese are all we called as a primitive operation.',
#   'start': 771.85,
#   'duration': 5.661},
#  {'text': '• Data movement (assign)\n• Control (branch, subroutine call, return)',
#   'start': 777.511,
#   'duration': 1.0},
#  {'text': '• Arithmetic an logical operations (e.g.\naddition, comparison)',
#   'start': 778.511,
#   'duration': 1.0},
#  {'text': 'In my pseudo code, I just inspect the pseudo\ncode and count the number of primitive operations',
#   'start': 779.511,
#   'duration': 3.239},
#  {'text': 'that are executed by an algorithm. Let us\nsee an example of sorting. You all know what',
#   'start': 782.75,
#   'duration': 11.31},
#  {'text': 'sorting is, the input is some sequence of\nnumbers and output is a permutation of the',
#   'start': 794.06,
#   'duration': 6.57},
#  {'text': 'sequence which is in non decreasing order.\nWhat are ',
#   'start': 800.63,
#   'duration': 19.3},
#  {'text': 'the requirements for the output? It should\nbe in non-decreasing order and it should be',
#   'start': 819.93,
#   'duration': 7.57},
#  {'text': 'the permutation of the input.', 'start': 827.5, 'duration': 1.46},
#  {'text': 'Any set of numbers which are in non-decreasing\norder does not make an output. Algorithm should',
#   'start': 828.96,
#   'duration': 6.4},
#  {'text': 'sort the numbers that were given to it and\nnot just produce the sequence of numbers as',
#   'start': 835.36,
#   'duration': 4.72},
#  {'text': 'an increasing order. Clearly the running time\nwill depends upon, number of elements (n)',
#   'start': 840.08,
#   'duration': 7.97},
#  {'text': 'and often it depends upon, how sorted these\nnumbers are. If they are already in sorted',
#   'start': 848.05,
#   'duration': 11.29},
#  {'text': 'order then the algorithm will not take a long\ntime. It also depends upon the particular',
#   'start': 859.34,
#   'duration': 6.91},
#  {'text': 'algorithm we use. The running time would depend\nupon all these things. The first sorting technique',
#   'start': 866.25,
#   'duration': 8.77},
#  {'text': 'we use is the one that you have used very\noften.',
#   'start': 875.02,
#   'duration': 3.6},
#  {'text': 'Let us say when you are playing game of cards.',
#   'start': 878.62,
#   'duration': 7.94},
#  {'text': 'What is the strategy you follow, when you\nare picking up a set of cards that have been',
#   'start': 886.56,
#   'duration': 5.02},
#  {'text': 'dealt out to you? You like to keep them in\na sorted order in your hand. You start with',
#   'start': 891.58,
#   'duration': 6.45},
#  {'text': 'the empty hand and you pick up the first card,\nthen you take the next card and insert it',
#   'start': 898.03,
#   'duration': 5.369},
#  {'text': 'at the appropriate place.', 'start': 903.399, 'duration': 1.12},
#  {'text': 'Suppose if I have some five cards in your\nhand already, let us say 2, 7, 9, jack and',
#   'start': 904.519,
#   'duration': 5.88},
#  {'text': 'queen. Then I getting 8, so I am going to\nput it between 7 and 9. That is the right',
#   'start': 910.399,
#   'duration': 6.581},
#  {'text': 'place it has to be placed in. I am inserting\nit at the appropriate place and that is why',
#   'start': 916.98,
#   'duration': 7.39},
#  {'text': 'this technique is called insertion sort. I\nkeep on doing this, till I have picked up',
#   'start': 924.37,
#   'duration': 6.0},
#  {'text': 'all the cards and inserted in the appropriate\nplace.',
#   'start': 930.37,
#   'duration': 7.81},
#  {'text': 'So this is the pseudo-code for insertion sort.\nI will give an array of integers A contain',
#   'start': 938.18,
#   'duration': 14.11},
#  {'text': 'input and output is a permutation of the original\nnumbers, such that it is sorted. The output',
#   'start': 952.29,
#   'duration': 8.33},
#  {'text': 'is also going to be in the same array.\nA [1]≤ A [2]≤ _ ≤ A[n]',
#   'start': 960.62,
#   'duration': 1.93},
#  {'text': 'This is the input, output specification. I\nam going to have 2 variables or indices i',
#   'start': 962.55,
#   'duration': 9.53},
#  {'text': 'and j. The array is going to be sorted from\na [1] through a [j-1]. The jth Location is',
#   'start': 972.08,
#   'duration': 16.23},
#  {'text': 'an element which I have to insert appropriately\nto the right place Clearly j has to vary from',
#   'start': 988.31,
#   'duration': 13.55},
#  {'text': '2 to n.', 'start': 1001.86, 'duration': 1.0},
#  {'text': 'For j ←2 to n', 'start': 1002.86, 'duration': 1.0},
#  {'text': 'I am going to look at jth element and I put\nthat in key. Key ←A[j] I have to insert',
#   'start': 1003.86,
#   'duration': 6.9},
#  {'text': 'A [j] or the key in to the sorted sequence\nwhich is A [1] through A [j-1]. i.e. A [1_j-1]',
#   'start': 1010.76,
#   'duration': 10.16},
#  {'text': 'I am going to use the index i to do this.\nWhat is index i going to do? Index i is going',
#   'start': 1020.92,
#   'duration': 8.47},
#  {'text': 'to run down from j-1 down to 1. We going to\ndecrease index i, which is what we are doing',
#   'start': 1029.39,
#   'duration': 8.659},
#  {'text': 'in here in this while do loop.',
#   'start': 1038.049,
#   'duration': 6.5},
#  {'text': 'It starts with the value j-1.And what I am\ngoing to do? I have to insert 7 and I am going',
#   'start': 1044.549,
#   'duration': 11.451},
#  {'text': 'to move 9 to 7th location, because 9 is more\nthan 7. Then I compare 7 with 8 and 8 is still',
#   'start': 1056.0,
#   'duration': 17.23},
#  {'text': 'greater than 7, so I will move it right. Then\nI compare 7 with 6. As 6 is smaller than 7,Now',
#   'start': 1073.23,
#   'duration': 6.92},
#  {'text': 'I found the right place for 7, I would put\n7 here ,that exactly what is happening here.',
#   'start': 1080.15,
#   'duration': 8.159},
#  {'text': 'I run through this loop, till I find an element\nwhich is less than key. Key is the element',
#   'start': 1088.309,
#   'duration': 7.05},
#  {'text': 'which I am trying to insert. This loop will\ncontinue while the element, I am consider',
#   'start': 1095.359,
#   'duration': 4.671},
#  {'text': 'is more than key and this loop will terminate,\nwhen I see an element which is less than key',
#   'start': 1100.03,
#   'duration': 4.68},
#  {'text': 'or the loop will terminate when I reach i=0.\nWhile i >0 and A[i] > key do A [i+1] ← A[i]',
#   'start': 1104.71,
#   'duration': 5.99},
#  {'text': 'That means I have moved everything to the\nright and I should insert the element at the',
#   'start': 1110.7,
#   'duration': 3.969},
#  {'text': 'very first place and what am I doing Here?\nI am just shifting the element one step to',
#   'start': 1114.669,
#   'duration': 4.791},
#  {'text': 'the right. Do A [i+1] ← A[i]', 'start': 1119.46, 'duration': 2.86},
#  {'text': 'Note that I have to insert 7 at the right\nplace, so I shift 9 right to 1 step. 9th location',
#   'start': 1122.32,
#   'duration': 6.07},
#  {'text': 'becomes empty, then I shift 8 to 1 step, so\nthis 8th location becomes empty and now I',
#   'start': 1128.39,
#   'duration': 6.69},
#  {'text': 'can put 7 here. i + 1 is the index, which\nwould be the empty location eventually and',
#   'start': 1135.08,
#   'duration': 9.809},
#  {'text': 'i put the key there. A [i+1]← key All of\nyou can implement it. May be you would have',
#   'start': 1144.889,
#   'duration': 5.88},
#  {'text': 'implemented it in a slightly different way,\nthat would give you a different program, but',
#   'start': 1150.769,
#   'duration': 4.831},
#  {'text': 'the algorithm is essentially the same. You\nare going to find the right place for the',
#   'start': 1155.6,
#   'duration': 5.75},
#  {'text': 'element and insert it.Now Let us analyze this\nalgorithm.',
#   'start': 1161.35,
#   'duration': 13.02},
#  {'text': 'I have put down the algorithm on the left\n(There is a small mistake here there should',
#   'start': 1174.37,
#   'duration': 7.09},
#  {'text': 'be a left arrow Please make a correction on\nthat) .What we are going to do?',
#   'start': 1181.46,
#   'duration': 6.429},
#  {'text': 'A [i+1] ← A key\nLet us count.',
#   'start': 1187.889,
#   'duration': 2.47},
#  {'text': 'Key ← A[j]\nI ← j-1', 'start': 1190.359, 'duration': 1.41},
#  {'text': 'These are all my primitive operations. Here\nI have to do primitive operations, why because',
#   'start': 1191.769,
#   'duration': 10.84},
#  {'text': 'I am comparing i with 0 and I am comparing\nA[i] with key, I am also taking and, so there',
#   'start': 1202.609,
#   'duration': 9.42},
#  {'text': 'are three primitive operations.\nwhile i >0 and A[i] > key',
#   'start': 1212.029,
#   'duration': 5.75},
#  {'text': 'Each of the operation takes a certain amount\nof time, depending upon the computer system',
#   'start': 1217.779,
#   'duration': 6.541},
#  {'text': 'you have.C1,C2,C3,C4,C5,C6 just Reflect or\njust represent the amount of time taken for',
#   'start': 1224.32,
#   'duration': 5.989},
#  {'text': 'these operations and they can be in any units.\nAnd here I am counting the number of times,',
#   'start': 1230.309,
#   'duration': 9.45},
#  {'text': 'each of these operations is executed is done\nin this entire program.',
#   'start': 1239.759,
#   'duration': 7.461},
#  {'text': 'Why this operation is done n times? I start\nby assigning j =2 then assign 3, 4,5,6,7 and',
#   'start': 1247.22,
#   'duration': 16.54},
#  {'text': 'go up to n. Then when I increment it once\nand check that there is one more, so I have',
#   'start': 1263.76,
#   'duration': 6.149},
#  {'text': 'counted it as n times. There might be small\nerrors in n and n + 1, that is not very important.',
#   'start': 1269.909,
#   'duration': 7.27},
#  {'text': 'So this roughly n times we have to do this\noperation.',
#   'start': 1277.179,
#   'duration': 2.35},
#  {'text': 'How about this operation? Key ← A[j] I am\ngoing to do exactly n-1 times once for 2,',
#   'start': 1279.529,
#   'duration': 5.46},
#  {'text': 'once for3, once for 4 up to n. That is why\nthis operation is being done up to n-1 times.',
#   'start': 1284.989,
#   'duration': 6.961},
#  {'text': 'Just leave the comment statement. Again the\noperation will be done exactly n-1 times.',
#   'start': 1291.95,
#   'duration': 5.37},
#  {'text': 'We have to look at how many times I come to\nthis statement. While I >0 and A[i] > key',
#   'start': 1297.32,
#   'duration': 11.059},
#  {'text': 'tj -reflects the Counts the number of times\nI have to shift an element to the right, when',
#   'start': 1308.379,
#   'duration': 12.821},
#  {'text': 'I am inserting the jth card in to my hand.\nIn the previous example when I am inserting',
#   'start': 1321.2,
#   'duration': 11.39},
#  {'text': '7, I had to shift 2 elements 8 and 9. is going\nto count that quantity and that is the number',
#   'start': 1332.59,
#   'duration': 14.81},
#  {'text': 'of times I am going to reach A[i] part of\nmy while loop. While I >0 and A[i] >key',
#   'start': 1347.4,
#   'duration': 10.36},
#  {'text': 'I will be checking this condition for many\ntimes. For one iteration or for the jth iteration',
#   'start': 1357.76,
#   'duration': 8.07},
#  {'text': 'of this for loop, I am going to reach this\ncondition for tj times. The total number of',
#   'start': 1365.83,
#   'duration': 5.37},
#  {'text': 'times I am saying that condition is the sum\nof tj as j goes from 2 to n. ∑nj=2 tj ,while',
#   'start': 1371.2,
#   'duration': 5.209},
#  {'text': 'I >0 and A[i] > key,\ndo A[i+1] ← A[i]',
#   'start': 1376.409,
#   'duration': 1.811},
#  {'text': 'Every time I see (A[i] >key) condition I also\ncome to A[i], I am going to be see this condition,',
#   'start': 1378.22,
#   'duration': 4.589},
#  {'text': 'I am going to come this statement one more\ntime then, I come here because you know the',
#   'start': 1382.809,
#   'duration': 3.761},
#  {'text': 'last time i see the statement I would exit\nout of here. That is why this is tj -1 where',
#   'start': 1386.57,
#   'duration': 4.939},
#  {'text': 'j going from 2 to n.∑nj=2 (t j-1)',
#   'start': 1391.509,
#   'duration': 5.601},
#  {'text': 'A [i+1] ← A key. This statement here is\nnot a part of the while loop (this is an assignment',
#   'start': 1397.11,
#   'duration': 8.35},
#  {'text': 'operation please correct this). So this statement\nis part of the for loop is done exactly n',
#   'start': 1405.46,
#   'duration': 7.32},
#  {'text': 'minus one times as the other statement. So\nthe total time this procedure takes if you',
#   'start': 1412.78,
#   'duration': 6.399},
#  {'text': 'knew what this constant work can be computed.\nYou do not know what tj is. tj is quantity',
#   'start': 1419.179,
#   'duration': 8.23},
#  {'text': 'which depends upon your instance and not problem\nthere is a difference here. Problem is one',
#   'start': 1427.409,
#   'duration': 10.65},
#  {'text': 'of sorting. The instance is a set of numbers,\nthe sequence of numbers that have given to',
#   'start': 1438.059,
#   'duration': 7.231},
#  {'text': 'you. Thus tj depends upon the instance.',
#   'start': 1445.29,
#   'duration': 4.489},
#  {'text': 'Let us see the difference that tj makes. If\nthe input was already sorted, then tj is always',
#   'start': 1449.779,
#   'duration': 14.77},
#  {'text': '1(tj=1). I just have to compare the element\nwith the last element and if it is larger',
#   'start': 1464.549,
#   'duration': 6.191},
#  {'text': 'than the last element, I would not have to\ndo anything. tj is always a 1 if the input',
#   'start': 1470.74,
#   'duration': 6.179},
#  {'text': 'is already in increasing order.',
#   'start': 1476.919,
#   'duration': 3.651},
#  {'text': 'What happens when the input is in decreasing\norder? If the input is in decreasing order,',
#   'start': 1480.57,
#   'duration': 6.4},
#  {'text': 'then the number that I am trying to insert\nis going to be smaller than all the numbers',
#   'start': 1486.97,
#   'duration': 8.72},
#  {'text': 'that that i already have because the input\nis in decreasing order the number I am trying',
#   'start': 1495.69,
#   'duration': 7.589},
#  {'text': 'to insert is smaller than the numbers I have\nsorted in my array .What am I going to do?',
#   'start': 1503.279,
#   'duration': 5.201},
#  {'text': 'I am going to compare with the 1st element,2nd\nelement,3rd element, 4th element and all the',
#   'start': 1508.48,
#   'duration': 4.409},
#  {'text': 'way up to the element. When I am trying to\ninsert the tj element, I am going to end up',
#   'start': 1512.889,
#   'duration': 7.931},
#  {'text': 'in comparing with all the other j elements\nin the array. In that case when tj is equal',
#   'start': 1520.82,
#   'duration': 5.799},
#  {'text': 'to j, note that the quantity becomes its summation\nof j, where j goes from 2 to n. It is of the',
#   'start': 1526.619,
#   'duration': 8.88},
#  {'text': 'kind and the running time n square of this\nalgorithm would be some constant time plus',
#   'start': 1535.499,
#   'duration': 7.68},
#  {'text': 'some other constant times n minus some other\nconstant.',
#   'start': 1543.179,
#   'duration': 2.531},
#  {'text': 'n(C1+C2+C3+C7)+∑nj=2 t j(C4+C5+C6)-(C2+C3+C5+C6+C7)',
#   'start': 1545.71,
#   'duration': 1.0},
#  {'text': 'Thus the behavior of this running time is\nmore like n square. We come to this point',
#   'start': 1546.71,
#   'duration': 5.649},
#  {'text': 'later, when we talk about asymptotic analysis\nbut this is what I meant by f(n square). On',
#   'start': 1552.359,
#   'duration': 8.7},
#  {'text': 'the other hand in the best case when tj=1,\nthe sum is just n or n-1 and in that case',
#   'start': 1561.059,
#   'duration': 7.891},
#  {'text': 'the total time is n times some constant plus\nn-1 times some constant minus some constant',
#   'start': 1568.95,
#   'duration': 5.13},
#  {'text': 'which is roughly n times some constant. So\nwhat we call linear time algorithm.',
#   'start': 1574.08,
#   'duration': 15.349},
#  {'text': 'On an average what would you expect? In the\nbest case it is something like that you have',
#   'start': 1589.429,
#   'duration': 3.281},
#  {'text': 'to compare only against one element you have\nto compare only against one element and in',
#   'start': 1592.71,
#   'duration': 1.96},
#  {'text': 'the worst case you have to compare about j\nelements. In the average case would expect',
#   'start': 1594.67,
#   'duration': 4.02},
#  {'text': 'that it would take compare against half of\nthis element In an average case if you were',
#   'start': 1598.69,
#   'duration': 5.7},
#  {'text': 'to take it as you comparing again j/2 , even\nwhen the summation of j/2 where j goes from',
#   'start': 1604.39,
#   'duration': 7.07},
#  {'text': '2 to n, what will this be? This will be roughly\nby (n square/4) and it behaves like n square(',
#   'start': 1611.46,
#   'duration': 10.26},
#  {'text': 'and will come to these points in a minute).\nThis is what I mean by the best, worst and',
#   'start': 1621.72,
#   'duration': 5.509},
#  {'text': 'average case. I take the size of input, suppose\nif I am interested in sorting n numbers and',
#   'start': 1627.229,
#   'duration': 8.01},
#  {'text': 'I look at all possible instances of these\nn numbers.',
#   'start': 1635.239,
#   'duration': 4.79},
#  {'text': 'It may be infinitely many, again it is not\nclear about how to do that. What is worst',
#   'start': 1640.029,
#   'duration': 7.091},
#  {'text': 'case?\nThe worst case is defined as the maximum possible',
#   'start': 1647.12,
#   'duration': 3.259},
#  {'text': 'time that your algorithm would take for any\ninstance of that size. So these are all the',
#   'start': 1650.379,
#   'duration': 8.29},
#  {'text': 'instances are of the same size. The best case\nwould be the smallest time that your algorithm',
#   'start': 1658.669,
#   'duration': 8.281},
#  {'text': 'takes and the average would be the average\nof all infinite bars. That was for the input',
#   'start': 1666.95,
#   'duration': 18.77},
#  {'text': 'for 1size of size n, that would give the values,\nfrom that we can compute worst case, best',
#   'start': 1685.72,
#   'duration': 9.649},
#  {'text': 'case and the average case. If I would consider\ninputs of all sizes then I can create a plot',
#   'start': 1695.369,
#   'duration': 7.391},
#  {'text': 'for each inputs size and I could figure out\nthe worst case, best case and an average case.',
#   'start': 1702.76,
#   'duration': 6.769},
#  {'text': 'Then I would get such a monotonically increasing\nplots. It is clear that as the size of the',
#   'start': 1709.529,
#   'duration': 8.311},
#  {'text': 'input increases, the time taken by your algorithm\nwill increase. It is not going to happen that',
#   'start': 1717.84,
#   'duration': 6.059},
#  {'text': 'your input size become larger and it takes\nlesser time.',
#   'start': 1723.899,
#   'duration': 6.72},
#  {'text': 'Which of this is the easiest to work with?\nWorst case is the one we will use the most.',
#   'start': 1730.619,
#   'duration': 9.88},
#  {'text': 'For the purpose of this course this is the\nonly measure we will be working with. Why',
#   'start': 1740.499,
#   'duration': 5.17},
#  {'text': 'is the worst case used often? First it provides\nan upper bound and it tells you how long your',
#   'start': 1745.669,
#   'duration': 6.96},
#  {'text': 'algorithm is going to take in the worst case.',
#   'start': 1752.629,
#   'duration': 3.52},
#  {'text': 'Many algorithms occurs fairly often. Quite\noften it is the case that the worst case that',
#   'start': 1756.149,
#   'duration': 7.39},
#  {'text': 'for many instances the time taken by the algorithm\nis close to the worst case .So that average',
#   'start': 1763.539,
#   'duration': 7.301},
#  {'text': 'case essentially becomes as bad as the worst\ncase In fact for the previous example that',
#   'start': 1770.84,
#   'duration': 7.25},
#  {'text': 'we saw average case was like n square squared\nand worst case was also n squared there were',
#   'start': 1778.09,
#   'duration': 5.069},
#  {'text': 'differences in the constant but it was roughly\nthe same.The average case might be very difficult',
#   'start': 1783.159,
#   'duration': 8.95},
#  {'text': 'quantity to compete because as you said average\ncase if you have to compute look at all possible',
#   'start': 1792.109,
#   'duration': 3.78},
#  {'text': 'instances and then take some kind of average\n.Or you have to say like, when my input instance',
#   'start': 1795.889,
#   'duration': 6.79},
#  {'text': 'is drawn from a certain distribution and the\nexpected time my algorithm will take is typically',
#   'start': 1802.679,
#   'duration': 7.25},
#  {'text': 'a much harder quantity to work and to compute\nwith.',
#   'start': 1809.929,
#   'duration': 5.31},
#  {'text': 'The worst case is the measure of interest\nin which we will be working with. Asymptotic',
#   'start': 1815.239,
#   'duration': 12.94},
#  {'text': 'analysis is the kind of thing that we have\nbeen doing so far as n and n square and the',
#   'start': 1828.179,
#   'duration': 7.58},
#  {'text': 'goal of this is to analyze the running time\nwhile getting rid of superficial details.',
#   'start': 1835.759,
#   'duration': 7.64},
#  {'text': 'We would like to say that an algorithm, which\nhas the running time of some constant times',
#   'start': 1843.399,
#   'duration': 8.941},
#  {'text': 'squared is the same as an algorithm which\nhas a running time of some other constant',
#   'start': 1852.34,
#   'duration': 5.439},
#  {'text': 'times ,because this constant is typically\nsomething which would be dependent upon the',
#   'start': 1857.779,
#   'duration': 6.63},
#  {'text': 'hardware that your using.\n3n2 = n2',
#   'start': 1864.409,
#   'duration': 2.27},
#  {'text': 'In the previous exampleC1,C2, and C3 would\ndepend upon the computer system, the hardware,',
#   'start': 1866.679,
#   'duration': 7.48},
#  {'text': 'the compiler and many factors. We are not\ninterested to distinguish between such algorithms.',
#   'start': 1874.159,
#   'duration': 9.551},
#  {'text': 'Both of these algorithms, one which has the\nrunning time of 3 n square and another with',
#   'start': 1883.71,
#   'duration': 4.809},
#  {'text': 'running time n square have a quadratic behavior.\nWhen the input size doubles the running time',
#   'start': 1888.519,
#   'duration': 7.89},
#  {'text': 'of both of the algorithm increases four fold.',
#   'start': 1896.409,
#   'duration': 6.36},
#  {'text': 'That is the thing which is of interest to\nus. We are interested in capturing how the',
#   'start': 1902.769,
#   'duration': 5.721},
#  {'text': 'running time of algorithm increases, with\nthe size of the input in the limit. This is',
#   'start': 1908.49,
#   'duration': 8.519},
#  {'text': 'the crucial point here and that is what the\nsymptotic analysis is all about here. In the',
#   'start': 1917.009,
#   'duration': 5.76},
#  {'text': 'limit how does the running time of this algorithm\nincrease in input size.',
#   'start': 1922.769,
#   'duration': 6.351},
#  {'text': 'That brings us to something that some of you\nmight have seen before the "big-oh" O-notation.',
#   'start': 1929.12,
#   'duration': 9.72},
#  {'text': 'If I have functions f(n) , g (n) and n represents\nthe input size. f (n) measures the time taken',
#   'start': 1938.84,
#   'duration': 12.48},
#  {'text': 'by that algorithm. f (n) and g (n) are non-negative\nfunctions and also non-decreasing, because',
#   'start': 1951.32,
#   'duration': 11.689},
#  {'text': 'as the input size increases, the running time\ntaken by the algorithm would also increase.',
#   'start': 1963.009,
#   'duration': 11.101},
#  {'text': 'Both of these are non-decreasing functions\nof n and we say that f (n) is O (g (n)), if',
#   'start': 1974.11,
#   'duration': 10.609},
#  {'text': 'there exist constants c and , such that f\n(n)≤ c times of g (n)≥ n0 .',
#   'start': 1984.719,
#   'duration': 5.131},
#  {'text': 'f (n) =O(g(n)\nf (n) c g(n) for n ≥ n0',
#   'start': 1989.85,
#   'duration': 3.829},
#  {'text': 'What does it mean? I have drawn two functions.\nThe function in red is f (n) and g (n) is',
#   'start': 1993.679,
#   'duration': 5.48},
#  {'text': 'some other function. The function in green\nis some constant times of g (n). As you can',
#   'start': 1999.159,
#   'duration': 5.06},
#  {'text': 'see beyond the point , c (g (n)) is always\nlarger than that of f (n). This is the way',
#   'start': 2004.219,
#   'duration': 9.5},
#  {'text': 'it continues even beyond. Then we would say\nthat f (n) is O (g (n) or f (n) is order (g',
#   'start': 2013.719,
#   'duration': 11.981},
#  {'text': '(n)).', 'start': 2025.7, 'duration': 1.0},
#  {'text': 'f (n) = O (g(n))', 'start': 2026.7, 'duration': 3.179},
#  {'text': 'Few examples would clarify this and we will\nsee those examples. The function f (n) =2n+6',
#   'start': 2029.879,
#   'duration': 13.16},
#  {'text': 'and g (n) =n. If you look at these two functions\n2n+6 is always larger than ',
#   'start': 2043.039,
#   'duration': 18.201},
#  {'text': 'n and you might be wondering why this 2n+6\nis a non-linear function. That is because',
#   'start': 2061.24,
#   'duration': 4.34},
#  {'text': 'the scale here is an exponential scale. The\nscale increases by 2 on y-axis and similarly',
#   'start': 2065.58,
#   'duration': 7.029},
#  {'text': 'on x-axis. The red colored line is n and the\nblue line is 2n and the above next line is',
#   'start': 2072.609,
#   'duration': 17.691},
#  {'text': '4n. As you can see beyond the dotted line\nf (n) is less than 4 times of n. Hence the',
#   'start': 2090.3,
#   'duration': 10.92},
#  {'text': 'constant c is 4 and would be this point of\ncrossing beyond which 4n becomes larger than',
#   'start': 2101.22,
#   'duration': 11.4},
#  {'text': '2n+6.', 'start': 2112.62, 'duration': 7.12},
#  {'text': 'At what point does 4n becomes larger than\n2n+6. It is three. So becomes three. Then',
#   'start': 2119.74,
#   'duration': 13.63},
#  {'text': 'we say that f (n) which is 2n+6 is O (n).\n2n+6 = O (n)',
#   'start': 2133.37,
#   'duration': 12.87},
#  {'text': 'Let us look at another example. The function\nin red is g (n) which is n and any constant',
#   'start': 2146.24,
#   'duration': 16.1},
#  {'text': 'time g (n) which is as same scale as in the\nprevious slide. Any constant time g (n) will',
#   'start': 2162.34,
#   'duration': 4.99},
#  {'text': 'be just the same straight line displaced by\nsuitable amount. The green line will be 4',
#   'start': 2167.33,
#   'duration': 8.48},
#  {'text': "times n and it depends upon the intercept,\nbut you're n2 would be like the line which",
#   'start': 2175.81,
#   'duration': 10.65},
#  {'text': 'is blue in color. So there is no constant\nc such that n2 < c (n).',
#   'start': 2186.46,
#   'duration': 9.86},
#  {'text': 'Can you find out a constant c so that n2 < c\n(n) for n more than . We cannot find it.',
#   'start': 2196.32,
#   'duration': 5.11},
#  {'text': 'Any constant that you choose, I can pick a\nlarger n such that this is violated and so',
#   'start': 2201.43,
#   'duration': 9.43},
#  {'text': 'it is not the case that n2 is O (n).',
#   'start': 2210.86,
#   'duration': 9.64},
#  {'text': 'How does one figure out these things? This\nis the very simple rule. Suppose this is my',
#   'start': 2220.5,
#   'duration': 5.13},
#  {'text': 'function 50 n log n, I just drop all constants\nand the lower order terms. Forget the constant',
#   'start': 2225.63,
#   'duration': 7.89},
#  {'text': '50 and I get n log n. This function 50 n log\nn is O (n log n). In the function 7n-3, I',
#   'start': 2233.52,
#   'duration': 13.2},
#  {'text': 'drop the constant and lower order terms, I\nget 7n-3 as O (n).',
#   'start': 2246.72,
#   'duration': 4.67},
#  {'text': 'I have some complicated function like 8n2\nlog n+ 5n2 +n in which I just drop all lower',
#   'start': 2251.39,
#   'duration': 6.11},
#  {'text': 'order terms. This is the fastest growing term\nbecause this has n2 as well as log n in it.',
#   'start': 2257.5,
#   'duration': 6.42},
#  {'text': 'I just drop n2 , n term and also I drop my\nconstant and get n2 log n. This function is',
#   'start': 2263.92,
#   'duration': 8.85},
#  {'text': 'O ( log n). There is a constant c such that\nthis quantity this large sum here is less',
#   'start': 2272.77,
#   'duration': 9.46},
#  {'text': 'than c times n square log n for n larger than\nsum n0. In the limit this quantity (8n2 log',
#   'start': 2282.23,
#   'duration': 7.32},
#  {'text': 'n+5n2 +n) will be less than some constant\ntimes this quantity (O (n2 log n)). You can',
#   'start': 2289.55,
#   'duration': 5.641},
#  {'text': 'figure out what should be the value of c and\nn0 , for that to happen.',
#   'start': 2295.191,
#   'duration': 7.119},
#  {'text': 'This is a common error. The function 50 n\nlog n is also O (n5). Whether it is yes or',
#   'start': 2302.31,
#   'duration': 9.5},
#  {'text': 'no. It is yes, because this quantity (50 n\nlog n) in fact is ≤ 50 times n5 always,',
#   'start': 2311.81,
#   'duration': 9.3},
#  {'text': 'for all n and that is just a constant so this\nis O(n5). But when we use the O-notation we',
#   'start': 2321.11,
#   'duration': 10.33},
#  {'text': 'try and provide as strong amount as possible\ninstead of saying this statement is true we',
#   'start': 2331.44,
#   'duration': 6.41},
#  {'text': 'will rather call this as O (n log n)). We\nwill see more of this in subsequent slides.',
#   'start': 2337.85,
#   'duration': 13.75},
#  {'text': 'How are we going to use the O-notation? We\nare going to express the number of primitive',
#   'start': 2351.6,
#   'duration': 8.73},
#  {'text': 'operations that are executed during run of\nthe program as a function of the input size.',
#   'start': 2360.33,
#   'duration': 7.13},
#  {'text': 'We are going to use O-notation for that. If\nI have an algorithm which takes the number',
#   'start': 2367.46,
#   'duration': 9.28},
#  {'text': 'of primitive operations as O (n) and some\nother algorithm for which the number of primitive',
#   'start': 2376.74,
#   'duration': 4.82},
#  {'text': 'operations is O (n2 ). Then clearly the first\nalgorithm is better than the second. Why because',
#   'start': 2381.56,
#   'duration': 5.801},
#  {'text': 'as the input size doubles then the running\ntime of the algorithm is also going to double,',
#   'start': 2387.361,
#   'duration': 6.739},
#  {'text': 'while the running time of O (n2 ) algorithm\nwill increase four fold.',
#   'start': 2394.1,
#   'duration': 5.45},
#  {'text': 'Similarly our algorithm which has the running\ntime of O (log n) is better than the one which',
#   'start': 2399.55,
#   'duration': 4.94},
#  {'text': 'has running time of O (n). Thus we have a\nhierarchy of functions in the order of log',
#   'start': 2404.49,
#   'duration': 8.17},
#  {'text': 'n, n2,n3,n4, .', 'start': 2412.66, 'duration': 13.15},
#  {'text': 'There is a word of caution here. You might\nhave an algorithm whose running time is 1,000,000',
#   'start': 2425.81,
#   'duration': 5.6},
#  {'text': 'n, because you may be doing some other operations.\nI cannot see how you would create such an',
#   'start': 2431.41,
#   'duration': 7.97},
#  {'text': 'algorithm, but you might have an algorithm\nof this running time. 1,000,000n is O (n),',
#   'start': 2439.38,
#   'duration': 5.78},
#  {'text': 'because this is ≤ some constant time n and\nyou might have some other algorithm with the',
#   'start': 2445.16,
#   'duration': 4.99},
#  {'text': 'running time of 2n2 .\nHence from what I said before, you would say',
#   'start': 2450.15,
#   'duration': 5.36},
#  {'text': 'that 1,000,000 n algorithm is better than\n2n2 . The one with the linear running time',
#   'start': 2455.51,
#   'duration': 6.13},
#  {'text': 'which is O (n) running time is better than\nO (n2). It is true but in the limit and the',
#   'start': 2461.64,
#   'duration': 5.91},
#  {'text': 'limit is achieved very late when n is really\nlarge. For small instances this 2 might actually',
#   'start': 2467.55,
#   'duration': 7.12},
#  {'text': 'take less amount of time than your 1,000,000\nn. You have to be careful about the constants',
#   'start': 2474.67,
#   'duration': 6.82},
#  {'text': 'also.', 'start': 2481.49, 'duration': 1.81},
#  {'text': 'We will do some examples of asymptotic analysis.\nI have a pseudo code and I have an array of',
#   'start': 2483.3,
#   'duration': 17.59},
#  {'text': 'n numbers sitting in an array called x and\nI have to output an array A, in which the',
#   'start': 2500.89,
#   'duration': 10.63},
#  {'text': 'element A[i] is the average of the numbers\nX [0] through X[i]. One way of doing it is,',
#   'start': 2511.52,
#   'duration': 16.48},
#  {'text': 'I basically have a for loop in which I compute\neach element of the array A. To compute A',
#   'start': 2528.0,
#   'duration': 10.21},
#  {'text': '[10],what should I do? I just have to sum\nup X [0] through X [10], which I am doing',
#   'start': 2538.21,
#   'duration': 6.89},
#  {'text': 'here.\nFor j ← 0 to I do', 'start': 2545.1, 'duration': 4.13},
#  {'text': 'A ← a + X[j]\nA[i]← a/ (i+1)', 'start': 2549.23, 'duration': 1.43},
#  {'text': 'To compute A [10], i is taking the value 10\nand I am running the index j from 0-10. I',
#   'start': 2550.66,
#   'duration': 8.601},
#  {'text': 'am summing up the value of X from X [0] - X\n[10] in this accumulator a and then I am eventually',
#   'start': 2559.261,
#   'duration': 8.309},
#  {'text': 'dividing the value of this accumulator with\n11, because it is from X [0] to X [10]. That',
#   'start': 2567.57,
#   'duration': 7.531},
#  {'text': 'gives me the number I should have in A [10].\nI am going to repeat this for 11,12,13,14',
#   'start': 2575.101,
#   'duration': 11.209},
#  {'text': 'and for all the elements.', 'start': 2586.31, 'duration': 5.23},
#  {'text': 'It is an algorithm and let us compute the\nrunning time. This is one step. It is executed',
#   'start': 2591.54,
#   'duration': 12.1},
#  {'text': 'for i number of times and initially i take\na value from 0,1,2,3 and all the way up to',
#   'start': 2603.64,
#   'duration': 8.25},
#  {'text': 'n-1. This entire thing is done n times. This\ngives you the total running time of roughly',
#   'start': 2611.89,
#   'duration': 11.05},
#  {'text': '.\na ← a+ X[j]', 'start': 2622.94, 'duration': 1.0},
#  {'text': 'This one step is getting executed times and\nthis is the dominant thing. How many times',
#   'start': 2623.94,
#   'duration': 8.4},
#  {'text': 'the steps given below are executed?\nA[i] ← a/ (j+1)',
#   'start': 2632.34,
#   'duration': 2.28},
#  {'text': 'a ← 0 These steps are executed for n times.\na ← a + X[j] But the step mentioned above',
#   'start': 2634.62,
#   'duration': 3.64},
#  {'text': 'is getting executed roughly for some constant\nn2 times. Thus the running time of the algorithm',
#   'start': 2638.26,
#   'duration': 8.98},
#  {'text': 'is O (n2). It is a very simple problem but\nyou can have a better solution.',
#   'start': 2647.24,
#   'duration': 12.23},
#  {'text': 'What is a better solution? We will have a\nvariable S in which we would keep accumulating',
#   'start': 2659.47,
#   'duration': 10.73},
#  {'text': 'the X[i]. Initially S=0. When I compute A[i],\nwhich I already have in S, X [0] through X',
#   'start': 2670.2,
#   'duration': 17.59},
#  {'text': '[i-1] because they used that at the last step.\nThat is the problem here.',
#   'start': 2687.79,
#   'duration': 5.99},
#  {'text': 'a ← a +X[j]', 'start': 2693.78, 'duration': 1.43},
#  {'text': 'Every time we are computing X. First we are\ncomputing X [0] + X [1], then we are computing',
#   'start': 2695.21,
#   'duration': 4.69},
#  {'text': 'X [0] + X [1] +X [2] and goes on. It is a\nkind of repeating computations. Why should',
#   'start': 2699.9,
#   'duration': 5.81},
#  {'text': 'we do that? We will have a single variable\nwhich will keep track of the sum of the prefixes.',
#   'start': 2705.71,
#   'duration': 10.41},
#  {'text': 'S at this point (s← s+x[i]), when I am in\nthe jth run of this loop has some of X [0]',
#   'start': 2716.12,
#   'duration': 9.12},
#  {'text': 'through X [i-1] and then some X[i] in it.\nTo compute jth element, I just need to divide',
#   'start': 2725.24,
#   'duration': 6.39},
#  {'text': 'this sum by i +1.\nS ←S +X[i]', 'start': 2731.63, 'duration': 2.05},
#  {'text': 'A[i] ← S/ (i+1)\nI keep this accumulator(S) around with me.',
#   'start': 2733.68,
#   'duration': 3.79},
#  {'text': 'When I finish the jth iteration of this loop,\nI have an S, the sum X [0] through X[i]. I',
#   'start': 2737.47,
#   'duration': 11.98},
#  {'text': 'can reuse it for the next step.',
#   'start': 2749.45,
#   'duration': 1.46},
#  {'text': 'How much time does this take? In each run\nof this loop I am just doing two primitive',
#   'start': 2750.91,
#   'duration': 8.32},
#  {'text': 'operations that makes an order n times, because\nthis loop is executed n times. I have been',
#   'start': 2759.23,
#   'duration': 17.95},
#  {'text': 'using this freely linear and quadratic, but\nthe slide given below just tells you the other',
#   'start': 2777.18,
#   'duration': 6.62},
#  {'text': 'terms I might be using.', 'start': 2783.8, 'duration': 1.42},
#  {'text': 'Linear is when an algorithm has an asymptotic\nrunning time of O (n), then we call it as',
#   'start': 2785.22,
#   'duration': 6.87},
#  {'text': 'a linear algorithm. If it has asymptotic running\ntime of n2 , we called it as a quadratic and',
#   'start': 2792.09,
#   'duration': 5.5},
#  {'text': 'logarithmic if it is log n. It is polynomial\nif it is nk for some constant k.',
#   'start': 2797.59,
#   'duration': 9.53},
#  {'text': 'Algorithm is called exponential if it has\nrunning time of (a n), where a is some number',
#   'start': 2807.12,
#   'duration': 4.94},
#  {'text': 'more than 1. Till now I have introduced only\nthe big-oh notation, we also have the big-omega',
#   'start': 2812.06,
#   'duration': 13.79},
#  {'text': 'notation and big-theta notation. The "big-Omega"\nnotation provides a lower bound. The function',
#   'start': 2825.85,
#   'duration': 10.39},
#  {'text': 'f (n) is omega of g (n),', 'start': 2836.24, 'duration': 3.05},
#  {'text': 'f (n) =Ω (g(n))', 'start': 2839.29, 'duration': 3.83},
#  {'text': 'If constant time g (n) is always less than\nf(n), earlier that was more than f(n) but',
#   'start': 2843.12,
#   'duration': 6.85},
#  {'text': 'now it is less than f(n) in the limit, beyond\na certain as the picture given below illustrates.',
#   'start': 2849.97,
#   'duration': 6.76},
#  {'text': 'c g (n) f (n) for n\nf (n) is more than c (g(n)) beyond the point',
#   'start': 2856.73,
#   'duration': 4.69},
#  {'text': '. That case we will say that f (n) is omega\nof g (n).',
#   'start': 2861.42,
#   'duration': 6.87},
#  {'text': 'f (n) =Ω (g (n))', 'start': 2868.29, 'duration': 2.82},
#  {'text': 'In θ notation f (n) is θ (g (n), if there\nexist constant and such that f (n) is sandwiched',
#   'start': 2871.11,
#   'duration': 8.83},
#  {'text': 'between C1 g (n) and C2 g (n). Beyond a certain\npoint, f (n) lies between 1 constant time',
#   'start': 2879.94,
#   'duration': 8.48},
#  {'text': 'g (n) and another constant time of g (n).\nThen f (n) is θ (g (n)) where f (n) grows',
#   'start': 2888.42,
#   'duration': 8.54},
#  {'text': 'like g (n) in the limit. Another way of thinking\nof it is, f (n) is θ (g (n)). If f (n) is',
#   'start': 2896.96,
#   'duration': 12.25},
#  {'text': 'O (g (n)) and it also Ω (g (n). There are\ntwo more related asymptotic notations, one',
#   'start': 2909.21,
#   'duration': 22.24},
#  {'text': 'is called "Little-oh" notation and the other\nis called "Little-omega" notation. They are',
#   'start': 2931.45,
#   'duration': 4.94},
#  {'text': 'the non-tight analogs of Big-oh and Big-omega.\nIt is best to understand this through the',
#   'start': 2936.39,
#   'duration': 13.06},
#  {'text': 'analogy of real numbers.', 'start': 2949.45, 'duration': 1.99},
#  {'text': 'When I say that f (n) is O (g (n)) and iam\nreally saying that the function f in some',
#   'start': 2951.44,
#   'duration': 6.2},
#  {'text': 'sense is less than or equal to g, that in\nfact what use in definition or f (n) is less',
#   'start': 2957.64,
#   'duration': 8.36},
#  {'text': 'than c (g (n). The analogy with the real numbers\nis when the number is less than or equal to',
#   'start': 2966.0,
#   'duration': 6.36},
#  {'text': 'another number. is for and is for =. θ (g\n(n) is function and f=g are real numbers.',
#   'start': 2972.36,
#   'duration': 8.09},
#  {'text': 'If these are real numbers, you can talk of\nequality but you cannot talk of equality for',
#   'start': 2980.45,
#   'duration': 5.501},
#  {'text': 'a function unless they are equal. Little-oh\ncorresponds to strictly less than g and Little-omega',
#   'start': 2985.951,
#   'duration': 13.949},
#  {'text': 'corresponds to strictly more. We are not going\nto use these, infact we will use Big-oh. You',
#   'start': 2999.9,
#   'duration': 9.35},
#  {'text': 'should be very clear with that part.',
#   'start': 3009.25,
#   'duration': 7.56},
#  {'text': 'The formal definition for Little-oh is that,\nfor every constant c there should exist some',
#   'start': 3016.81,
#   'duration': 9.68},
#  {'text': 'such that f (n) is  n0 . f\n(n) ≤ c (g(n)) for n ≥ n0 How it is different',
#   'start': 3026.49,
#   'duration': 7.7},
#  {'text': 'from Big- oh? In that case I said, there exist\nc and such that this is true. Here we will',
#   'start': 3034.19,
#   'duration': 7.0},
#  {'text': 'say for every c there should exist an n0 .',
#   'start': 3041.19,
#   'duration': 11.61},
#  {'text': 'This is just one slide I had put up to show\nwhat the differences between these functions',
#   'start': 3052.8,
#   'duration': 4.12},
#  {'text': 'is like. I have an algorithm whose running\ntimes are like 400n, 20n log n, 2 ,2n2,n4',
#   'start': 3056.92,
#   'duration': 6.11},
#  {'text': 'and 2n . Also I have listed out, the largest\nproblem size that you can solve in 1 second',
#   'start': 3063.03,
#   'duration': 8.12},
#  {'text': 'or 1 minute or 1 hour. The largest problem\nsize that you can solve is roughly 2500.',
#   'start': 3071.15,
#   'duration': 6.76},
#  {'text': 'Say you using some some constant, so it lets\nsay 2500if you had this has running time let',
#   'start': 3077.91,
#   'duration': 8.91},
#  {'text': 'say your this is what the problem size would\nbe like 4096. Why did you say that 4096 is',
#   'start': 3086.82,
#   'duration': 7.23},
#  {'text': 'larger than 2500, although 20n log n is the\nworst running time than 400n, because of the',
#   'start': 3094.05,
#   'duration': 6.25},
#  {'text': 'constant. You can see the differences happening.\nIf it is 2n2 then the problem size is 707',
#   'start': 3100.3,
#   'duration': 7.47},
#  {'text': 'and when it is the problem size is 19.',
#   'start': 3107.77,
#   'duration': 3.93},
#  {'text': 'See the behavior as the time increases. An\nhour is 3600seconds and there is a huge increase',
#   'start': 3111.7,
#   'duration': 7.61},
#  {'text': 'in the size of the problem you solve, if it\nis linear time algorithm. Still there is a',
#   'start': 3119.31,
#   'duration': 6.4},
#  {'text': 'large increase, when it is n log n algorithm\nand not so large increase when it is an n2',
#   'start': 3125.71,
#   'duration': 4.81},
#  {'text': 'algorithm and almost no increase when it is\n2n algorithm. If you have an algorithm whose',
#   'start': 3130.52,
#   'duration': 5.8},
#  {'text': 'running time is something like 2n , you cannot\nsolve for problem of more than size 100. It',
#   'start': 3136.32,
#   'duration': 7.62},
#  {'text': 'will take millions of years to solve it.',
#   'start': 3143.94,
#   'duration': 4.65},
#  {'text': 'So that is the behavior that bothers us that\nis the behavior we are interested in course',
#   'start': 3148.59,
#   'duration': 5.71},
#  {'text': 'that is why a asymptotic analysis is what\nwe we considering most of it. So any questions',
#   'start': 3154.3,
#   'duration': 9.94},
#  {'text': 'till this point so with that we are going\nto stop this lecture. Today we have looked',
#   'start': 3164.24,
#   'duration': 7.47},
#  {'text': 'at\nasymptotic analysis and some initial notation',
#   'start': 3171.71,
#   'duration': 4.2},
#  {'text': 'and terminology that we be following with\nthis course.',
#   'start': 3175.91,
#   'duration': 34.75}]

# %%
pipeline_results
# Out:
# [['7kLHJ-F33GI',
#   'sliding_window-tfidf-cosine-median_(3,3)-spectral_clustering',
#   "{'n_clusters': 18.0, 'sim_thresh': 0.6, 'step_size': 10.0, 'window_size': 150.0}",
#   0.8181818181818182],
#  ['7kLHJ-F33GI',
#   'sliding_window-tfidf-cosine-None-spectral_clustering',
#   "{'n_clusters': 14.502132028215444, 'sim_thresh': 0.5160973480326474, 'step_size': 10.005718740867245, 'window_size': 59.30323444213917}",
#   0.7272727272727273],
#  ['7kLHJ-F33GI',
#   'sliding_window-tfidf-cosine-None-spectral_clustering',
#   "{'n_clusters': 12.880535344902679, 'sim_thresh': 0.32770157843063935, 'step_size': 19.313010568883545, 'window_size': 64.9228945155962}",
#   0.7272727272727273],
#  ['7snJ1mx1EMQ',
#   'sliding_window-tfidf-cosine-median_(2,2)-spectral_clustering',
#   "{'n_clusters': 16.432431412456257, 'sim_thresh': 0.3000063890009115, 'step_size': 59.99514192872911, 'window_size': 21.1099397077962}",
#   0.8571428571428571],
#  ['7snJ1mx1EMQ',
#   'sliding_window-tfidf-cosine-median_(3,3)-spectral_clustering',
#   "{'n_clusters': 12.0, 'sim_thresh': 0.6, 'step_size': 60.0, 'window_size': 113.1280123783269}",
#   0.7142857142857143],
#  ['7snJ1mx1EMQ',
#   'sliding_window-tfidf-cosine-None-spectral_clustering',
#   "{'n_clusters': 18.0, 'sim_thresh': 0.6, 'step_size': 60.0, 'window_size': 20.0}",
#   0.5714285714285714],
#  ['RIawrYLVdIw',
#   'sliding_window-tfidf-cosine-None-spectral_clustering',
#   "{'n_clusters': 14.786160659898577, 'sim_thresh': 0.5924873369457966, 'step_size': 10.073958555862824, 'window_size': 60.422260605496106}",
#   0.625],
#  ['RIawrYLVdIw',
#   'sliding_window-tfidf-cosine-median_(3,3)-spectral_clustering',
#   "{'n_clusters': 14.786160659898577, 'sim_thresh': 0.5924873369457966, 'step_size': 10.073958555862824, 'window_size': 60.422260605496106}",
#   0.625],
#  ['RIawrYLVdIw',
#   'sliding_window-tfidf-cosine-median_(2,2)-spectral_clustering',
#   "{'n_clusters': 14.786160659898577, 'sim_thresh': 0.5924873369457966, 'step_size': 10.073958555862824, 'window_size': 60.422260605496106}",
#   0.5],
#  ['tORLeHHtazM',
#   'sliding_window-tfidf-cosine-median_(3,3)-spectral_clustering',
#   "{'n_clusters': 12.880535344902679, 'sim_thresh': 0.32770157843063935, 'step_size': 19.313010568883545, 'window_size': 64.9228945155962}",
#   0.6],
#  ['tORLeHHtazM',
#   'sliding_window-tfidf-cosine-median_(2,2)-spectral_clustering',
#   "{'n_clusters': 17.91079887564834, 'sim_thresh': 0.817336080129486, 'step_size': 11.151010670803554, 'window_size': 199.95285581039045}",
#   0.4],
#  ['tORLeHHtazM',
#   'sliding_window-tfidf-cosine-None-spectral_clustering',
#   "{'n_clusters': 14.502132028215444, 'sim_thresh': 0.5160973480326474, 'step_size': 10.005718740867245, 'window_size': 59.30323444213917}",
#   0.0],
#  ['zWg7U0OEAoE',
#   'sliding_window-tfidf-cosine-median_(3,3)-spectral_clustering',
#   "{'n_clusters': 12.880535344902679, 'sim_thresh': 0.32770157843063935, 'step_size': 19.313010568883545, 'window_size': 64.9228945155962}",
#   0.384615385],
#  ['zWg7U0OEAoE',
#   'sliding_window-tfidf-cosine-median_(3,3)-spectral_clustering',
#   "{'n_clusters': 17.90913045315346, 'sim_thresh': 0.48840541351614664, 'step_size': 22.277728309382358, 'window_size': 55.313492553993115}",
#   0.307692308],
#  ['zWg7U0OEAoE',
#   'sliding_window-tfidf-cosine-None-spectral_clustering',
#   "{'n_clusters': 18.0, 'sim_thresh': 0.6, 'step_size': 60.0, 'window_size': 150.0}",
#   0.230769231]]

# %%
def boundryevaluation(curresults,ground_base,accurrcy_shift = 30):
        true_positive = 0
        false_negative = 0
        false_positive = 0 
        true_positive_list_debug = []
        #false_negative_list_debug = []
        false_positive_list_debug = []
        results = curresults[:]
        
        
        #print('curresults %s' %(curresults))
        #print('ground_base %s ' %(ground_base))
        
        for grb in ground_base:
            is_false_positive = True
            for res in results:     
                if abs(res - grb) < accurrcy_shift:
                    is_false_positive = False
                    true_positive_list_debug.append(res)
                    true_positive+=1
                    results.remove(res)
                    break   
            if is_false_positive:
                false_positive_list_debug.append(grb)
                false_positive+=1
                
        #print("TP: " + str(true_positive_list_debug))
        #print("FP: " + str(false_positive_list_debug))
        #print("FN: " + str(curresults))
        #print('true_positive : %s ' %(true_positive))
        false_negative = len(results) # make sure the true positive are removed from here 
        recall_rate = true_positive/(true_positive + false_negative )
        precision_rate = true_positive/(true_positive + false_positive)
        #print("TP: %s , FP: %s, FN: %s" %(true_positive,false_positive,false_negative))
        #print("precision rate : %s, recall rate : %s " % (precision_rate,recall_rate))
        return precision_rate

# %%
videos_division = {}

for vid in videos_ids:
    vid_results = list(filter(lambda x: x[0] == vid,pipeline_results))
    max_precision = 0
    vid_words = None
    vid_shifts = None
    for result in vid_results:
        '''From the get optimized by bayesian we get that for the video '''
        vid = result[0]
        params = ast.literal_eval(result[2]) #{'n_clusters': 18, 'sim_thresh': 0.6, 'step_size': 49, 'window_size': 150}
        #print(params)
        for key in ['n_clusters','step_size','window_size']:
            params[key] = int(params[key])# - 1
        workflow = result[1] #'sliding_window-tfidf-cosine-median_(3,3)-spectral_clustering'
        
        shifts = df_videos.loc[df_videos['video id'] == vid,'topic shifts(ends)'].values.tolist()
        groundbase = shifts[:-1]
        transcripts = transcripts_jsons[vid]
        #print(grounbase)
        _pipeline = workflow.split('-')
        filter_type = None
        mask_shape = None
        filtering = _pipeline[3]
        if filtering != 'None':
            filter_type = filtering.split('_')[0]
            mask_shape = ast.literal_eval(filtering.split('_')[1])
        '''This running may not work at first time do not give up and run it couple of times'''

        '''print('Running the following %s for video %s with params %s %s %s'
              %(workflow, vid,params,filter_type,mask_shape))'''
        #print(vid_results[1])
        #print(str(filter_type) + " " + str(mask_shape))
        shift_times,topic_words = (None,None)
        n_trials = 5
        while shift_times is None and topic_words is None and n_trials > 0:
            print('##################################################')
            print("running trial %s for vid %s desired precision %s "%(n_trials,vid,result[3]))
            n_trials= n_trials - 1
            shift_times,topic_words = pipeline.run_for_baye(groundbase,
                                                            transcripts,
                                                            slicing_method='sliding_window',
                                                            window_size=params['window_size'],#59
                                                            step_size_sd= params['step_size'], #10
                                  vector_method='tfidf',vectorizing_params=None,
                                  similarity_method='cosine',
                                  filter_params={"filter_type":filter_type,
                                                 "mask_shape":mask_shape,
                                                 "sim_thresh": params['sim_thresh'], #0.5160973480326474 
                                                 "is_min_thresh":True
                                                 },
                                 clustering_params={
                                         'algorithm':'spectral_clustering',
                                         'n_clusters':params['n_clusters'] #14
                                         },
                                        accurrcy_shift=30,
                                        return_value='division') or (None,None)

            if shift_times is not None:
                pr = boundryevaluation(shift_times,groundbase,accurrcy_shift=30)
                print("output precision %s " %(pr))
                
                if pr > max_precision:
                    print("new high percision caught")
                    max_precision = pr 
                    vid_words = topic_words
                    shift_times.append('end')
                    vid_shifts = shift_times 
                if pr < result[3]:
                    shift_times,topic_words = (None,None)    

    videos_division[vid] = {'topic_words':vid_words,'topic_shift':vid_shifts}
# Out:
# ##################################################
# running trial 5 for vid 7kLHJ-F33GI desired precision 0.8181818181818182
# output precision 0.5454545454545454
# new high percision caught
# ##################################################
# running trial 4 for vid 7kLHJ-F33GI desired precision 0.8181818181818182
# output precision 0.5454545454545454
# ##################################################
# running trial 3 for vid 7kLHJ-F33GI desired precision 0.8181818181818182
# output precision 0.6363636363636364
# new high percision caught
# ##################################################
# running trial 2 for vid 7kLHJ-F33GI desired precision 0.8181818181818182
# output precision 0.6363636363636364
# ##################################################
# running trial 1 for vid 7kLHJ-F33GI desired precision 0.8181818181818182
# output precision 0.5454545454545454
# ##################################################
# running trial 5 for vid 7kLHJ-F33GI desired precision 0.7272727272727273
# output precision 0.7272727272727273
# new high percision caught
# ##################################################
# running trial 5 for vid 7kLHJ-F33GI desired precision 0.7272727272727273
# output precision 0.5454545454545454
# ##################################################
# running trial 4 for vid 7kLHJ-F33GI desired precision 0.7272727272727273
# output precision 0.5454545454545454
# ##################################################
# running trial 3 for vid 7kLHJ-F33GI desired precision 0.7272727272727273
# output precision 0.5454545454545454
# ##################################################
# running trial 2 for vid 7kLHJ-F33GI desired precision 0.7272727272727273
# output precision 0.5454545454545454
# ##################################################
# running trial 1 for vid 7kLHJ-F33GI desired precision 0.7272727272727273
# output precision 0.5454545454545454
# ##################################################
# running trial 5 for vid 7snJ1mx1EMQ desired precision 0.8571428571428571
# output precision 0.8571428571428571
# new high percision caught
# ##################################################
# running trial 5 for vid 7snJ1mx1EMQ desired precision 0.7142857142857143
# output precision 0.7142857142857143
# ##################################################
# running trial 5 for vid 7snJ1mx1EMQ desired precision 0.5714285714285714
# output precision 0.5714285714285714
# ##################################################
# running trial 5 for vid RIawrYLVdIw desired precision 0.625
# output precision 0.625
# new high percision caught
# ##################################################
# running trial 5 for vid RIawrYLVdIw desired precision 0.625
# output precision 0.5
# ##################################################
# running trial 4 for vid RIawrYLVdIw desired precision 0.625
# output precision 0.625
# ##################################################
# running trial 5 for vid RIawrYLVdIw desired precision 0.5
# output precision 0.5
# ##################################################
# running trial 5 for vid tORLeHHtazM desired precision 0.6
# output precision 0.6
# new high percision caught
# ##################################################
# running trial 5 for vid tORLeHHtazM desired precision 0.4
# output precision 0.4
# ##################################################
# running trial 5 for vid tORLeHHtazM desired precision 0.0
# label 9 has done already cannot evaluate unsequentional segmentation, try other parameters
# ##################################################
# running trial 4 for vid tORLeHHtazM desired precision 0.0
# label 5 has done already cannot evaluate unsequentional segmentation, try other parameters
# ##################################################
# running trial 3 for vid tORLeHHtazM desired precision 0.0
# label 13 has done already cannot evaluate unsequentional segmentation, try other parameters
# ##################################################
# running trial 2 for vid tORLeHHtazM desired precision 0.0
# label 13 has done already cannot evaluate unsequentional segmentation, try other parameters
# ##################################################
# running trial 1 for vid tORLeHHtazM desired precision 0.0
# label 13 has done already cannot evaluate unsequentional segmentation, try other parameters
# ##################################################
# running trial 5 for vid zWg7U0OEAoE desired precision 0.384615385
# label 10 has done already cannot evaluate unsequentional segmentation, try other parameters
# ##################################################
# running trial 4 for vid zWg7U0OEAoE desired precision 0.384615385
# label 10 has done already cannot evaluate unsequentional segmentation, try other parameters
# ##################################################
# running trial 3 for vid zWg7U0OEAoE desired precision 0.384615385
# label 10 has done already cannot evaluate unsequentional segmentation, try other parameters
# ##################################################
# running trial 2 for vid zWg7U0OEAoE desired precision 0.384615385
# label 3 has done already cannot evaluate unsequentional segmentation, try other parameters
# ##################################################
# running trial 1 for vid zWg7U0OEAoE desired precision 0.384615385
# label 10 has done already cannot evaluate unsequentional segmentation, try other parameters
# ##################################################
# running trial 5 for vid zWg7U0OEAoE desired precision 0.307692308
# output precision 0.46153846153846156
# new high percision caught
# ##################################################
# running trial 5 for vid zWg7U0OEAoE desired precision 0.230769231
# output precision 0.3076923076923077

# %%
#videos_division

# %% [markdown]
# # EXTRACT MAIN CHAPTERS OF BOOKS AND ORAGANIZE THE PAPER AS DIFFERENT DOCUMENTS GROUPS

# %%
paper_content[doc_name].keys()
# Out:
# dict_keys(['corpus', 'titles', 'main titles'])

# %%
'''Find the following for each paper:
    1) main chapter title index. for example [10,15....]
    2) range of subsection within each main chapter . for example [(0,9),(11,14)...]
    
    '''

paper_mainchapter_indexes = {}
paper_sec_within_main_indexes = {}
paper_mains_as_one_doc = {}
paper_subsec_as_one_doc = {}

for doc_name in paper_content.keys():
    '''Find the main chapter indexes in the list of the overall titles'''
    mainchapter_indexes = [paper_content[doc_name]['titles'].index(ch_title)
                           for ch_title in paper_content[doc_name]['main titles']]
    '''Find the subsection indexes range within each main chapter '''
    subsec_mainchapter_indexes = [range(mainchapter_indexes[index],mainchapter_indexes[index + 1])
                                  for index in range(len(mainchapter_indexes) - 1)]
    subsec_mainchapter_indexes.append(range(mainchapter_indexes[-1],
                                            len(paper_content[doc_name]['titles'])))
    paper_mainchapter_indexes[doc_name] = mainchapter_indexes
    paper_sec_within_main_indexes[doc_name] = subsec_mainchapter_indexes
    
    
    '''Making each chapter as a one documents'''
    
    '''Union all the documents in a section into single document'''
    paper_subsec_as_one_doc[doc_name] = [list(reduce(lambda doc,acc:doc + acc,sec,[]))
                                         for sec in paper_content[doc_name]['corpus']]
    '''Union all the sub section in a main chapter into one document'''
    paper_mains_as_one_doc[doc_name] = [list(reduce(lambda acc,s_i:
                                                    paper_subsec_as_one_doc[doc_name][s_i]+acc,subsec_indexes,[]))
                                        for subsec_indexes in paper_sec_within_main_indexes[doc_name]]

# %%
#paper_subsec_as_one_doc['statbook'][0]

# %%
'''Debug'''
"""
print(paper_content['statbook']['main titles'])
print((paper_content['statbook']['titles']))
print(len(paper_content['statbook']['titles']))# 
print(len(paper_content['statbook']['corpus']))#members of each element:section corpus
print(len(paper_content['statbook']['corpus'][0]))#members of each element: documents
print(len(paper_content['statbook']['corpus'][0][0])) #of each element words
print(paper_sec_within_main_indexes['statbook'])


#debug
print(sum([len(paper_subsec_as_one_doc['statbook'][s]) for s in range(0,10)]))
print(len(paper_mains_as_one_doc['statbook'][0]))
print(len(paper_mains_as_one_doc['statbook']))



"""
"""#print(len(paper_subsec_as_one_doc['statbook']))
print((subsec_mainchapter_indexes))
print(len(paper_content['Dsa']['titles']))
print(len(paper_subsec_as_one_doc[doc_name]))
print(len(paper_sec_within_main_indexes[doc_name]))
print(paper_content['Dsa']['titles'][-1])
print(paper_subsec_as_one_doc[doc_name][-2])
"""
"""print(paper_content['Dsa']['main titles'][0])
print(len(paper_mains_as_one_doc['Dsa'][0][0]))
print((paper_mains_as_one_doc['Dsa'][0][0]))
#print(len(paper_sec_within_main_indexes['Dsa'][0][0]))
print(len(paper_subsec_as_one_doc['Dsa'][0]))
print((paper_subsec_as_one_doc['Dsa'][0][0]))
print(len(videos_division['tORLeHHtazM']['topic_words'][0][0]))
print((videos_division['tORLeHHtazM']['topic_words'][0][0]))"""

#paper_content['Dsa']['corpus']
print((paper_mains_as_one_doc['Dsa'][0][0]))
# Out:
# flnal

# %% [markdown]
# # FIND CORRELATION BETWEEN MAIN CHAPTERES AND FOUNDED TOPICS IN THE VIDEO

# %%
def find_top_words_of_topic(topic_words,chapter_titles=None):
    for tp_i,tp_words in enumerate(topic_words):
        #
        raw_text = ' '.join(tp_words)
        myvectorizer = CountVectorizer()
        mytf = myvectorizer.fit_transform([raw_text]).toarray()
        #print(mytf)
        maxes = heapq.nlargest(3,mytf[0])
        indexes = []
        for i,bal in enumerate(mytf[0]):
            if bal in maxes:
                indexes.append(i)
        ws = [myvectorizer.get_feature_names()[_] for i,_ in enumerate(indexes)]
        
        if chapter_titles is None:
            print('top words for topic %s are %s' %(tp_i,ws))
        else:
            print('top words for topic %s are %s' %(chapter_titles[tp_i],ws))

# %%
from nltk.corpus import stopwords
from gensim.utils import simple_preprocess
import spacy
stop_words = stopwords.words('english')
nlp = spacy.load('en',disable=['parser','ner'])
allowed_postags=['NOUN', 'ADJ', 'VERB']

# %%
def emphasize_title(book_chapters,titles,factor_enrich = 20):
    chapters_enriched = book_chapters[:]
    
    for index,tl in enumerate(titles):
        tl_text_no_punc = simple_preprocess(tl,deacc=True) 
        tokenized_text_non_stop_words = [ word for word in tl_text_no_punc 
                                         if word not in stop_words]
        text_non_stop_words = ' '.join(tokenized_text_non_stop_words)
        tokenized_lemmas = nlp(text_non_stop_words)
        tokenized_lemmas = [token.lemma_ for token in tokenized_lemmas \
                            if token.pos_ in allowed_postags]
        chapters_enriched[index] = chapters_enriched[index] + tokenized_lemmas * factor_enrich
    return chapters_enriched

# %%
def get_topic_chapter_corr_tfidf(paper_name,book_chapters,
                                 vid_topics_words,vid_topics_shift,
                                 dispaly_titles):
    raw_book_video = []
    for tp_vid in vid_topics_words:
        raw_book_video = raw_book_video + [tp_vid]
    
    for ch in book_chapters:
        raw_book_video = raw_book_video + [ch]

    # creating dictionary of all of the words in the corpus of the video and the paper
    print(len(raw_book_video))
    dictionary = Dictionary(raw_book_video)
    #dictionary = Dictionary(book_chapters)
    
    #ch_dict = Dictionary(book_chapters)
    #vid_dict = Dictionary(vid_topics_words)
    
    the_dictionary = dictionary
    
    #whole_corpus = vid_topics_words + book_chapters
    #bgw_corpus = [dictionary.doc2bow(doc) for doc in whole_corpus]
    bgw_chapter = [the_dictionary.doc2bow(doc) for doc in book_chapters]
    bgw_vids = [the_dictionary.doc2bow(doc) for doc in vid_topics_words]
    tf_idf_model_ch = models.TfidfModel(bgw_chapter,dictionary=the_dictionary)
    tf_idf_model_vid = models.TfidfModel(bgw_vids,dictionary=the_dictionary)#,smartirs='lfc')
    
    index_sim = similarities.SparseMatrixSimilarity(tf_idf_model_ch[bgw_chapter],
                                                    num_features=len(the_dictionary))
    
    correlation = [[s for s in index_sim[tf_idf_model_vid[doc]]] for doc in bgw_vids]
    #print(tf_idf_model[bgw_vids])
    
    # find the top n words in the topic (in the video)
    print('$$$$$$$$$$$$$$top words of video topic$$$$$$$$$$$$$$')
    find_top_words_of_topic(videos_division[vid]['topic_words'])
    print('$$$$$$$$$$$$$$top words of book chapters$$$$$$$$$$$$$$')
    find_top_words_of_topic(book_chapters,chapter_titles=dispaly_titles)
    
    
    
    # normalizing the correlation between each topic and chapter 
    for i_t in range(len(correlation)):
        sum_ = sum(correlation[i_t])
        for ch_index in range(len(correlation[i_t])):
            correlation[i_t][ch_index] = correlation[i_t][ch_index]/sum_
    
    corr_as_row = reduce(lambda x,y: x+y,correlation,[] ) # to get the global max in min
    sns.heatmap(correlation,vmin=min(corr_as_row),vmax=max(corr_as_row))
    plt.show()
    
    
    
    # find the cha
    ch_matching_top = []
    #print(len(correlation[0]))
    for i,corr in enumerate(correlation):
        max_cor = max(corr) # max correlation with that topic
        shift = vid_topics_shift[i]

        #ch_matching_top.append(paper_mainchapter_indexes[paper_name][corr.index(max_cor)])
        ch_matching_top.append(dispaly_titles[corr.index(max_cor)])
        
        print (" video_shift index %s at %s , chapter title %s ( index %s) " 
               %(i,
                 sec_to_min(shift),
                 dispaly_titles[corr.index(max_cor)],
                 corr.index(max_cor)
                 ))
    return ch_matching_top
    return None

def find_dominent_main_chapter(ch_tp_corr,titles):
    
    '''Find the frequency of each chapter'''
    chapter_matching_counts_max = [max([ch_tp_corr.count(ch) for ch in ch_tp_corr])]
    for max_count in chapter_matching_counts_max:
        #print("####### #######")
        '''Find the most frequent chapter'''
        #print(([ch for ch in ch_tp_corr if ch_tp_corr.count(ch) == max_count]))
        dominent_chapters = list(set([ch for ch in ch_tp_corr if ch_tp_corr.count(ch) == max_count]))
        #print(dominent_chapters)
        
        # if we have absulote majority on topic
        if len(dominent_chapters) == 1:
            return dominent_chapters[0]
        else:
            '''####################################################3'''
            '''Think in the future maybe change this code ! making the decision based on something statistic else'''
            '''####################################################3'''
            # draw between topics, decide which one by taking this with the high variance
            index_winner = 0
            df_ch_corr =   pd.DataFrame.from_records(ch_tp_corr)
            for j_dom in range(len(dominent_chapters)):
                first = df_ch_corr.var()[titles.index(dominent_chapters[index_winner])]
                #print(first)
                second = df_ch_corr.var()[titles.index(dominent_chapters[j_dom])]
                #print(second)
                if first < second:
                    index_winner = j_dom
            return (dominent_chapters[index_winner])
        
        
def sec_to_min(seconds):
    if seconds == 'end':
        return 'end'
    return ("%02d:%02d"%(seconds//60,seconds%60))

# %%
chapters_matching_topics = {}
for vid in videos_ids:
    print('################ %s ################' % (vid))
    paper_name = video_to_paper[vid]
    '''Finding the correlation between topic and main chapters'''
    main_matching_topic = get_topic_chapter_corr_tfidf(paper_name,
                                 paper_mains_as_one_doc[paper_name],
                                 videos_division[vid]['topic_words'],
                                 videos_division[vid]['topic_shift'],
                                 paper_content[paper_name]['main titles'])
    #print(main_matching_topic)
    dominet_chapter =  find_dominent_main_chapter(main_matching_topic,
                                                  paper_content[paper_name]['main titles'])
    print(dominet_chapter) 
    
    #Searching for each topic the most correlated 
    #subsection to a topic within the dominent main chapter '''
    dom_main_cha_index = paper_content[paper_name]['main titles'].index(dominet_chapter)
    dom_subsec_text = [paper_subsec_as_one_doc[paper_name][s_i] for s_i in
                      paper_sec_within_main_indexes[paper_name][dom_main_cha_index]]
    dom_subsec_titles = [paper_content[paper_name]['titles'][tl]
                         for tl in paper_sec_within_main_indexes[paper_name][dom_main_cha_index]]
    
    dom_subsec_text = emphasize_title(dom_subsec_text,dom_subsec_titles)
    
    subsec_matching_topic = get_topic_chapter_corr_tfidf(paper_name,
                                 dom_subsec_text,
                                 videos_division[vid]['topic_words'],
                                 videos_division[vid]['topic_shift'],
                                 dom_subsec_titles
                                    )
# Out:
# ################ 7kLHJ-F33GI ################
# 37
# $$$$$$$$$$$$$$top words of video topic$$$$$$$$$$$$$$
# top words for topic 0 are ['deal', 'go', 'look']
# top words for topic 1 are ['let', 'maximum', 'sample', 'value']
# top words for topic 2 are ['attempt', 'couple', 'probability']
# top words for topic 3 are ['function', 'go', 'point']
# top words for topic 4 are ['confidence', 'go', 'information']
# top words for topic 5 are ['go', 'information', 'theta']
# top words for topic 6 are ['equation', 'estimate', 'first', 'go', 'point', 'possible', 'thing']
# top words for topic 7 are ['consistent', 'estimator', 'may', 'mean', 'true', 'unbiased', 'value']
# top words for topic 8 are ['function', 'standard', 'theta']
# top words for topic 9 are ['parameter', 'theta', 'vector']
# top words for topic 10 are ['find', 'get', 'little', 'sigma', 'value']
# top words for topic 11 are ['bit', 'equal', 'go', 'respect', 'set', 'square', 'term', 'time']
# top words for topic 12 are ['equation', 'get', 'go']
# top words for topic 13 are ['distribution', 'may', 'use']
# top words for topic 14 are ['check', 'com', 'resource', 'say', 'social', 'statistic', 'statistical', 'video']
# $$$$$$$$$$$$$$top words of book chapters$$$$$$$$$$$$$$
# top words for topic Displaying Data are ['age', 'datum', 'display']
# top words for topic Describing Distributions with Numbers are ['datum', 'mean', 'value']
# top words for topic Correlation and Regression are ['correlation', 'line', 'regression', 'use']
# top words for topic Producing Data are ['datum', 'experiment', 'light', 'use']
# top words for topic The Basics of Probability are ['event', 'number', 'probability']
# top words for topic Conditional Probability and Independence are ['disease', 'event', 'probability']
# top words for topic Random Variables and Distribution Functions are ['function', 'random', 'variable']
# top words for topic The Expected Value are ['random', 'value', 'variable']
# top words for topic Examples of Mass Functions and Densities are ['function', 'random', 'variable']
# top words for topic The Law of Large Numbers are ['integral', 'random', 'variable']
# top words for topic The Central Limit Theorem are ['central', 'random', 'variable']
# top words for topic Overview of Estimation are ['density', 'distribution', 'posterior']
# top words for topic Method of Moments are ['estimate', 'moment', 'number']
# top words for topic Unbiased Estimation are ['estimator', 'unbiased', 'variance']
# top words for topic Maximum Likelihood Estimation are ['estimator', 'likelihood', 'maximum']
# top words for topic Interval Estimation are ['confidence', 'interval', 'value']
# top words for topic Simple Hypotheses are ['hypothesis', 'test', 'value']
# top words for topic Composite Hypotheses are ['hypothesis', 'test', 'value']
# top words for topic Extensions on the Likelihood Ratio are ['hypothesis', 'test', 'value']
# top words for topic Procedures are ['sample', 'test', 'value']
# top words for topic Goodness of Fit are ['statistic', 'table', 'test', 'value']
# top words for topic Analysis of Variance are ['group', 'mean', 'test', 'value']
#  video_shift index 0 at 02:32 , chapter title Maximum Likelihood Estimation ( index 14)
#  video_shift index 1 at 05:11 , chapter title Maximum Likelihood Estimation ( index 14)
#  video_shift index 2 at 09:00 , chapter title Random Variables and Distribution Functions ( index 6)
#  video_shift index 3 at 11:54 , chapter title Maximum Likelihood Estimation ( index 14)
#  video_shift index 4 at 15:08 , chapter title Interval Estimation ( index 15)
#  video_shift index 5 at 18:39 , chapter title Interval Estimation ( index 15)
#  video_shift index 6 at 20:48 , chapter title Unbiased Estimation ( index 13)
#  video_shift index 7 at 24:12 , chapter title Unbiased Estimation ( index 13)
#  video_shift index 8 at 27:43 , chapter title Simple Hypotheses ( index 16)
#  video_shift index 9 at 30:39 , chapter title Maximum Likelihood Estimation ( index 14)
#  video_shift index 10 at 33:47 , chapter title Goodness of Fit ( index 20)
#  video_shift index 11 at 36:48 , chapter title Describing Distributions with Numbers ( index 1)
#  video_shift index 12 at 40:12 , chapter title Unbiased Estimation ( index 13)
#  video_shift index 13 at 42:30 , chapter title Method of Moments ( index 12)
#  video_shift index 14 at end , chapter title Producing Data ( index 3)
# Maximum Likelihood Estimation
# 26
# $$$$$$$$$$$$$$top words of video topic$$$$$$$$$$$$$$
# top words for topic 0 are ['deal', 'go', 'look']
# top words for topic 1 are ['let', 'maximum', 'sample', 'value']
# top words for topic 2 are ['attempt', 'couple', 'probability']
# top words for topic 3 are ['function', 'go', 'point']
# top words for topic 4 are ['confidence', 'go', 'information']
# top words for topic 5 are ['go', 'information', 'theta']
# top words for topic 6 are ['equation', 'estimate', 'first', 'go', 'point', 'possible', 'thing']
# top words for topic 7 are ['consistent', 'estimator', 'may', 'mean', 'true', 'unbiased', 'value']
# top words for topic 8 are ['function', 'standard', 'theta']
# top words for topic 9 are ['parameter', 'theta', 'vector']
# top words for topic 10 are ['find', 'get', 'little', 'sigma', 'value']
# top words for topic 11 are ['bit', 'equal', 'go', 'respect', 'set', 'square', 'term', 'time']
# top words for topic 12 are ['equation', 'get', 'go']
# top words for topic 13 are ['distribution', 'may', 'use']
# top words for topic 14 are ['check', 'com', 'resource', 'say', 'social', 'statistic', 'statistical', 'video']
# $$$$$$$$$$$$$$top words of book chapters$$$$$$$$$$$$$$
# top words for topic Maximum Likelihood Estimation are ['likelihood', 'maximum', 'parameter']
# top words for topic 15.1 are ['function', 'likelihood', 'maximum']
# top words for topic 15.2 Examples are ['estimator', 'example', 'likelihood']
# top words for topic 15.3 Summary of Estimators are ['definition', 'estimator', 'look', 'summary', 'text', 'variable']
# top words for topic 15.4 Asymptotic Properties are ['asymptotic', 'likelihood', 'property']
# top words for topic 15.5 Comparison of Estimation Procedures are ['comparison', 'estimation', 'procedure']
# top words for topic 15.6 Multidimensional Estimation are ['estimation', 'estimator', 'likelihood']
# top words for topic 15.7 The Case of Exponential Families are ['case', 'exponential', 'family']
# top words for topic 15.8 Choice of Estimators are ['cell', 'choice', 'density', 'estimator', 'function']
# top words for topic 15.9 Technical Aspects are ['aspect', 'concept', 'estimator', 'introduce', 'likelihood', 'maximum', 'obtain', 'property', 'technical', 'use']
# top words for topic 15.10 Answers to Selected Exercises are ['answer', 'exercise', 'select']
#  video_shift index 0 at 02:32 , chapter title 15.6 Multidimensional Estimation ( index 6)
#  video_shift index 1 at 05:11 , chapter title 15.6 Multidimensional Estimation ( index 6)
#  video_shift index 2 at 09:00 , chapter title 15.2 Examples ( index 2)
#  video_shift index 3 at 11:54 , chapter title 15.1 ( index 1)
#  video_shift index 4 at 15:08 , chapter title 15.6 Multidimensional Estimation ( index 6)
#  video_shift index 5 at 18:39 , chapter title 15.6 Multidimensional Estimation ( index 6)
#  video_shift index 6 at 20:48 , chapter title 15.2 Examples ( index 2)
#  video_shift index 7 at 24:12 , chapter title 15.4 Asymptotic Properties ( index 4)
#  video_shift index 8 at 27:43 , chapter title 15.6 Multidimensional Estimation ( index 6)
#  video_shift index 9 at 30:39 , chapter title 15.2 Examples ( index 2)
#  video_shift index 10 at 33:47 , chapter title 15.2 Examples ( index 2)
#  video_shift index 11 at 36:48 , chapter title 15.2 Examples ( index 2)
#  video_shift index 12 at 40:12 , chapter title 15.2 Examples ( index 2)
#  video_shift index 13 at 42:30 , chapter title 15.6 Multidimensional Estimation ( index 6)
#  video_shift index 14 at end , chapter title 15.2 Examples ( index 2)
# ################ 7snJ1mx1EMQ ################
# 38
# $$$$$$$$$$$$$$top words of video topic$$$$$$$$$$$$$$
# top words for topic 0 are ['denote', 'estimation', 'model', 'module', 'observation', 'sensor']
# top words for topic 1 are ['make', 'measurement', 'sensor']
# top words for topic 2 are ['density', 'observation', 'probability']
# top words for topic 3 are ['independent', 'noise', 'observation']
# top words for topic 4 are ['density', 'function', 'probability']
# top words for topic 5 are ['density', 'function', 'probability', 'raise', 'square']
# top words for topic 6 are ['function', 'point', 'unknown']
# top words for topic 7 are ['function', 'parameter', 'unknown']
# top words for topic 8 are ['estimate', 'find', 'function', 'likelihood', 'maximum', 'raise']
# top words for topic 9 are ['bar', 'observation', 'vector']
# top words for topic 10 are ['bar', 'function', 'like', 'likelihood', 'maximum', 'would']
# top words for topic 11 are ['function', 'square', 'term']
# top words for topic 12 are ['equal', 'part', 'submission']
# top words for topic 13 are ['estimate', 'maximum', 'observation']
# top words for topic 14 are ['function', 'likelihood', 'maximum', 'observation']
# top words for topic 15 are ['discover', 'estimate', 'estimation', 'interesting', 'likelihood', 'maximum']
# $$$$$$$$$$$$$$top words of book chapters$$$$$$$$$$$$$$
# top words for topic Displaying Data are ['age', 'datum', 'display']
# top words for topic Describing Distributions with Numbers are ['datum', 'mean', 'value']
# top words for topic Correlation and Regression are ['correlation', 'line', 'regression', 'use']
# top words for topic Producing Data are ['datum', 'experiment', 'light', 'use']
# top words for topic The Basics of Probability are ['event', 'number', 'probability']
# top words for topic Conditional Probability and Independence are ['disease', 'event', 'probability']
# top words for topic Random Variables and Distribution Functions are ['function', 'random', 'variable']
# top words for topic The Expected Value are ['random', 'value', 'variable']
# top words for topic Examples of Mass Functions and Densities are ['function', 'random', 'variable']
# top words for topic The Law of Large Numbers are ['integral', 'random', 'variable']
# top words for topic The Central Limit Theorem are ['central', 'random', 'variable']
# top words for topic Overview of Estimation are ['density', 'distribution', 'posterior']
# top words for topic Method of Moments are ['estimate', 'moment', 'number']
# top words for topic Unbiased Estimation are ['estimator', 'unbiased', 'variance']
# top words for topic Maximum Likelihood Estimation are ['estimator', 'likelihood', 'maximum']
# top words for topic Interval Estimation are ['confidence', 'interval', 'value']
# top words for topic Simple Hypotheses are ['hypothesis', 'test', 'value']
# top words for topic Composite Hypotheses are ['hypothesis', 'test', 'value']
# top words for topic Extensions on the Likelihood Ratio are ['hypothesis', 'test', 'value']
# top words for topic Procedures are ['sample', 'test', 'value']
# top words for topic Goodness of Fit are ['statistic', 'table', 'test', 'value']
# top words for topic Analysis of Variance are ['group', 'mean', 'test', 'value']
#  video_shift index 0 at 01:16 , chapter title Overview of Estimation ( index 11)
#  video_shift index 1 at 04:38 , chapter title The Central Limit Theorem ( index 10)
#  video_shift index 2 at 06:44 , chapter title Random Variables and Distribution Functions ( index 6)
#  video_shift index 3 at 09:12 , chapter title Random Variables and Distribution Functions ( index 6)
#  video_shift index 4 at 11:56 , chapter title Random Variables and Distribution Functions ( index 6)
#  video_shift index 5 at 13:42 , chapter title Displaying Data ( index 0)
#  video_shift index 6 at 15:21 , chapter title Overview of Estimation ( index 11)
#  video_shift index 7 at 17:20 , chapter title Maximum Likelihood Estimation ( index 14)
#  video_shift index 8 at 18:54 , chapter title Maximum Likelihood Estimation ( index 14)
#  video_shift index 9 at 21:03 , chapter title Displaying Data ( index 0)
#  video_shift index 10 at 23:06 , chapter title Maximum Likelihood Estimation ( index 14)
#  video_shift index 11 at 25:04 , chapter title Maximum Likelihood Estimation ( index 14)
#  video_shift index 12 at 28:24 , chapter title Maximum Likelihood Estimation ( index 14)
#  video_shift index 13 at 30:31 , chapter title Maximum Likelihood Estimation ( index 14)
#  video_shift index 14 at 31:48 , chapter title Maximum Likelihood Estimation ( index 14)
#  video_shift index 15 at end , chapter title Maximum Likelihood Estimation ( index 14)
# Maximum Likelihood Estimation
# 27
# $$$$$$$$$$$$$$top words of video topic$$$$$$$$$$$$$$
# top words for topic 0 are ['denote', 'estimation', 'model', 'module', 'observation', 'sensor']
# top words for topic 1 are ['make', 'measurement', 'sensor']
# top words for topic 2 are ['density', 'observation', 'probability']
# top words for topic 3 are ['independent', 'noise', 'observation']
# top words for topic 4 are ['density', 'function', 'probability']
# top words for topic 5 are ['density', 'function', 'probability', 'raise', 'square']
# top words for topic 6 are ['function', 'point', 'unknown']
# top words for topic 7 are ['function', 'parameter', 'unknown']
# top words for topic 8 are ['estimate', 'find', 'function', 'likelihood', 'maximum', 'raise']
# top words for topic 9 are ['bar', 'observation', 'vector']
# top words for topic 10 are ['bar', 'function', 'like', 'likelihood', 'maximum', 'would']
# top words for topic 11 are ['function', 'square', 'term']
# top words for topic 12 are ['equal', 'part', 'submission']
# top words for topic 13 are ['estimate', 'maximum', 'observation']
# top words for topic 14 are ['function', 'likelihood', 'maximum', 'observation']
# top words for topic 15 are ['discover', 'estimate', 'estimation', 'interesting', 'likelihood', 'maximum']
# $$$$$$$$$$$$$$top words of book chapters$$$$$$$$$$$$$$
# top words for topic Maximum Likelihood Estimation are ['likelihood', 'maximum', 'parameter']
# top words for topic 15.1 are ['function', 'likelihood', 'maximum']
# top words for topic 15.2 Examples are ['estimator', 'example', 'likelihood']
# top words for topic 15.3 Summary of Estimators are ['definition', 'estimator', 'look', 'summary', 'text', 'variable']
# top words for topic 15.4 Asymptotic Properties are ['asymptotic', 'likelihood', 'property']
# top words for topic 15.5 Comparison of Estimation Procedures are ['comparison', 'estimation', 'procedure']
# top words for topic 15.6 Multidimensional Estimation are ['estimation', 'estimator', 'likelihood']
# top words for topic 15.7 The Case of Exponential Families are ['case', 'exponential', 'family']
# top words for topic 15.8 Choice of Estimators are ['cell', 'choice', 'density', 'estimator', 'function']
# top words for topic 15.9 Technical Aspects are ['aspect', 'concept', 'estimator', 'introduce', 'likelihood', 'maximum', 'obtain', 'property', 'technical', 'use']
# top words for topic 15.10 Answers to Selected Exercises are ['answer', 'exercise', 'select']
#  video_shift index 0 at 01:16 , chapter title 15.6 Multidimensional Estimation ( index 6)
#  video_shift index 1 at 04:38 , chapter title 15.2 Examples ( index 2)
#  video_shift index 2 at 06:44 , chapter title 15.2 Examples ( index 2)
#  video_shift index 3 at 09:12 , chapter title 15.1 ( index 1)
#  video_shift index 4 at 11:56 , chapter title 15.1 ( index 1)
#  video_shift index 5 at 13:42 , chapter title 15.2 Examples ( index 2)
#  video_shift index 6 at 15:21 , chapter title 15.2 Examples ( index 2)
#  video_shift index 7 at 17:20 , chapter title Maximum Likelihood Estimation ( index 0)
#  video_shift index 8 at 18:54 , chapter title 15.9 Technical Aspects ( index 9)
#  video_shift index 9 at 21:03 , chapter title 15.2 Examples ( index 2)
#  video_shift index 10 at 23:06 , chapter title 15.2 Examples ( index 2)
#  video_shift index 11 at 25:04 , chapter title 15.2 Examples ( index 2)
#  video_shift index 12 at 28:24 , chapter title 15.6 Multidimensional Estimation ( index 6)
#  video_shift index 13 at 30:31 , chapter title Maximum Likelihood Estimation ( index 0)
#  video_shift index 14 at 31:48 , chapter title Maximum Likelihood Estimation ( index 0)
#  video_shift index 15 at end , chapter title 15.5 Comparison of Estimation Procedures ( index 5)
# ################ RIawrYLVdIw ################
# 37
# $$$$$$$$$$$$$$top words of video topic$$$$$$$$$$$$$$
# top words for topic 0 are ['break', 'grade', 'instal', 'package', 'point', 'thing', 'use']
# top words for topic 1 are ['distribution', 'make', 'show']
# top words for topic 2 are ['distribution', 'estimate', 'give']
# top words for topic 3 are ['cream', 'hear', 'ice', 'know', 'probability', 'right', 'say']
# top words for topic 4 are ['get', 'head', 'know', 'tail']
# top words for topic 5 are ['observe', 'say', 'theta']
# top words for topic 6 are ['good', 'take', 'thing']
# top words for topic 7 are ['head', 'say', 'toss']
# top words for topic 8 are ['know', 'question', 'say', 'see', 'statistic', 'word']
# top words for topic 9 are ['random', 'say', 'theta', 'variable']
# top words for topic 10 are ['know', 'say', 'statistic', 'theta', 'thing']
# top words for topic 11 are ['distribution', 'say', 'theta']
# top words for topic 12 are ['alpha', 'term', 'theta', 'thing']
# top words for topic 13 are ['give', 'say', 'theta']
# top words for topic 14 are ['next', 'week']
# $$$$$$$$$$$$$$top words of book chapters$$$$$$$$$$$$$$
# top words for topic Displaying Data are ['age', 'datum', 'display']
# top words for topic Describing Distributions with Numbers are ['datum', 'mean', 'value']
# top words for topic Correlation and Regression are ['correlation', 'line', 'regression', 'use']
# top words for topic Producing Data are ['datum', 'experiment', 'light', 'use']
# top words for topic The Basics of Probability are ['event', 'number', 'probability']
# top words for topic Conditional Probability and Independence are ['disease', 'event', 'probability']
# top words for topic Random Variables and Distribution Functions are ['function', 'random', 'variable']
# top words for topic The Expected Value are ['random', 'value', 'variable']
# top words for topic Examples of Mass Functions and Densities are ['function', 'random', 'variable']
# top words for topic The Law of Large Numbers are ['integral', 'random', 'variable']
# top words for topic The Central Limit Theorem are ['central', 'random', 'variable']
# top words for topic Overview of Estimation are ['density', 'distribution', 'posterior']
# top words for topic Method of Moments are ['estimate', 'moment', 'number']
# top words for topic Unbiased Estimation are ['estimator', 'unbiased', 'variance']
# top words for topic Maximum Likelihood Estimation are ['estimator', 'likelihood', 'maximum']
# top words for topic Interval Estimation are ['confidence', 'interval', 'value']
# top words for topic Simple Hypotheses are ['hypothesis', 'test', 'value']
# top words for topic Composite Hypotheses are ['hypothesis', 'test', 'value']
# top words for topic Extensions on the Likelihood Ratio are ['hypothesis', 'test', 'value']
# top words for topic Procedures are ['sample', 'test', 'value']
# top words for topic Goodness of Fit are ['statistic', 'table', 'test', 'value']
# top words for topic Analysis of Variance are ['group', 'mean', 'test', 'value']
#  video_shift index 0 at 02:24 , chapter title Producing Data ( index 3)
#  video_shift index 1 at 05:51 , chapter title Simple Hypotheses ( index 16)
#  video_shift index 2 at 08:52 , chapter title Method of Moments ( index 12)
#  video_shift index 3 at 11:44 , chapter title The Law of Large Numbers ( index 9)
#  video_shift index 4 at 14:21 , chapter title Conditional Probability and Independence ( index 5)
#  video_shift index 5 at 18:17 , chapter title Goodness of Fit ( index 20)
#  video_shift index 6 at 24:04 , chapter title Maximum Likelihood Estimation ( index 14)
#  video_shift index 7 at 27:13 , chapter title Overview of Estimation ( index 11)
#  video_shift index 8 at 30:52 , chapter title Producing Data ( index 3)
#  video_shift index 9 at 34:08 , chapter title Random Variables and Distribution Functions ( index 6)
#  video_shift index 10 at 36:47 , chapter title Overview of Estimation ( index 11)
#  video_shift index 11 at 42:04 , chapter title Overview of Estimation ( index 11)
#  video_shift index 12 at 45:36 , chapter title Overview of Estimation ( index 11)
#  video_shift index 13 at 48:47 , chapter title Random Variables and Distribution Functions ( index 6)
#  video_shift index 14 at end , chapter title The Law of Large Numbers ( index 9)
# Overview of Estimation
# 20
# $$$$$$$$$$$$$$top words of video topic$$$$$$$$$$$$$$
# top words for topic 0 are ['break', 'grade', 'instal', 'package', 'point', 'thing', 'use']
# top words for topic 1 are ['distribution', 'make', 'show']
# top words for topic 2 are ['distribution', 'estimate', 'give']
# top words for topic 3 are ['cream', 'hear', 'ice', 'know', 'probability', 'right', 'say']
# top words for topic 4 are ['get', 'head', 'know', 'tail']
# top words for topic 5 are ['observe', 'say', 'theta']
# top words for topic 6 are ['good', 'take', 'thing']
# top words for topic 7 are ['head', 'say', 'toss']
# top words for topic 8 are ['know', 'question', 'say', 'see', 'statistic', 'word']
# top words for topic 9 are ['random', 'say', 'theta', 'variable']
# top words for topic 10 are ['know', 'say', 'statistic', 'theta', 'thing']
# top words for topic 11 are ['distribution', 'say', 'theta']
# top words for topic 12 are ['alpha', 'term', 'theta', 'thing']
# top words for topic 13 are ['give', 'say', 'theta']
# top words for topic 14 are ['next', 'week']
# $$$$$$$$$$$$$$top words of book chapters$$$$$$$$$$$$$$
# top words for topic Overview of Estimation are ['datum', 'inference', 'knowledge']
# top words for topic 12.1 are ['estimation', 'number', 'parameter', 'probability', 'statistic']
# top words for topic 12.2 Classical Statistics are ['classical', 'estimator', 'statistic']
# top words for topic 12.3 Bayesian Statistics are ['density', 'posterior', 'prior', 'statistic']
# top words for topic 12.4 Answers to Selected Exercises are ['answer', 'exercise', 'select']
#  video_shift index 0 at 02:24 , chapter title Overview of Estimation ( index 0)
#  video_shift index 1 at 05:51 , chapter title 12.3 Bayesian Statistics ( index 3)
#  video_shift index 2 at 08:52 , chapter title 12.1 ( index 1)
#  video_shift index 3 at 11:44 , chapter title 12.3 Bayesian Statistics ( index 3)
#  video_shift index 4 at 14:21 , chapter title 12.3 Bayesian Statistics ( index 3)
#  video_shift index 5 at 18:17 , chapter title 12.1 ( index 1)
#  video_shift index 6 at 24:04 , chapter title 12.2 Classical Statistics ( index 2)
#  video_shift index 7 at 27:13 , chapter title 12.3 Bayesian Statistics ( index 3)
#  video_shift index 8 at 30:52 , chapter title 12.2 Classical Statistics ( index 2)
#  video_shift index 9 at 34:08 , chapter title 12.3 Bayesian Statistics ( index 3)
#  video_shift index 10 at 36:47 , chapter title 12.3 Bayesian Statistics ( index 3)
#  video_shift index 11 at 42:04 , chapter title 12.3 Bayesian Statistics ( index 3)
#  video_shift index 12 at 45:36 , chapter title 12.3 Bayesian Statistics ( index 3)
#  video_shift index 13 at 48:47 , chapter title Overview of Estimation ( index 0)
#  video_shift index 14 at end , chapter title 12.1 ( index 1)
# ################ tORLeHHtazM ################
# 24
# $$$$$$$$$$$$$$top words of video topic$$$$$$$$$$$$$$
# top words for topic 0 are ['grandparent', 'parent', 'tree']
# top words for topic 1 are ['child', 'level', 'tree']
# top words for topic 2 are ['call', 'could', 'directory', 'environment', 'sub', 'tree', 'use']
# top words for topic 3 are ['child', 'leave', 'tree']
# top words for topic 4 are ['binary', 'node', 'tree']
# top words for topic 5 are ['left', 'may', 'right', 'subtree']
# top words for topic 6 are ['child', 'internal', 'tree', 'would']
# top words for topic 7 are ['answer', 'come', 'decision', 'example', 'tree', 'want', 'would']
# top words for topic 8 are ['node', 'number', 'tree']
# top words for topic 9 are ['give', 'position', 'tree']
# top words for topic 10 are ['child', 'method', 'would']
# top words for topic 11 are ['child', 'leave', 'refer', 'would']
# top words for topic 12 are ['class', 'go', 'look', 'reversal', 'tree']
# $$$$$$$$$$$$$$top words of book chapters$$$$$$$$$$$$$$
# top words for topic Introduction are ['algorithm', 'book', 'language']
# top words for topic Linked Lists are ['head', 'link', 'list']
# top words for topic Binary Search Tree are ['end', 'root', 'value']
# top words for topic Heap are ['array', 'heap', 'value']
# top words for topic Sets are ['intersection', 'item', 'order', 'set']
# top words for topic Queues are ['item', 'priority', 'queue']
# top words for topic AVL Tree are ['current', 'tree', 'value']
# top words for topic Sorting are ['end', 'key', 'list']
# top words for topic Numeric are ['algorithm', 'end', 'number', 'numberbase']
# top words for topic Searching are ['index', 'list', 'search']
# top words for topic Strings are ['index', 'value', 'word']
#  video_shift index 0 at 04:09 , chapter title Binary Search Tree ( index 2)
#  video_shift index 1 at 06:38 , chapter title AVL Tree ( index 6)
#  video_shift index 2 at 08:32 , chapter title Introduction ( index 0)
#  video_shift index 3 at 11:25 , chapter title Binary Search Tree ( index 2)
#  video_shift index 4 at 12:44 , chapter title Binary Search Tree ( index 2)
#  video_shift index 5 at 13:53 , chapter title Binary Search Tree ( index 2)
#  video_shift index 6 at 14:36 , chapter title Binary Search Tree ( index 2)
#  video_shift index 7 at 15:47 , chapter title Introduction ( index 0)
#  video_shift index 8 at 32:09 , chapter title AVL Tree ( index 6)
#  video_shift index 9 at 36:18 , chapter title Binary Search Tree ( index 2)
#  video_shift index 10 at 38:54 , chapter title Binary Search Tree ( index 2)
#  video_shift index 11 at 42:34 , chapter title Linked Lists ( index 1)
#  video_shift index 12 at end , chapter title Binary Search Tree ( index 2)
# Binary Search Tree
# 26
# $$$$$$$$$$$$$$top words of video topic$$$$$$$$$$$$$$
# top words for topic 0 are ['grandparent', 'parent', 'tree']
# top words for topic 1 are ['child', 'level', 'tree']
# top words for topic 2 are ['call', 'could', 'directory', 'environment', 'sub', 'tree', 'use']
# top words for topic 3 are ['child', 'leave', 'tree']
# top words for topic 4 are ['binary', 'node', 'tree']
# top words for topic 5 are ['left', 'may', 'right', 'subtree']
# top words for topic 6 are ['child', 'internal', 'tree', 'would']
# top words for topic 7 are ['answer', 'come', 'decision', 'example', 'tree', 'want', 'would']
# top words for topic 8 are ['node', 'number', 'tree']
# top words for topic 9 are ['give', 'position', 'tree']
# top words for topic 10 are ['child', 'method', 'would']
# top words for topic 11 are ['child', 'leave', 'refer', 'would']
# top words for topic 12 are ['class', 'go', 'look', 'reversal', 'tree']
# $$$$$$$$$$$$$$top words of book chapters$$$$$$$$$$$$$$
# top words for topic Binary Search Tree are ['binary', 'search', 'tree']
# top words for topic 3.1	Insertion are ['current', 'insertion', 'value']
# top words for topic 3.2	Searching are ['root', 'search', 'value']
# top words for topic 3.3	Deletion are ['deletion', 'remove', 'value']
# top words for topic 3.4	Finding the parent of a given node are ['find', 'give', 'parent']
# top words for topic 3.5	Attaining a reference to a node are ['attain', 'reference', 'root', 'value']
# top words for topic 3.6	Finding the smallest and largest values in the binary search tree are ['large', 'small', 'value']
# top words for topic 3.7	Tree Traversals are ['strategy', 'traversal', 'tree']
# top words for topic 3.7.1	Preorder are ['end', 'preorder', 'root']
# top words for topic 3.7.2	Postorder are ['binary', 'root', 'search', 'tree']
# top words for topic 3.7.3	Inorder are ['inorder', 'root', 'yield']
# top words for topic 3.7.4	Breadth First are ['end', 'node', 'root', 'visit']
# top words for topic 3.8	Summary are ['binary', 'search', 'summary', 'time', 'tree']
#  video_shift index 0 at 04:09 , chapter title 3.4	Finding the parent of a given node ( index 4)
#  video_shift index 1 at 06:38 , chapter title 3.7.4	Breadth First ( index 11)
#  video_shift index 2 at 08:32 , chapter title 3.7.2	Postorder ( index 9)
#  video_shift index 3 at 11:25 , chapter title 3.7.4	Breadth First ( index 11)
#  video_shift index 4 at 12:44 , chapter title 3.7.4	Breadth First ( index 11)
#  video_shift index 5 at 13:53 , chapter title 3.3	Deletion ( index 3)
#  video_shift index 6 at 14:36 , chapter title 3.7.4	Breadth First ( index 11)
#  video_shift index 7 at 15:47 , chapter title Binary Search Tree ( index 0)
#  video_shift index 8 at 32:09 , chapter title Binary Search Tree ( index 0)
#  video_shift index 9 at 36:18 , chapter title 3.4	Finding the parent of a given node ( index 4)
#  video_shift index 10 at 38:54 , chapter title 3.5	Attaining a reference to a node ( index 5)
#  video_shift index 11 at 42:34 , chapter title 3.5	Attaining a reference to a node ( index 5)
#  video_shift index 12 at end , chapter title 3.2	Searching ( index 2)
# ################ zWg7U0OEAoE ################
# 29
# $$$$$$$$$$$$$$top words of video topic$$$$$$$$$$$$$$
# top words for topic 0 are ['input', 'specification', 'structure']
# top words for topic 1 are ['input', 'time', 'would']
# top words for topic 2 are ['algorithm', 'program', 'run', 'set', 'time', 'would']
# top words for topic 3 are ['algorithm', 'description', 'go', 'time', 'would']
# top words for topic 4 are ['current', 'element', 'go']
# top words for topic 5 are ['call', 'operation', 'primitive', 'return']
# top words for topic 6 are ['card', 'number', 'order', 'place']
# top words for topic 7 are ['element', 'go', 'key']
# top words for topic 8 are ['go', 'operation', 'time']
# top words for topic 9 are ['element', 'go', 'time']
# top words for topic 10 are ['average', 'bad', 'case']
# top words for topic 11 are ['constant', 'function', 'increase', 'input', 'run', 'size', 'time', 'would']
# top words for topic 12 are ['constant', 'function', 'log']
# top words for topic 13 are ['algorithm', 'may', 'number', 'run', 'time']
# top words for topic 14 are ['execute', 'step', 'time']
# top words for topic 15 are ['big', 'notation', 'number', 'time']
# top words for topic 16 are ['problem', 'say', 'size', 'time']
# top words for topic 17 are ['course', 'follow', 'go', 'lecture', 'look', 'notation', 'point', 'stop', 'today']
# $$$$$$$$$$$$$$top words of book chapters$$$$$$$$$$$$$$
# top words for topic Introduction are ['algorithm', 'book', 'language']
# top words for topic Linked Lists are ['head', 'link', 'list']
# top words for topic Binary Search Tree are ['end', 'root', 'value']
# top words for topic Heap are ['array', 'heap', 'value']
# top words for topic Sets are ['intersection', 'item', 'order', 'set']
# top words for topic Queues are ['item', 'priority', 'queue']
# top words for topic AVL Tree are ['current', 'tree', 'value']
# top words for topic Sorting are ['end', 'key', 'list']
# top words for topic Numeric are ['algorithm', 'end', 'number', 'numberbase']
# top words for topic Searching are ['index', 'list', 'search']
# top words for topic Strings are ['index', 'value', 'word']
#  video_shift index 0 at 03:12 , chapter title Introduction ( index 0)
#  video_shift index 1 at 05:22 , chapter title Introduction ( index 0)
#  video_shift index 2 at 06:49 , chapter title Sets ( index 4)
#  video_shift index 3 at 08:50 , chapter title Introduction ( index 0)
#  video_shift index 4 at 11:08 , chapter title AVL Tree ( index 6)
#  video_shift index 5 at 13:24 , chapter title Heap ( index 3)
#  video_shift index 6 at 15:54 , chapter title Sorting ( index 7)
#  video_shift index 7 at 19:45 , chapter title Sorting ( index 7)
#  video_shift index 8 at 22:52 , chapter title Sorting ( index 7)
#  video_shift index 9 at 26:08 , chapter title Sorting ( index 7)
#  video_shift index 10 at 30:36 , chapter title Introduction ( index 0)
#  video_shift index 11 at 33:46 , chapter title Introduction ( index 0)
#  video_shift index 12 at 39:06 , chapter title Introduction ( index 0)
#  video_shift index 13 at 42:38 , chapter title Strings ( index 10)
#  video_shift index 14 at 45:45 , chapter title Numeric ( index 8)
#  video_shift index 15 at 50:00 , chapter title Introduction ( index 0)
#  video_shift index 16 at 52:39 , chapter title Introduction ( index 0)
#  video_shift index 17 at end , chapter title Introduction ( index 0)
# Introduction
# 30
# $$$$$$$$$$$$$$top words of video topic$$$$$$$$$$$$$$
# top words for topic 0 are ['input', 'specification', 'structure']
# top words for topic 1 are ['input', 'time', 'would']
# top words for topic 2 are ['algorithm', 'program', 'run', 'set', 'time', 'would']
# top words for topic 3 are ['algorithm', 'description', 'go', 'time', 'would']
# top words for topic 4 are ['current', 'element', 'go']
# top words for topic 5 are ['call', 'operation', 'primitive', 'return']
# top words for topic 6 are ['card', 'number', 'order', 'place']
# top words for topic 7 are ['element', 'go', 'key']
# top words for topic 8 are ['go', 'operation', 'time']
# top words for topic 9 are ['element', 'go', 'time']
# top words for topic 10 are ['average', 'bad', 'case']
# top words for topic 11 are ['constant', 'function', 'increase', 'input', 'run', 'size', 'time', 'would']
# top words for topic 12 are ['constant', 'function', 'log']
# top words for topic 13 are ['algorithm', 'may', 'number', 'run', 'time']
# top words for topic 14 are ['execute', 'step', 'time']
# top words for topic 15 are ['big', 'notation', 'number', 'time']
# top words for topic 16 are ['problem', 'say', 'size', 'time']
# top words for topic 17 are ['course', 'follow', 'go', 'lecture', 'look', 'notation', 'point', 'stop', 'today']
# $$$$$$$$$$$$$$top words of book chapters$$$$$$$$$$$$$$
# top words for topic Introduction are ['empty', 'introduction', 'section']
# top words for topic 1.1	What this book is, and what it isn’t are ['algorithm', 'base', 'book', 'implementation', 'language', 'provide', 'use']
# top words for topic 1.2	Assumed knowledge are ['assumed', 'book', 'knowledge', 'reader']
# top words for topic 1.2.1	Big Oh notation are ['big', 'notation', 'time']
# top words for topic 1.2.2	Imperative programming language are ['imperative', 'language', 'programming']
# top words for topic 1.2.3	Object oriented concepts are ['concept', 'object', 'orient']
# top words for topic 1.3	Pseudocode are ['condition', 'end', 'pre', 'type']
# top words for topic 1.4	Tips for working through the examples are ['example', 'tip', 'work']
# top words for topic 1.5	Book outline are ['chapter', 'part', 'read', 'structure']
# top words for topic 1.6	Testing are ['problem', 'test', 'testing']
# top words for topic 1.7	Where can I get the code? are ['empty', 'section']
# top words for topic 1.8	Final messages are ['final', 'message', 'work']
#  video_shift index 0 at 03:12 , chapter title 1.5	Book outline ( index 8)
#  video_shift index 1 at 05:22 , chapter title 1.2.1	Big Oh notation ( index 3)
#  video_shift index 2 at 06:49 , chapter title 1.2.1	Big Oh notation ( index 3)
#  video_shift index 3 at 08:50 , chapter title 1.2.1	Big Oh notation ( index 3)
#  video_shift index 4 at 11:08 , chapter title 1.2.2	Imperative programming language ( index 4)
#  video_shift index 5 at 13:24 , chapter title 1.3	Pseudocode ( index 6)
#  video_shift index 6 at 15:54 , chapter title 1.7	Where can I get the code? ( index 10)
#  video_shift index 7 at 19:45 , chapter title 1.7	Where can I get the code? ( index 10)
#  video_shift index 8 at 22:52 , chapter title 1.3	Pseudocode ( index 6)
#  video_shift index 9 at 26:08 , chapter title 1.3	Pseudocode ( index 6)
#  video_shift index 10 at 30:36 , chapter title 1.6	Testing ( index 9)
#  video_shift index 11 at 33:46 , chapter title 1.2.1	Big Oh notation ( index 3)
#  video_shift index 12 at 39:06 , chapter title 1.2.1	Big Oh notation ( index 3)
#  video_shift index 13 at 42:38 , chapter title 1.2.1	Big Oh notation ( index 3)
#  video_shift index 14 at 45:45 , chapter title 1.2.1	Big Oh notation ( index 3)
#  video_shift index 15 at 50:00 , chapter title 1.2.1	Big Oh notation ( index 3)
#  video_shift index 16 at 52:39 , chapter title 1.2.1	Big Oh notation ( index 3)
#  video_shift index 17 at end , chapter title 1.2.1	Big Oh notation ( index 3)
