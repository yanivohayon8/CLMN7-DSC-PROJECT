# %%
import sys
sys.path.append('..')
from src.data.docx  import read_docx,process_docx,find_content
import glob
import json
import os
import pandas as pd
import ast
import warnings
warnings.filterwarnings("ignore")
from src.models.pipeline import pipeline
from src.features.segment_transcript import CreateBlocks
from functools import reduce
import heapq
from gensim.corpora import Dictionary
from gensim import models
from gensim import similarities
import re
import statistics
import numpy as np
import seaborn as sns; sns.set()
# %matplotlib inline
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
from IPython.display import display, HTML
from scipy.stats import entropy
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # READ BOOKS OF VIDEOS

# %%
'''Defining CONSTS'''
docx_path = '../data/raw/docx'
groundbase_dir = '../data/raw/groundbase'
transcripts_dir = os.path.join(groundbase_dir,'transcripts')
topic_dataset_path = os.path.join(groundbase_dir,'dataset.csv')
transcript_filespath = glob.glob(groundbase_dir + '/transcripts/*.json')
lemmatizing_method ='lemma' #'stemm'

# %%
videos_ids = list(map(lambda fl: fl.split('\\')[-1].split('.')[0],glob.glob(docx_path + '/*')))

# %%
desired_videos =['NuY7szYSXSw','XX7ePR21Ook','h9wxtqoa1jY','GJpt_3ie4WU','bTyxpoi2dmM']#['7kLHJ-F33GI','RIawrYLVdIw','7snJ1mx1EMQ','zWg7U0OEAoE','tORLeHHtazM'] #['zWg7U0OEAoE','tORLeHHtazM'] #['7kLHJ-F33GI','RIawrYLVdIw','7snJ1mx1EMQ']
videos_ids = list(filter(lambda x: x in desired_videos,videos_ids))

# %%
#video_docx = [glob.glob(os.path.join(docx_path,vid + '/*.docx'))[0] for vid in videos_ids]
#docx_db =[read_docx(path) for path in video_docx]
videos_ids
# Out:
# ['bTyxpoi2dmM', 'GJpt_3ie4WU', 'h9wxtqoa1jY', 'NuY7szYSXSw', 'XX7ePR21Ook']

# %%
f_read = {
    'statbook':'statbook',
    'Dsa':'Dsa',
    'MIT6_042JF10_notes':'MIT6_042JF10_notes'
}

docxs_chapter_keyword = {
    'statbook':'Topic',
    'Dsa': 'Chapter',
    'MIT6_042JF10_notes':'Chapter'
}

# %%
video_to_paper = {}
paper_content ={}
for vid in videos_ids:
    doc_path = glob.glob(os.path.join(docx_path,vid + '/*.docx'))[0]
    doc_name = doc_path.split('\\')[-1].split('.')[0]
    video_to_paper[vid] = doc_name    
    if doc_name not in paper_content.keys():    
        full_text,font_sizes = read_docx(doc_path)
        paper_content[doc_name] = find_content(f_read[doc_name],
                                               full_text,
                                               font_sizes,
                                               docxs_chapter_keyword[doc_name],
                                              lemmatizing=lemmatizing_method)

# %% [markdown]
# # RESTORE RESULTS FROM TRAINING

# %%
'''Select transcript for only wanted videos'''
transcript_filespath = list(filter(lambda x: x.split('\\')[-1].split('.')[0] in videos_ids,transcript_filespath))

'''Read the transcript'''
transcripts_jsons = {}
for fl in transcript_filespath:
    with open(fl,encoding="utf8") as f:
        transcript =ast.literal_eval(f.read()) #json.load(f)
        vid = fl.split('\\')[-1].split('.')[0]
        #print(vid)
        transcripts_jsons[vid] = transcript
#print(transcripts_jsons)

'''Read the videos metadata to perform on them the segmentation'''
df_videos = pd.read_csv(topic_dataset_path)

''' Transfer topic shifts time to seconds units instead HH:MM:SS'''
def topic_shifts_seconds(topic_shifts):
    tp_shift_sec=[]
    for tp in topic_shifts:
        intervals = tp.split(':')
        seconds = int(intervals[2])
        minutes = int(intervals[1]) * 60
        hours = int(intervals[0]) * 60 *60
        tp_shift_sec.append(seconds + minutes + hours)
    return tp_shift_sec
for video_id in transcripts_jsons.keys():    
    df_videos.at[df_videos['video id'] == video_id,'topic shifts(ends)'] =\
    topic_shifts_seconds(\
                         df_videos[df_videos['video id'] == \
                                   video_id]['topic shifts(ends)'])
    

'''Get parameters from training'''
df_results = pd.read_csv('../data/processed/bayesian_opt/phrases/lemmas_adv_propn.csv')
n_largest_res = 3
pipeline_results = df_results[df_results['video'].isin(videos_ids)]\
                .groupby('video')[['video','workflow','params','max_target']]\
                .apply(lambda grp: grp.nlargest(n_largest_res,'max_target')).values.tolist()

pipeline_results = pipeline_results[:-1]#this is for zWg7U0OEAoE

    
    
    
def boundryevaluation(curresults,ground_base,accurrcy_shift = 30):
        true_positive = 0
        false_negative = 0
        false_positive = 0 
        true_positive_list_debug = []
        #false_negative_list_debug = []
        false_positive_list_debug = []
        results = curresults[:]
        
        
        #print('curresults %s' %(curresults))
        #print('ground_base %s ' %(ground_base))
        
        for grb in ground_base:
            is_false_positive = True
            for res in results:     
                if abs(res - grb) < accurrcy_shift:
                    is_false_positive = False
                    true_positive_list_debug.append(res)
                    true_positive+=1
                    results.remove(res)
                    break   
            if is_false_positive:
                false_positive_list_debug.append(grb)
                false_positive+=1
                
        #print("TP: " + str(true_positive_list_debug))
        #print("FP: " + str(false_positive_list_debug))
        #print("FN: " + str(curresults))
        #print('true_positive : %s ' %(true_positive))
        false_negative = len(results) # make sure the true positive are removed from here 
        recall_rate = true_positive/(true_positive + false_negative )
        precision_rate = true_positive/(true_positive + false_positive)
        #print("TP: %s , FP: %s, FN: %s" %(true_positive,false_positive,false_negative))
        #print("precision rate : %s, recall rate : %s " % (precision_rate,recall_rate))
        return precision_rate

# %%
videos_division = {}

for vid in videos_ids:
    vid_results = list(filter(lambda x: x[0] == vid,pipeline_results))
    max_precision = 0
    vid_words = None
    vid_shifts = None
    for result in vid_results:
        '''From the get optimized by bayesian we get that for the video '''
        vid = result[0]
        params = ast.literal_eval(result[2]) #{'n_clusters': 18, 'sim_thresh': 0.6, 'step_size': 49, 'window_size': 150}
        #print(params)
        for key in ['n_clusters','step_size','window_size']:
            params[key] = int(params[key])# - 1
        workflow = result[1] #'sliding_window-tfidf-cosine-median_(3,3)-spectral_clustering'
        
        shifts = df_videos.loc[df_videos['video id'] == vid,'topic shifts(ends)'].values.tolist()
        groundbase = shifts[:-1]
        transcripts = transcripts_jsons[vid]
        #print(grounbase)
        _pipeline = workflow.split('-')
        filter_type = None
        mask_shape = None
        filtering = _pipeline[3]
        if filtering != 'None':
            filter_type = filtering.split('_')[0]
            mask_shape = ast.literal_eval(filtering.split('_')[1])
        '''This running may not work at first time do not give up and run it couple of times'''

        '''print('Running the following %s for video %s with params %s %s %s'
              %(workflow, vid,params,filter_type,mask_shape))'''
        #print(vid_results[1])
        #print(str(filter_type) + " " + str(mask_shape))
        shift_times,topic_words = (None,None)
        n_trials = 7
        while shift_times is None and topic_words is None and n_trials > 0:
            print('##################################################')
            print("running trial %s for vid %s desired precision %s "%(n_trials,vid,result[3]))
            n_trials= n_trials - 1
            shift_times,topic_words = pipeline.run_for_baye(groundbase,
                                                            transcripts,
                                                            slicing_method='sliding_window',
                                                            window_size=params['window_size'],#59
                                                            step_size_sd= params['step_size'], #10
                                  vector_method='tfidf',vectorizing_params=None,
                                  similarity_method='cosine',
                                  filter_params={"filter_type":filter_type,
                                                 "mask_shape":mask_shape,
                                                 "sim_thresh": params['sim_thresh'], #0.5160973480326474 
                                                 "is_min_thresh":True
                                                 },
                                 clustering_params={
                                         'algorithm':'spectral_clustering',
                                         'n_clusters':params['n_clusters'] #14
                                         },
                                        accurrcy_shift=30,
                                        return_value='division') or (None,None)

            if shift_times is not None:
                pr = boundryevaluation(shift_times,groundbase,accurrcy_shift=45)
                print("output precision %s " %(pr))
                
                if pr > max_precision:
                    print("new high percision caught")
                    max_precision = pr 
                    vid_words = topic_words
                    shift_times.append('end')
                    vid_shifts = shift_times 
                if pr < result[3]:
                    shift_times,topic_words = (None,None)    

    videos_division[vid] = {'topic_words':vid_words,'topic_shift':vid_shifts}
# Out:
# ##################################################
# running trial 7 for vid bTyxpoi2dmM desired precision 0.875
# label 5 has done already cannot evaluate unsequentional segmentation, try other parameters
# Traceback (most recent call last):
#   File "..\src\models\pipeline.py", line 266, in run_for_baye
#     accurrcy_shift)
#   File "..\src\models\clustering.py", line 139, in run
#     myresults = clustering.boundery_change(clustering_results.labels_,gap_timestamp)
#   File "..\src\models\clustering.py", line 91, in boundery_change
#     raise Exception("label %s has done already cannot evaluate unsequentional segmentation, try other parameters" % (block_labeles[blk_index]))
# Exception: label 5 has done already cannot evaluate unsequentional segmentation, try other parameters
# None
# ##################################################
# running trial 6 for vid bTyxpoi2dmM desired precision 0.875
# label 13 has done already cannot evaluate unsequentional segmentation, try other parameters
# Traceback (most recent call last):
#   File "..\src\models\pipeline.py", line 266, in run_for_baye
#     accurrcy_shift)
#   File "..\src\models\clustering.py", line 139, in run
#     myresults = clustering.boundery_change(clustering_results.labels_,gap_timestamp)
#   File "..\src\models\clustering.py", line 91, in boundery_change
#     raise Exception("label %s has done already cannot evaluate unsequentional segmentation, try other parameters" % (block_labeles[blk_index]))
# Exception: label 13 has done already cannot evaluate unsequentional segmentation, try other parameters
# None
# ##################################################
# running trial 5 for vid bTyxpoi2dmM desired precision 0.875
# The results:
# [91, 264, 418, 613, 764, 913, 1069, 1252, 1457, 1647, 1802, 1941, 2100, 2269, 2473, 2611, 2803, 3000, 3130, 3233, 3387, 3569, 3662, 3876, 4187, 4506, 4674, 4853]
# The ground base:
# [90, 360, 665, 885, 985, 1620, 2233, 3220]
# output precision 0.625
# new high percision caught
# ##################################################
# running trial 4 for vid bTyxpoi2dmM desired precision 0.875
# The results:
# [91, 279, 433, 613, 764, 913, 1083, 1396, 1562, 1722, 1914, 2086, 2288, 2473, 2632, 2829, 3028, 3147, 3246, 3355, 3465, 3647, 3861, 4009, 4271, 4593, 4764, 4989]
# The ground base:
# [90, 360, 665, 885, 985, 1620, 2233, 3220]
# output precision 0.375
# ##################################################
# running trial 3 for vid bTyxpoi2dmM desired precision 0.875
# label 6 has done already cannot evaluate unsequentional segmentation, try other parameters
# Traceback (most recent call last):
#   File "..\src\models\pipeline.py", line 266, in run_for_baye
#     accurrcy_shift)
#   File "..\src\models\clustering.py", line 139, in run
#     myresults = clustering.boundery_change(clustering_results.labels_,gap_timestamp)
#   File "..\src\models\clustering.py", line 91, in boundery_change
#     raise Exception("label %s has done already cannot evaluate unsequentional segmentation, try other parameters" % (block_labeles[blk_index]))
# Exception: label 6 has done already cannot evaluate unsequentional segmentation, try other parameters
# None
# ##################################################
# running trial 2 for vid bTyxpoi2dmM desired precision 0.875
# label 2 has done already cannot evaluate unsequentional segmentation, try other parameters
# Traceback (most recent call last):
#   File "..\src\models\pipeline.py", line 266, in run_for_baye
#     accurrcy_shift)
#   File "..\src\models\clustering.py", line 139, in run
#     myresults = clustering.boundery_change(clustering_results.labels_,gap_timestamp)
#   File "..\src\models\clustering.py", line 91, in boundery_change
#     raise Exception("label %s has done already cannot evaluate unsequentional segmentation, try other parameters" % (block_labeles[blk_index]))
# Exception: label 2 has done already cannot evaluate unsequentional segmentation, try other parameters
# None
# ##################################################
# running trial 1 for vid bTyxpoi2dmM desired precision 0.875
# label 7 has done already cannot evaluate unsequentional segmentation, try other parameters
# Traceback (most recent call last):
#   File "..\src\models\pipeline.py", line 266, in run_for_baye
#     accurrcy_shift)
#   File "..\src\models\clustering.py", line 139, in run
#     myresults = clustering.boundery_change(clustering_results.labels_,gap_timestamp)
#   File "..\src\models\clustering.py", line 91, in boundery_change
#     raise Exception("label %s has done already cannot evaluate unsequentional segmentation, try other parameters" % (block_labeles[blk_index]))
# Exception: label 7 has done already cannot evaluate unsequentional segmentation, try other parameters
# None
# ##################################################
# running trial 7 for vid bTyxpoi2dmM desired precision 0.75
# The results:
# [113, 190, 332, 433, 633, 840, 1011, 1265, 1467, 1638, 1733, 1873, 2052, 2204, 2358, 2538, 2711, 2889, 3088, 3240, 3437, 3608, 3796, 4109, 4382, 4610, 4984]
# The ground base:
# [90, 360, 665, 885, 985, 1620, 2233, 3220]
# output precision 0.875
# new high percision caught
# ##################################################
# running trial 7 for vid bTyxpoi2dmM desired precision 0.75
# The results:
# [95, 294, 462, 628, 796, 927, 1061, 1256, 1429, 1621, 1795, 1932, 2103, 2292, 2514, 2680, 2836, 3077, 3169, 3261, 3440, 3652, 3854, 4014, 4187, 4561, 4737, 4973]
# The ground base:
# [90, 360, 665, 885, 985, 1620, 2233, 3220]
# output precision 0.625
# ##################################################
# running trial 6 for vid bTyxpoi2dmM desired precision 0.75
# The results:
# [95, 294, 462, 628, 796, 927, 1061, 1256, 1429, 1656, 1795, 1932, 2103, 2292, 2514, 2680, 2878, 3077, 3203, 3342, 3477, 3610, 3854, 4014, 4187, 4561, 4772, 4973]
# The ground base:
# [90, 360, 665, 885, 985, 1620, 2233, 3220]
# output precision 0.625
# ##################################################
# running trial 5 for vid bTyxpoi2dmM desired precision 0.75
# The results:
# [95, 294, 439, 628, 770, 905, 1061, 1256, 1429, 1621, 1795, 1932, 2103, 2292, 2514, 2707, 2878, 3077, 3232, 3381, 3477, 3610, 3783, 4014, 4187, 4561, 4772, 4973]
# The ground base:
# [90, 360, 665, 885, 985, 1620, 2233, 3220]
# output precision 0.625
# ##################################################
# running trial 4 for vid bTyxpoi2dmM desired precision 0.75
# The results:
# [95, 273, 365, 532, 628, 796, 927, 1084, 1256, 1429, 1656, 1795, 1932, 2103, 2259, 2514, 2648, 2836, 3077, 3232, 3412, 3610, 3783, 4014, 4187, 4561, 4772, 4973]
# The ground base:
# [90, 360, 665, 885, 985, 1620, 2233, 3220]
# output precision 0.875
# ##################################################
# running trial 7 for vid GJpt_3ie4WU desired precision 1.0
# The results:
# [128, 298, 475, 738, 892, 1002, 1119, 1262, 1407, 1526, 1698, 1919, 2166, 2393, 2545, 2713, 2811, 2933, 3095, 3350, 3599, 3817, 4073, 4235, 4391, 4605, 4821]
# The ground base:
# [324, 733, 855, 1015, 1135, 1820, 2673]
# output precision 0.8571428571428571
# new high percision caught
# ##################################################
# running trial 6 for vid GJpt_3ie4WU desired precision 1.0
# The results:
# [160, 339, 738, 892, 1055, 1206, 1354, 1526, 1698, 1854, 2092, 2333, 2434, 2650, 2713, 2875, 3060, 3350, 3556, 3757, 4024, 4127, 4235, 4337, 4452, 4605, 4767]
# The ground base:
# [324, 733, 855, 1015, 1135, 1820, 2673]
# output precision 0.8571428571428571
# ##################################################
# running trial 5 for vid GJpt_3ie4WU desired precision 1.0
# The results:
# [128, 298, 475, 738, 892, 1055, 1206, 1354, 1526, 1698, 1854, 2092, 2236, 2393, 2650, 2811, 3002, 3095, 3350, 3556, 3757, 3909, 4073, 4235, 4337, 4605, 4821]
# The ground base:
# [324, 733, 855, 1015, 1135, 1820, 2673]
# output precision 0.8571428571428571
# ##################################################
# running trial 4 for vid GJpt_3ie4WU desired precision 1.0
# The results:
# [128, 339, 678, 832, 1055, 1206, 1354, 1464, 1644, 1854, 2033, 2236, 2434, 2650, 2713, 2811, 2933, 3095, 3350, 3493, 3599, 3817, 4073, 4235, 4337, 4605, 4821]
# The ground base:
# [324, 733, 855, 1015, 1135, 1820, 2673]
# output precision 0.7142857142857143
# ##################################################
# running trial 3 for vid GJpt_3ie4WU desired precision 1.0
# The results:
# [160, 298, 475, 599, 790, 955, 1055, 1161, 1306, 1464, 1644, 1854, 2092, 2333, 2434, 2713, 2875, 3060, 3350, 3599, 3817, 3909, 4073, 4235, 4391, 4605, 4821]
# The ground base:
# [324, 733, 855, 1015, 1135, 1820, 2673]
# output precision 0.7142857142857143
# ##################################################
# running trial 2 for vid GJpt_3ie4WU desired precision 1.0
# The results:
# [128, 298, 475, 738, 892, 1055, 1206, 1354, 1526, 1698, 1854, 2092, 2333, 2490, 2650, 2811, 3002, 3167, 3350, 3556, 3757, 3909, 4024, 4180, 4337, 4496, 4706]
# The ground base:
# [324, 733, 855, 1015, 1135, 1820, 2673]
# output precision 0.8571428571428571
# ##################################################
# running trial 1 for vid GJpt_3ie4WU desired precision 1.0
# The results:
# [160, 339, 599, 790, 1002, 1161, 1306, 1464, 1698, 1854, 1979, 2166, 2393, 2545, 2713, 2811, 3002, 3095, 3350, 3599, 3817, 3976, 4127, 4235, 4391, 4605, 4821]
# The ground base:
# [324, 733, 855, 1015, 1135, 1820, 2673]
# output precision 0.7142857142857143
# ##################################################
# running trial 7 for vid GJpt_3ie4WU desired precision 0.7142857142857143
# The results:
# [160, 385, 738, 892, 1055, 1206, 1354, 1464, 1644, 1854, 2092, 2393, 2587, 2761, 2875, 3060, 3350, 3556, 3817, 4024, 4180, 4337, 4552, 4767]
# The ground base:
# [324, 733, 855, 1015, 1135, 1820, 2673]
# output precision 0.5714285714285714
# ##################################################
# running trial 6 for vid GJpt_3ie4WU desired precision 0.7142857142857143
# The results:
# [128, 339, 738, 955, 1161, 1354, 1526, 1644, 1854, 2092, 2333, 2545, 2713, 2875, 3095, 3350, 3556, 3817, 3976, 4073, 4180, 4337, 4605, 4821]
# The ground base:
# [324, 733, 855, 1015, 1135, 1820, 2673]
# output precision 0.7142857142857143
# ##################################################
# running trial 7 for vid GJpt_3ie4WU desired precision 0.7142857142857143
# The results:
# [117, 308, 669, 840, 1013, 1168, 1322, 1397, 1475, 1657, 1838, 2072, 2377, 2610, 2733, 2863, 3042, 3293, 3386, 3537, 3692, 3802, 4014, 4163, 4351, 4539, 4721, 4999]
# The ground base:
# [324, 733, 855, 1015, 1135, 1820, 2673]
# output precision 0.7142857142857143
# ##################################################
# running trial 7 for vid h9wxtqoa1jY desired precision 0.8
# The results:
# [116, 298, 507, 720, 953, 1152, 1517, 1692, 1905, 2133, 2263, 2407, 2575, 2805, 2991, 3154, 3371, 3675, 3929, 4158, 4409, 4620, 4797, 4958]
# The ground base:
# [509, 720, 767, 980, 1660, 1980, 2570, 2980, 4560, 4662]
# output precision 0.7
# new high percision caught
# ##################################################
# running trial 6 for vid h9wxtqoa1jY desired precision 0.8
# The results:
# [116, 283, 507, 720, 953, 1152, 1517, 1692, 1905, 2133, 2271, 2414, 2575, 2818, 2991, 3144, 3358, 3675, 3929, 4180, 4409, 4620, 4797, 4958]
# The ground base:
# [509, 720, 767, 980, 1660, 1980, 2570, 2980, 4560, 4662]
# output precision 0.7
# ##################################################
# running trial 5 for vid h9wxtqoa1jY desired precision 0.8
# The results:
# [116, 298, 507, 696, 953, 1152, 1536, 1692, 1929, 2151, 2271, 2414, 2575, 2818, 2991, 3154, 3358, 3675, 3929, 4180, 4409, 4620, 4797, 4958]
# The ground base:
# [509, 720, 767, 980, 1660, 1980, 2570, 2980, 4560, 4662]
# output precision 0.7
# ##################################################
# running trial 4 for vid h9wxtqoa1jY desired precision 0.8
# The results:
# [116, 283, 507, 696, 953, 1152, 1536, 1692, 1905, 2133, 2263, 2407, 2561, 2805, 2991, 3154, 3371, 3675, 3929, 4180, 4409, 4620, 4797, 4958]
# The ground base:
# [509, 720, 767, 980, 1660, 1980, 2570, 2980, 4560, 4662]
# output precision 0.7
# ##################################################
# running trial 3 for vid h9wxtqoa1jY desired precision 0.8
# The results:
# [127, 298, 507, 696, 953, 1152, 1517, 1692, 1905, 2133, 2263, 2407, 2575, 2805, 2991, 3154, 3371, 3675, 3929, 4180, 4409, 4620, 4797, 4958]
# The ground base:
# [509, 720, 767, 980, 1660, 1980, 2570, 2980, 4560, 4662]
# output precision 0.7
# ##################################################
# running trial 2 for vid h9wxtqoa1jY desired precision 0.8
# The results:
# [116, 283, 507, 720, 953, 1168, 1536, 1692, 1905, 2133, 2263, 2407, 2575, 2818, 2991, 3144, 3358, 3675, 3918, 4144, 4409, 4620, 4797, 4958]
# The ground base:
# [509, 720, 767, 980, 1660, 1980, 2570, 2980, 4560, 4662]
# output precision 0.7
# ##################################################
# running trial 1 for vid h9wxtqoa1jY desired precision 0.8
# The results:
# [116, 298, 507, 720, 953, 1168, 1536, 1692, 1905, 2133, 2271, 2414, 2575, 2818, 2991, 3154, 3371, 3675, 3929, 4144, 4409, 4620, 4797, 4958]
# The ground base:
# [509, 720, 767, 980, 1660, 1980, 2570, 2980, 4560, 4662]
# output precision 0.7
# ##################################################
# running trial 7 for vid h9wxtqoa1jY desired precision 0.8
# The results:
# [116, 303, 492, 720, 967, 1163, 1537, 1701, 1949, 2234, 2407, 2579, 2810, 2997, 3146, 3354, 3672, 3933, 4180, 4413, 4623, 4795]
# The ground base:
# [509, 720, 767, 980, 1660, 1980, 2570, 2980, 4560, 4662]
# output precision 0.8
# new high percision caught
# ##################################################
# running trial 7 for vid NuY7szYSXSw desired precision 0.875
# The results:
# [163, 244, 348, 479, 624, 791, 987, 1178, 1311, 1510, 1716, 1843, 1994, 2157, 2253, 2422, 2557, 2710, 2936, 3093, 3301, 3507, 3655, 3979, 4164, 4348, 4571, 4810]
# The ground base:
# [520, 590, 1835, 2028, 2090, 2570, 3470, 4320]
# output precision 0.875
# new high percision caught
# ##################################################
# running trial 7 for vid NuY7szYSXSw desired precision 0.875
# label 22 has done already cannot evaluate unsequentional segmentation, try other parameters
# Traceback (most recent call last):
#   File "..\src\models\pipeline.py", line 266, in run_for_baye
#     accurrcy_shift)
#   File "..\src\models\clustering.py", line 139, in run
#     myresults = clustering.boundery_change(clustering_results.labels_,gap_timestamp)
#   File "..\src\models\clustering.py", line 91, in boundery_change
#     raise Exception("label %s has done already cannot evaluate unsequentional segmentation, try other parameters" % (block_labeles[blk_index]))
# Exception: label 22 has done already cannot evaluate unsequentional segmentation, try other parameters
# None
# ##################################################
# running trial 6 for vid NuY7szYSXSw desired precision 0.875
# The results:
# [189, 291, 450, 540, 756, 924, 1136, 1292, 1464, 1688, 1956, 2123, 2270, 2480, 2664, 2827, 2994, 3037, 3240, 3377, 3509, 3620, 3811, 4103, 4297, 4466, 4811]
# The ground base:
# [520, 590, 1835, 2028, 2090, 2570, 3470, 4320]
# output precision 0.5
# ##################################################
# running trial 5 for vid NuY7szYSXSw desired precision 0.875
# label 25 has done already cannot evaluate unsequentional segmentation, try other parameters
# Traceback (most recent call last):
#   File "..\src\models\pipeline.py", line 266, in run_for_baye
#     accurrcy_shift)
#   File "..\src\models\clustering.py", line 139, in run
#     myresults = clustering.boundery_change(clustering_results.labels_,gap_timestamp)
#   File "..\src\models\clustering.py", line 91, in boundery_change
#     raise Exception("label %s has done already cannot evaluate unsequentional segmentation, try other parameters" % (block_labeles[blk_index]))
# Exception: label 25 has done already cannot evaluate unsequentional segmentation, try other parameters
# None
# ##################################################
# running trial 4 for vid NuY7szYSXSw desired precision 0.875
# The results:
# [101, 189, 291, 373, 496, 647, 811, 1034, 1251, 1464, 1688, 1827, 2001, 2174, 2327, 2537, 2664, 2886, 3037, 3331, 3509, 3748, 4062, 4103, 4297, 4466, 4811]
# The ground base:
# [520, 590, 1835, 2028, 2090, 2570, 3470, 4320]
# output precision 0.75
# ##################################################
# running trial 3 for vid NuY7szYSXSw desired precision 0.875
# label 10 has done already cannot evaluate unsequentional segmentation, try other parameters
# Traceback (most recent call last):
#   File "..\src\models\pipeline.py", line 266, in run_for_baye
#     accurrcy_shift)
#   File "..\src\models\clustering.py", line 139, in run
#     myresults = clustering.boundery_change(clustering_results.labels_,gap_timestamp)
#   File "..\src\models\clustering.py", line 91, in boundery_change
#     raise Exception("label %s has done already cannot evaluate unsequentional segmentation, try other parameters" % (block_labeles[blk_index]))
# Exception: label 10 has done already cannot evaluate unsequentional segmentation, try other parameters
# None
# ##################################################
# running trial 2 for vid NuY7szYSXSw desired precision 0.875
# label 27 has done already cannot evaluate unsequentional segmentation, try other parameters
# Traceback (most recent call last):
#   File "..\src\models\pipeline.py", line 266, in run_for_baye
#     accurrcy_shift)
#   File "..\src\models\clustering.py", line 139, in run
#     myresults = clustering.boundery_change(clustering_results.labels_,gap_timestamp)
#   File "..\src\models\clustering.py", line 91, in boundery_change
#     raise Exception("label %s has done already cannot evaluate unsequentional segmentation, try other parameters" % (block_labeles[blk_index]))
# Exception: label 27 has done already cannot evaluate unsequentional segmentation, try other parameters
# None
# ##################################################
# running trial 1 for vid NuY7szYSXSw desired precision 0.875
# The results:
# [189, 251, 341, 450, 540, 703, 868, 1088, 1251, 1406, 1562, 1688, 1900, 2042, 2222, 2327, 2537, 2664, 2886, 3037, 3240, 3331, 3509, 3748, 4062, 4466, 4811]
# The ground base:
# [520, 590, 1835, 2028, 2090, 2570, 3470, 4320]
# output precision 0.5
# ##################################################
# running trial 7 for vid NuY7szYSXSw desired precision 0.75
# The results:
# [145, 248, 369, 505, 697, 880, 1132, 1271, 1473, 1697, 1870, 2041, 2219, 2380, 2506, 2659, 2952, 3105, 3310, 3492, 3680, 4073, 4332, 4514, 4814]
# The ground base:
# [520, 590, 1835, 2028, 2090, 2570, 3470, 4320]
# output precision 0.625
# ##################################################
# running trial 6 for vid NuY7szYSXSw desired precision 0.75
# The results:
# [158, 248, 369, 505, 659, 864, 1113, 1271, 1491, 1708, 1893, 2041, 2232, 2473, 2673, 2952, 3105, 3310, 3505, 3680, 3949, 4087, 4346, 4606, 4814]
# The ground base:
# [520, 590, 1835, 2028, 2090, 2570, 3470, 4320]
# output precision 0.5
# ##################################################
# running trial 5 for vid NuY7szYSXSw desired precision 0.75
# The results:
# [145, 248, 357, 505, 659, 864, 1113, 1271, 1473, 1726, 1916, 2052, 2232, 2456, 2659, 2952, 3105, 3310, 3505, 3680, 4073, 4315, 4450, 4624, 4814]
# The ground base:
# [520, 590, 1835, 2028, 2090, 2570, 3470, 4320]
# output precision 0.5
# ##################################################
# running trial 4 for vid NuY7szYSXSw desired precision 0.75
# The results:
# [145, 248, 369, 505, 680, 864, 1132, 1287, 1506, 1737, 1965, 2113, 2232, 2380, 2531, 2686, 2952, 3105, 3310, 3505, 3680, 4087, 4346, 4606, 4814]
# The ground base:
# [520, 590, 1835, 2028, 2090, 2570, 3470, 4320]
# output precision 0.625
# ##################################################
# running trial 3 for vid NuY7szYSXSw desired precision 0.75
# The results:
# [158, 248, 369, 505, 697, 880, 1132, 1271, 1473, 1708, 1893, 2041, 2232, 2434, 2612, 2861, 3019, 3137, 3310, 3505, 3680, 4087, 4346, 4606, 4814]
# The ground base:
# [520, 590, 1835, 2028, 2090, 2570, 3470, 4320]
# output precision 0.625
# ##################################################
# running trial 2 for vid NuY7szYSXSw desired precision 0.75
# The results:
# [145, 241, 325, 429, 520, 731, 1063, 1271, 1506, 1726, 1916, 2052, 2219, 2380, 2531, 2686, 2952, 3105, 3310, 3505, 3680, 4087, 4346, 4606, 4814]
# The ground base:
# [520, 590, 1835, 2028, 2090, 2570, 3470, 4320]
# output precision 0.625
# ##################################################
# running trial 1 for vid NuY7szYSXSw desired precision 0.75
# The results:
# [170, 288, 413, 520, 680, 864, 1113, 1271, 1506, 1726, 1893, 2010, 2195, 2365, 2506, 2659, 2952, 3124, 3328, 3492, 3680, 4073, 4332, 4503, 4814]
# The ground base:
# [520, 590, 1835, 2028, 2090, 2570, 3470, 4320]
# output precision 0.5
# ##################################################
# running trial 7 for vid XX7ePR21Ook desired precision 0.8
# The results:
# [109, 259, 376, 506, 702, 804, 988, 1187, 1387, 1508, 1667, 1820, 1972, 2092, 2316, 2492, 2688, 2848, 3096, 3372, 3592, 3718, 3861, 4033, 4153, 4359, 4547, 4714]
# The ground base:
# [300, 552, 665, 825, 945, 1072, 1535, 1920, 3570, 3810]
# output precision 0.6
# new high percision caught
# ##################################################
# running trial 6 for vid XX7ePR21Ook desired precision 0.8
# The results:
# [109, 185, 259, 376, 472, 614, 747, 885, 1086, 1317, 1469, 1635, 1791, 1960, 2092, 2280, 2476, 2711, 2975, 3225, 3438, 3613, 3738, 3972, 4087, 4344, 4547, 4714]
# The ground base:
# [300, 552, 665, 825, 945, 1072, 1535, 1920, 3570, 3810]
# output precision 0.4
# ##################################################
# running trial 5 for vid XX7ePR21Ook desired precision 0.8
# The results:
# [109, 185, 271, 388, 506, 702, 804, 988, 1221, 1450, 1614, 1791, 1941, 2067, 2296, 2476, 2628, 2742, 2975, 3225, 3453, 3650, 3757, 3987, 4131, 4359, 4559, 4714]
# The ground base:
# [300, 552, 665, 825, 945, 1072, 1535, 1920, 3570, 3810]
# output precision 0.5
# ##################################################
# running trial 4 for vid XX7ePR21Ook desired precision 0.8
# The results:
# [109, 172, 259, 388, 506, 664, 747, 817, 988, 1187, 1405, 1577, 1778, 1972, 2146, 2336, 2492, 2688, 2836, 3074, 3372, 3592, 3718, 3945, 4076, 4359, 4559, 4714]
# The ground base:
# [300, 552, 665, 825, 945, 1072, 1535, 1920, 3570, 3810]
# output precision 0.6
# ##################################################
# running trial 3 for vid XX7ePR21Ook desired precision 0.8
# The results:
# [109, 185, 259, 376, 494, 675, 804, 988, 1101, 1340, 1480, 1667, 1820, 1960, 2067, 2247, 2412, 2646, 2848, 3096, 3386, 3592, 3718, 3907, 4076, 4359, 4559, 4714]
# The ground base:
# [300, 552, 665, 825, 945, 1072, 1535, 1920, 3570, 3810]
# output precision 0.7
# new high percision caught
# ##################################################
# running trial 2 for vid XX7ePR21Ook desired precision 0.8
# The results:
# [124, 259, 388, 520, 702, 804, 917, 1086, 1340, 1480, 1635, 1805, 1960, 2092, 2247, 2394, 2628, 2822, 3074, 3386, 3613, 3718, 3861, 4033, 4131, 4359, 4547, 4714]
# The ground base:
# [300, 552, 665, 825, 945, 1072, 1535, 1920, 3570, 3810]
# output precision 0.8
# new high percision caught
# ##################################################
# running trial 7 for vid XX7ePR21Ook desired precision 0.8
# The results:
# [125, 260, 390, 523, 676, 792, 933, 1132, 1321, 1470, 1618, 1780, 1962, 2121, 2364, 2581, 2763, 2960, 3132, 3375, 3558, 3696, 3813, 4007, 4195, 4434, 4582]
# The ground base:
# [300, 552, 665, 825, 945, 1072, 1535, 1920, 3570, 3810]
# output precision 0.8
# ##################################################
# running trial 7 for vid XX7ePR21Ook desired precision 0.8
# The results:
# [155, 283, 436, 678, 802, 1003, 1248, 1495, 1719, 1903, 2015, 2227, 2432, 2666, 2876, 3112, 3387, 3574, 3739, 3908, 4074, 4319, 4521, 4588, 4714]
# The ground base:
# [300, 552, 665, 825, 945, 1072, 1535, 1920, 3570, 3810]
# output precision 0.6
# ##################################################
# running trial 6 for vid XX7ePR21Ook desired precision 0.8
# The results:
# [171, 283, 436, 678, 802, 963, 1155, 1372, 1537, 1747, 1919, 2057, 2318, 2530, 2730, 2955, 3207, 3387, 3595, 3739, 3908, 4074, 4355, 4570, 4714]
# The ground base:
# [300, 552, 665, 825, 945, 1072, 1535, 1920, 3570, 3810]
# output precision 0.7
# ##################################################
# running trial 5 for vid XX7ePR21Ook desired precision 0.8
# The results:
# [145, 269, 436, 678, 820, 1003, 1323, 1511, 1719, 1874, 2002, 2190, 2318, 2472, 2715, 2898, 3089, 3371, 3574, 3719, 3883, 4074, 4355, 4570, 4714]
# The ground base:
# [300, 552, 665, 825, 945, 1072, 1535, 1920, 3570, 3810]
# output precision 0.5
# ##################################################
# running trial 4 for vid XX7ePR21Ook desired precision 0.8
# The results:
# [171, 283, 436, 678, 802, 963, 1188, 1421, 1556, 1747, 1903, 2026, 2278, 2472, 2715, 2939, 3112, 3371, 3574, 3719, 3883, 4074, 4334, 4550, 4714]
# The ground base:
# [300, 552, 665, 825, 945, 1072, 1535, 1920, 3570, 3810]
# output precision 0.7
# ##################################################
# running trial 3 for vid XX7ePR21Ook desired precision 0.8
# The results:
# [145, 283, 454, 678, 802, 963, 1172, 1372, 1525, 1747, 1919, 2057, 2296, 2472, 2715, 2955, 3207, 3427, 3609, 3739, 3908, 4074, 4355, 4570, 4714]
# The ground base:
# [300, 552, 665, 825, 945, 1072, 1535, 1920, 3570, 3810]
# output precision 0.7
# ##################################################
# running trial 2 for vid XX7ePR21Ook desired precision 0.8
# The results:
# [145, 269, 436, 678, 820, 1003, 1203, 1435, 1651, 1826, 1990, 2190, 2318, 2457, 2666, 2850, 3089, 3371, 3574, 3719, 3883, 4074, 4319, 4550, 4714]
# The ground base:
# [300, 552, 665, 825, 945, 1072, 1535, 1920, 3570, 3810]
# output precision 0.4
# ##################################################
# running trial 1 for vid XX7ePR21Ook desired precision 0.8
# The results:
# [145, 269, 436, 661, 802, 963, 1188, 1407, 1537, 1719, 1874, 2015, 2227, 2432, 2666, 2850, 3089, 3371, 3574, 3719, 3883, 4074, 4319, 4570, 4714]
# The ground base:
# [300, 552, 665, 825, 945, 1072, 1535, 1920, 3570, 3810]
# output precision 0.6

# %%
#videos_division

# %% [markdown]
# # EXTRACT MAIN CHAPTERS OF BOOKS AND ORAGANIZE THE PAPER AS DIFFERENT DOCUMENTS GROUPS

# %%
'''Regex to identify '''
p_firstsubsection = re.compile(r'((\d+\.)+\d*\t[A-Za-z0-9? ]+)')

# %%
'''Find the following for each paper:
    1) main chapter title index. for example [10,15....]
    2) range of subsection within each main chapter . for example [(0,9),(11,14)...]
    
    '''

#paper_mainchapter_indexes = {}
paper_sec_within_main_indexes = {}
main_section_as_one_doc = {}
paper_subsec_as_one_doc = {}
first_dep_section_as_one_doc = {}

def get_sub_titles(all_titles,main_tl_indexes):
    subsec_mainchapter_indexes = [range(main_tl_indexes[index],main_tl_indexes[index + 1])
                                  for index in range(len(main_tl_indexes) - 1)]
    subsec_mainchapter_indexes.append(range(main_tl_indexes[-1],len(all_titles)))
    return subsec_mainchapter_indexes


for doc_name in paper_content.keys():
    '''
        first element array of subtitles by dividing based on main chapters like 4 number theory
        second element array of subtitles by dividing based on main first hierarchy depth titles like 4.1 simple graph 
    '''
    titles_by_hierchy_ranges = [] 
    titles_by_hierchy_indexes = []
    
    '''Find the main chapter indexes in the list of the overall titles'''
    '''Titles like 4 Number theory or 5 Graphs'''
    mainchapter_indexes = [paper_content[doc_name]['titles'].index(ch_title)
                           for ch_title in paper_content[doc_name]['main titles']]
    titles_by_hierchy_indexes.append(mainchapter_indexes)
    
    '''
        Find the indexes of the first depth subsection
        for example 4.1 simple graphs
    '''
    tl_first_dep_by_hier_indexes = [i for i,tl in enumerate(paper_content['MIT6_042JF10_notes']['titles'])
     if re.match(r'(^([0-9]+\.[0-9]*)$)',tl) is not None or
     re.match(r'[0-9]+\.[0-9]*\s+',tl) is not None]
    
    titles_by_hierchy_indexes.append(tl_first_dep_by_hier_indexes)
    
    tl_first_dep_by_hier = [tl for i,tl in enumerate(paper_content['MIT6_042JF10_notes']['titles'])
     if re.match(r'(^([0-9]+\.[0-9]*)$)',tl) is not None or
     re.match(r'[0-9]+\.[0-9]*\s+',tl) is not None]
    
    '''Adding the indexes of the first dep subsections to the main indexes'''
    '''For example the fourth place will contains the indexes of the titles: 4.1,4.2,4.3'''
    top_maintitle_ranges = []

    for index in range(len(mainchapter_indexes) - 1):
        j = mainchapter_indexes[index]
        range_j = []
        while j < mainchapter_indexes[index + 1]:
            '''If this title is from the shape like 4.1 or 4.2'''
            curr_tl = paper_content['MIT6_042JF10_notes']['titles'][j]
            if j in tl_first_dep_by_hier_indexes:
                range_j.append(tl_first_dep_by_hier.index(curr_tl))
            j+=1
        top_maintitle_ranges.append(range_j)
    '''Adding the last one'''
    j = mainchapter_indexes[-1]
    range_j = []
    while j < len(paper_content[doc_name]['titles']):
        curr_tl = paper_content['MIT6_042JF10_notes']['titles'][j]
        if j in tl_first_dep_by_hier_indexes:
            range_j.append(tl_first_dep_by_hier.index(curr_tl))
        j+=1
    top_maintitle_ranges.append(range_j)
        
    titles_by_hierchy_ranges.append(top_maintitle_ranges)
    
    '''adding the ranges of the subtitles of the first depth of each '''
    '''like for example for title 4.1 the range will be the indexes of the titles
        4.1.1,4.1.2 etc'''
    titles_by_hierchy_ranges.append(get_sub_titles(paper_content[doc_name]['titles'],
                                                             titles_by_hierchy_indexes[1]))
    
    
    '''Making each chapter as a one documents'''
    
    '''Union all the documents in a atomic section into single document'''
    paper_subsec_as_one_doc[doc_name] = [list(reduce(lambda doc,acc:doc + acc,sec,[]))
                                         for sec in paper_content[doc_name]['corpus']]
    
    
    '''Sections are like 4.1 simple graph'''
    first_dep_section_as_one_doc[doc_name] = [list(reduce(lambda acc,s_i:
                                                   paper_subsec_as_one_doc[doc_name][s_i]+acc,
                                                    subsec_indexes,[]))
                                        for subsec_indexes in titles_by_hierchy_ranges[1]]

    
    '''Union all the sub section in a main chapter into one document'''
    '''sections are like 4 Number theory'''
    main_section_as_one_doc[doc_name] = [list(reduce(lambda acc,s_i:
                                                   first_dep_section_as_one_doc[doc_name][s_i]+acc,
                                                    subsec_indexes,[]))
                                        for subsec_indexes in titles_by_hierchy_ranges[0]]

# %%
#paper_subsec_as_one_doc['statbook'][0]

# %%
#print(len(paper_content['MIT6_042JF10_notes']['titles']))
#print(len(paper_content['MIT6_042JF10_notes']['corpus']))
##print(len(paper_content['MIT6_042JF10_notes']['main titles']))
#print(len(main_section_as_one_doc['MIT6_042JF10_notes']))
print((titles_by_hierchy_ranges[0][5]))
print(len(titles_by_hierchy_ranges[0]))
print(len(first_dep_section_as_one_doc['MIT6_042JF10_notes']))
print(len(titles_by_hierchy_ranges[1]))
print(len(main_section_as_one_doc['MIT6_042JF10_notes']))
print(len(paper_content['MIT6_042JF10_notes']['main titles']))
#print(titles_by_hierchy_ranges[0][-1])
#print(tl_first_dep_by_hier)
print(tl_first_dep_by_hier[18])
print(first_dep_section_as_one_doc['MIT6_042JF10_notes'][18])
# Out:
# [33, 34, 35]
# 20
# 110
# 110
# 20
# 20
# 4.2 The Greatest Common Divisor
# ['pulverizer', 'unfortunately', 'proof', 'nonconstructive', 'suggest', 'way', 'find', 'job', 'tackle', 'mathematical', 'tool', 'date', 'sixth', 'century', 'india', 'call', 'kuttak', 'mean', 'pulverizer', 'today', 'pul', 'verizer', 'commonly', 'know', 'extended', 'euclidean', 'gcd', 'algorithm', 'close', 'euclid', 'algorithm', 'example', 'compute', 'gcd', 'follow', 'gcd', 'gcd', 'gcd', 'rem', 'rem', 'rem', 'rem', 'begin', 'initialize', 'variable', 'first', 'column', 'carry', 'euclid', 'algorithm', 'step', 'compute', 'rem', 'write', 'form', 'remember', 'division', 'algorithm', 'say', 'remainder', 'rearranging', 'term', 'replace', 'equation', 'equivalent', 'linear', 'combina', 'tion', 'already', 'compute', 'simplify', 'left', 'chapter_number', 'theory', 'linear_combination', 'equal', 'remainder', 'desire', 'solution', 'water_jug', 'problem', 'corollary', 'say', 'write', 'linear_combination', 'multiple', 'gcd', 'word', 'exist', 'integer', 'know', 'coefficient', 'know', 'exist', 'coefficient', 'could', 'positive', 'negative', 'however', 'readily', 'transform', 'linear_combination', 'equivalent', 'linear_combination', 'coefficient', 'end', 'process', 'must', 'empty', 'gallon', 'jug', 'exactly', 'jt', 'times', 'take', 'time', 'equation', 'remarkably', 'even', 'need', 'know', 'coefficient', 'chapter_number', 'theory', 'euclid', 'algorithm', 'chapter_number', 'theory', 'process', 'call', 'euclid', 'algorithm', 'discover', 'greeks', 'year_ago', 'prove', 'algorithm', 'always', 'eventually', 'terminate', 'use_induction', 'fact', 'number_step', 'keep', 'get', 'small', 'remainder', 'whereupon', 'compute', 'gcd', 'fact', 'number', 'get', 'small', 'quickly', 'least', 'factor', 'step', 'eul', 'algorithm', 'quite', 'fast', 'fact', 'euclid', 'algorithm', 'actually', 'produce', 'gcd', 'different', 'also', 'prove', 'inductive', 'invariant', 'argument', 'calculation', 'gcd', 'together', 'corollary', 'imply', 'way', 'measure', 'gallon', 'water', 'use', 'jug', 'capacity', 'obtain', 'multiple', 'gallon', 'jug', 'good_news', 'bruce', 'even', 'survive', 'die_hard', 'property', 'greatest', 'common_divisor', 'lemma', 'follow', 'statement', 'greatest', 'common_divisor', 'hold', 'leave_side', 'rewrite', 'asu', 'btu', 'csv', 'bc', 'tv', 'linear_combination', 'bc', 'equal', 'gcd', 'bc', 'theorem', 'proof', 'say', 'gcd', 'bc', 'equal', 'linear_combination', 'bc', 'ac', 'trivially', 'bc', 'assumption', 'therefore', 'divide', 'linear_combination', 'bc', 'particular', 'divide', 'gcd', 'bc', 'gcd', 'first', 'equality', 'use', 'part', 'linear_combination', 'gcd', 'theorem', 'relate', 'great', 'common_divisor', 'linear_combination', 'theorem', 'useful', 'take', 'time', 'understand', 'remember', 'first', 'show', 'gcd', 'common_divisor', 'divide', 'sa', 'tb', 'therefore', 'also', 'sa', 'tb', 'gcd', 'definition', 'common_divisor', 'chapter_number', 'theory', 'recall', 'sa', 'tb', 'integer', 'substituting', 'give', 'express', 'linear_combination', 'however', 'small', 'positive', 'linear_combination', 'possibility', 'proof', 'great', 'common_divisor']

# %%
'''Find phrasers of books  '''
paper_phrasers = {}
for doc_name in main_section_as_one_doc.keys():
    paper_phrasers[doc_name] = list(set(reduce(lambda acc,x: acc+x,
                                      [[w for w in ch if '_' in w]
                                      for ch in main_section_as_one_doc[doc_name]])))

# %%
#paper_phrasers['Dsa']

# %% [markdown]
# # FIND CORRELATION BETWEEN MAIN CHAPTERES AND FOUNDED TOPICS IN THE VIDEO

# %%
def find_top_words_of_topic(topic_words,chapter_titles=None):
    for tp_i,tp_words in enumerate(topic_words):
        #
        raw_text = ' '.join(tp_words)
        myvectorizer = CountVectorizer()
        mytf = myvectorizer.fit_transform([raw_text]).toarray()
        #print(mytf)
        maxes = heapq.nlargest(3,mytf[0])
        indexes = []
        for i,bal in enumerate(mytf[0]):
            if bal in maxes:
                indexes.append(i)
        ws = [myvectorizer.get_feature_names()[_] for i,_ in enumerate(indexes)]
        
        if chapter_titles is None:
            print('top words for topic %s are %s' %(tp_i,ws))
        else:
            print('top words for topic %s are %s' %(chapter_titles[tp_i],ws))

# %%
from nltk.corpus import stopwords
from gensim.utils import simple_preprocess
import spacy
from nltk.stem import PorterStemmer
stop_words = stopwords.words('english')
nlp = spacy.load('en',disable=['parser','ner'])
allowed_postags=['NOUN', 'ADJ', 'VERB','PROPN','ADV']#['NOUN', 'ADJ', 'VERB','ADV']#['NOUN', 'ADJ', 'VERB','PROPN']# #['NOUN', 'ADJ', 'VERB']
porter = PorterStemmer()

# %%
def emphasize_title(doc_name,book_chapters,titles,factor_enrich = 20,lemmatizing = "lemma"):
    chapters_enriched = book_chapters[:]
    
    for index,tl in enumerate(titles):
        tl_text_no_punc = simple_preprocess(tl,deacc=True) 
        tokenized_text_non_stop_words = [ word for word in tl_text_no_punc 
                                         if word not in stop_words]
        """text_non_stop_words = ' '.join(tokenized_text_non_stop_words)
        tokenized_lemmas = nlp(text_non_stop_words)
        tokenized_lemmas = [token.lemma_ for token in tokenized_lemmas \
                            if token.pos_ in allowed_postags]"""
        
        if lemmatizing == "stemm":
            tokenized_lemmas = [porter.stem(w) for w in tokenized_text_non_stop_words]
        else:
            text_non_stop_words = ' '.join(tokenized_text_non_stop_words)
            tokenized_lemmas = nlp(text_non_stop_words)
            tokenized_lemmas = [token.lemma_ for token in tokenized_lemmas \
                                if token.pos_ in allowed_postags]

        
        
        tokenized_lemmas_ph = '_'.join(tokenized_lemmas)#reduce(lambda acc,x: acc+x,
        #print('tokenized_lemmas_ph %s' %(tokenized_lemmas_ph))
        
        if tokenized_lemmas_ph in paper_phrasers[doc_name]:
            tokenized_lemmas =[tokenized_lemmas_ph]
        
        chapters_enriched[index] = chapters_enriched[index] + tokenized_lemmas * factor_enrich
    return chapters_enriched

# %%
def get_topic_chapter_corr_tfidf(paper_name,book_chapters,
                                 vid_topics_words,vid_topics_shift,
                                 dispaly_titles,pre_labeled_title=None,is_print_mess=True):
    raw_book_video = []
    for tp_vid in vid_topics_words:
        raw_book_video = raw_book_video + [tp_vid]
    
    for ch in book_chapters:
        raw_book_video = raw_book_video + [ch]

    # creating dictionary of all of the words in the corpus of the video and the paper
    #print(len(raw_book_video))
    dictionary = Dictionary(raw_book_video)
    #dictionary = Dictionary(book_chapters)
    
    #ch_dict = Dictionary(book_chapters)
    #vid_dict = Dictionary(vid_topics_words)
    
    the_dictionary = dictionary
    
    #whole_corpus = vid_topics_words + book_chapters
    #bgw_corpus = [dictionary.doc2bow(doc) for doc in whole_corpus]
    bgw_chapter = [the_dictionary.doc2bow(doc) for doc in book_chapters]
    bgw_vids = [the_dictionary.doc2bow(doc) for doc in vid_topics_words]
    
    '''Calculate the pivot '''
    _tmp =  [len(list(set([w for w in ch]))) for ch in book_chapters]
    book_pivot = sum(_tmp)/len(_tmp)
    _tmp = [len(list(set([w for w in ch]))) for ch in vid_topics_words]
    vid_pivot = sum(_tmp)/len(_tmp)
    
    tf_idf_model_ch = models.TfidfModel(bgw_chapter,
                                        dictionary=the_dictionary#,
                                        #pivot=book_pivot#,
                                        #slope=0.8,
                                        #smartirs='nnc'
                                       ) #,
    tf_idf_model_vid = models.TfidfModel(bgw_vids,
                                         dictionary=the_dictionary#,
                                         #pivot=vid_pivot#,
                                         #slope=0.4
                                        )#,smartirs='lfc'
    
    index_sim = similarities.SparseMatrixSimilarity(tf_idf_model_ch[bgw_chapter],
                                                    num_features=len(the_dictionary))
    
    correlation = [[s for s in index_sim[tf_idf_model_vid[doc]]] for doc in bgw_vids]
    #print(tf_idf_model[bgw_vids])
    
    # find the top n words in the topic (in the video)
    #print('$$$$$$$$$$$$$$top words of video topic$$$$$$$$$$$$$$')
    #find_top_words_of_topic(videos_division[vid]['topic_words'])
    #print('$$$$$$$$$$$$$$top words of book chapters$$$$$$$$$$$$$$')
    #find_top_words_of_topic(book_chapters,chapter_titles=dispaly_titles)
    
    
    
    # normalizing the correlation between each topic and chapter 
    for i_t in range(len(correlation)):
        sum_ = sum(correlation[i_t])
        for ch_index in range(len(correlation[i_t])):
            correlation[i_t][ch_index] = correlation[i_t][ch_index]/sum_
    
    corr_as_row = reduce(lambda x,y: x+y,correlation,[] ) # to get the global max in min
    
    if is_print_mess:
        sns.heatmap(correlation,vmin=min(corr_as_row),vmax=max(corr_as_row))
        plt.show()
    
    
    
    # find the cha
    ch_matching_top = []
    #print(len(correlation[0]))
    
    
    for i,corr in enumerate(correlation):
        max_cor = max(corr) # max correlation with that topic
        #shift = vid_topics_shift[i]
        founded_title = dispaly_titles[corr.index(max_cor)]
        #ch_matching_top.append(paper_mainchapter_indexes[paper_name][corr.index(max_cor)])
        ch_matching_top.append(founded_title)

    
    
    hit = 0 
    miss = 0
    
    if pre_labeled_title is not None:
        print(vid)
        shifts = df_videos.loc[df_videos['video id'] == vid,'topic shifts(ends)'].values.tolist()
        groundbase = shifts#[:-1] # not removing the end string - modify it in the next lines
        vid_topics_shift[-1] = groundbase[-1] # converting the 'end' string to 
        df_vid_results = pd.DataFrame(columns=['Video',
                                               'Video Shift',
                                               'Founded Title',
                                               'Similarity Ratio',
                                               'Chapter Section',
                                               'Prelabeled Title',
                                               'Labeling Confidence'])
        for i,corr in enumerate(correlation):
            max_cor = max(corr) # max correlation with that topic
            shift = vid_topics_shift[i]
            closest_grb_index = 0
            for grb_i in range(len(groundbase)):
                if abs(int(groundbase[grb_i])- shift) < abs(int(groundbase[closest_grb_index]) - shift):
                    closest_grb_index = grb_i
            
            founded_title = dispaly_titles[corr.index(max_cor)]
            df_vid_results = df_vid_results.append({
                                   'Video' :vid,
                                   'Video Shift': sec_to_min(shift),
                                   'Founded Title':founded_title,
                                   'Similarity Ratio':max_cor,
                                   'Chapter Section':pre_labeled_title[closest_grb_index][0],
                                   'Prelabeled Title':pre_labeled_title[closest_grb_index][1],
                                   'Labeling Confidence':pre_labeled_title[closest_grb_index][2]},ignore_index=True)

        display(HTML(df_vid_results[['Video Shift',
                                    'Founded Title',
                                    'Similarity Ratio',
                                    'Chapter Section',
                                    'Prelabeled Title',
                                    'Labeling Confidence']].to_html()))
    elif is_print_mess:
        for i,corr in enumerate(correlation):
            max_cor = max(corr) # max correlation with that topic
            shift = vid_topics_shift[i]
            print (" video_shift index %s at %s , chapter title %s ( index %s) " 
                   %(i,
                     sec_to_min(shift),
                     dispaly_titles[corr.index(max_cor)],
                     corr.index(max_cor)
                     ))

    return ch_matching_top,correlation

def find_dominent_main_chapter(ch_tp_corr,titles,correlation):
    
    '''Find the frequency of each chapter'''
    chapter_matching_counts_max = [max([ch_tp_corr.count(ch) for ch in ch_tp_corr])]
    for max_count in chapter_matching_counts_max:
        #print("####### #######")
        '''Find the most frequent chapter'''
        #print(([ch for ch in ch_tp_corr if ch_tp_corr.count(ch) == max_count]))
        dominent_chapters = list(set([ch for ch in ch_tp_corr if ch_tp_corr.count(ch) == max_count]))
        #print(dominent_chapters)
        
        # if we have absulote majority on topic
        if len(dominent_chapters) == 1:
            return dominent_chapters[0]
        else:
            # draw between topics, decide which one by taking this with the high variance
            index_winner = 0
            df_ch_corr = pd.DataFrame.from_records(correlation)
            for j_dom in range(len(dominent_chapters)):
                first = df_ch_corr.var()[titles.index(dominent_chapters[index_winner])]
                #print(first)
                second = df_ch_corr.var()[titles.index(dominent_chapters[j_dom])]
                #print(second)
                if first > second:
                    index_winner = j_dom
            return (dominent_chapters[index_winner])
        
            
        
def sec_to_min(seconds):
    if seconds == 'end':
        return 'end'
    return ("%02d:%02d"%(seconds//60,seconds%60))

# correlations : correaltions of all levels
def measure_confidence(vid,correlations):
    n_vid_topic = len(correlations[0]) # number of video topics that were found
    topics_errs = []
    for topic_index in range(n_vid_topic):
        topic_pr = 0
        for map_index,correlation_map in enumerate(correlations):
            '''Calculate soft max on the correlation of the current topic to the chapters'''
            #print('correlation %s map %s' % (topic_index,correlation_map[topic_index]))
            sum_ = sum(correlation_map[topic_index])
            max_corr_ch_val = max(correlation_map[topic_index])
            #most_corr_ch_index = correlation_map[topic_index].index(max_corr_ch_val)
            most_corr_ch_val = max_corr_ch_val/sum_
            #print('max_val : %s sum_ : %s value from softmax : %s '%(max_corr_ch_val,sum_,most_corr_ch_val))
            '''scaling the max value by the cosine value of the max correlated'''
            most_corr_ch_val = most_corr_ch_val * max_corr_ch_val
            '''adding and scaling the given value to the overall rate of the topic'''
            topic_pr += (2**(-(map_index - 1))) * most_corr_ch_val
        print("For topic number %s the confidence is %s " % (topic_index,topic_pr))
        topics_errs.append(topic_pr)

# %%
'''my hand tuning data frame'''

df_tp_to_ch = pd.read_csv(os.path.join(groundbase_dir,'Topic to chapter.csv'))
df_tp_to_ch  = df_tp_to_ch.replace({np.nan:None})

# %%
chapters_matching_topics = {}
#for vid in videos_ids:
for vid in videos_ids:
    print('################ %s ################' % (vid))
    paper_name = video_to_paper[vid]
    correlations_levels = []
    
    
    
    '''Finding the correlation between topic and main chapters'''
    main_matching_topic,correlation = get_topic_chapter_corr_tfidf(paper_name,
                                 main_section_as_one_doc[paper_name],
                                 videos_division[vid]['topic_words'],
                                 videos_division[vid]['topic_shift'],
                                 paper_content[paper_name]['main titles'])
    
    correlations_levels.append(correlation)
    #print(main_matching_topic)
    dominet_chapter =  find_dominent_main_chapter(main_matching_topic,
                                                  paper_content[paper_name]['main titles'],
                                                 correlation)
    print('By the majority vote, the dominent chapter choosed is %s ' %(dominet_chapter))
    
    '''Finding correlation to the first dep sections within the selected main chapter'''
    dom_main_cha_index = paper_content[paper_name]['main titles'].index(dominet_chapter)
    print(dom_main_cha_index)
    dom_subsec_text = [first_dep_section_as_one_doc[paper_name][s_i]
                       for s_i in titles_by_hierchy_ranges[0][dom_main_cha_index]]
    dom_subsec_titles = [tl_first_dep_by_hier[tl_i]
                         for tl_i in titles_by_hierchy_ranges[0][dom_main_cha_index]]
    
    dom_subsec_text = emphasize_title(paper_name,dom_subsec_text,
                                      dom_subsec_titles,lemmatizing = lemmatizing_method)
    
    
    subsec_matching_topic,correlation = get_topic_chapter_corr_tfidf(paper_name,
                                 dom_subsec_text,
                                 videos_division[vid]['topic_words'],
                                 videos_division[vid]['topic_shift'],
                                 dom_subsec_titles)
    
    correlations_levels.append(correlation)
    #measure_confidence(vid,correlations_levels)
    section_to_topic = []
    #topics_correlations = []
    '''Finding the third ganular level of chossing the chapter'''
    
    for tp_i,section in enumerate(subsec_matching_topic):
        '''
            Finding the subsections title and texts of the first dep section (4.1 etc)
        '''
        curr_first_dep_tl_index = tl_first_dep_by_hier.index(section)
        subsec_range = titles_by_hierchy_ranges[1][curr_first_dep_tl_index]
        subsection_titles = [paper_content[doc_name]['titles'][tl_i] for tl_i in  subsec_range]
        subsection_text = [paper_subsec_as_one_doc[doc_name][tx_i] for tx_i in subsec_range]
        subsection_text = emphasize_title(paper_name,subsection_text,
                                      subsection_titles,lemmatizing = lemmatizing_method)
        
        topic_matching,topic_corr = get_topic_chapter_corr_tfidf(paper_name,
                                                                 subsection_text,
                                                                 [videos_division[vid]['topic_words'][tp_i]],
                                                                 None,
                                                                 subsection_titles,
                                                                 is_print_mess=False
                                                                )
        section_to_topic = section_to_topic + topic_matching
    
    
    '''Extracting all pre labeled topics '''
    pre_labeled_titles = df_tp_to_ch.loc[df_tp_to_ch['video id'] == vid,
                        ['chapter section','chapter title','chapter confidence']].values.tolist()
    
    
    '''Find the match between the topics to the chapter at the most granular way'''
    
    shifts = df_videos.loc[df_videos['video id'] == vid,'topic shifts(ends)'].values.tolist()
    groundbase = shifts#[:-1] # not removing the end string - modify it in the next lines
    videos_division[vid]['topic_shift'][-1] = groundbase[-1] # converting the 'end' string to 
    df_vid_results = pd.DataFrame(columns=['Video',
                                           'Video Shift',
                                           'Founded Title',
                                           'Chapter Section',
                                           'Prelabeled Title',
                                           'Nearest Groundbase',
                                           'Labeling Confidence'])
    
    for topic_i in range(len(videos_division[vid]['topic_shift'])):
        #max_cor = max(corr) # max correlation with that topic
        curr_shift = videos_division[vid]['topic_shift'][topic_i]
        closest_grb_index = 0
        for grb_i in range(len(groundbase)):
            if abs(int(groundbase[grb_i])- curr_shift) < abs(int(groundbase[closest_grb_index]) - curr_shift):
                closest_grb_index = grb_i

        founded_title = section_to_topic[topic_i]
        df_vid_results = df_vid_results.append({
                               'Video' :vid,
                               'Video Shift': sec_to_min(curr_shift),
                               'Founded Title':founded_title,
                               'Chapter Section':pre_labeled_titles[closest_grb_index][0],
                               'Prelabeled Title':pre_labeled_titles[closest_grb_index][1],
                               'Nearest Groundbase':sec_to_min(groundbase[closest_grb_index]),
                               'Labeling Confidence':pre_labeled_titles[closest_grb_index][2]},ignore_index=True)

    display(HTML(df_vid_results[['Video Shift',
                                'Founded Title',
                                'Chapter Section',
                                'Prelabeled Title',
                                 'Nearest Groundbase',
                                'Labeling Confidence']].to_html()))
    #display(HTML(df_tp_to_ch.loc[df_tp_to_ch['video id'] == vid]).to_html())
    display(df_tp_to_ch.loc[df_tp_to_ch['video id'] == vid])
# Out:
# ################ bTyxpoi2dmM ################
#  video_shift index 0 at 01:53 , chapter title Directed Graphs ( index 5)
#  video_shift index 1 at 03:10 , chapter title Directed Graphs ( index 5)
#  video_shift index 2 at 05:32 , chapter title Directed Graphs ( index 5)
#  video_shift index 3 at 07:13 , chapter title Directed Graphs ( index 5)
#  video_shift index 4 at 10:33 , chapter title Directed Graphs ( index 5)
#  video_shift index 5 at 14:00 , chapter title Directed Graphs ( index 5)
#  video_shift index 6 at 16:51 , chapter title Directed Graphs ( index 5)
#  video_shift index 7 at 21:05 , chapter title Directed Graphs ( index 5)
#  video_shift index 8 at 24:27 , chapter title Directed Graphs ( index 5)
#  video_shift index 9 at 27:18 , chapter title Directed Graphs ( index 5)
#  video_shift index 10 at 28:53 , chapter title Directed Graphs ( index 5)
#  video_shift index 11 at 31:13 , chapter title Directed Graphs ( index 5)
#  video_shift index 12 at 34:12 , chapter title Directed Graphs ( index 5)
#  video_shift index 13 at 36:44 , chapter title Directed Graphs ( index 5)
#  video_shift index 14 at 39:18 , chapter title Directed Graphs ( index 5)
#  video_shift index 15 at 42:18 , chapter title Directed Graphs ( index 5)
#  video_shift index 16 at 45:11 , chapter title Directed Graphs ( index 5)
#  video_shift index 17 at 48:09 , chapter title Directed Graphs ( index 5)
#  video_shift index 18 at 51:28 , chapter title Directed Graphs ( index 5)
#  video_shift index 19 at 54:00 , chapter title Directed Graphs ( index 5)
#  video_shift index 20 at 57:17 , chapter title Directed Graphs ( index 5)
#  video_shift index 21 at 60:08 , chapter title Directed Graphs ( index 5)
#  video_shift index 22 at 63:16 , chapter title Directed Graphs ( index 5)
#  video_shift index 23 at 68:29 , chapter title Directed Graphs ( index 5)
#  video_shift index 24 at 73:02 , chapter title Directed Graphs ( index 5)
#  video_shift index 25 at 76:50 , chapter title Directed Graphs ( index 5)
#  video_shift index 26 at 83:04 , chapter title Directed Graphs ( index 5)
#  video_shift index 27 at 83:24 , chapter title Infinite Sets ( index 12)
# By the majority vote, the dominent chapter choosed is Directed Graphs
# 5
#  video_shift index 0 at 01:53 , chapter title 6.3 Communication Networks ( index 2)
#  video_shift index 1 at 03:10 , chapter title 6.3 Communication Networks ( index 2)
#  video_shift index 2 at 05:32 , chapter title 6.3 Communication Networks ( index 2)
#  video_shift index 3 at 07:13 , chapter title 6.3 Communication Networks ( index 2)
#  video_shift index 4 at 10:33 , chapter title 6.3 Communication Networks ( index 2)
#  video_shift index 5 at 14:00 , chapter title 6.3 Communication Networks ( index 2)
#  video_shift index 6 at 16:51 , chapter title 6.3 Communication Networks ( index 2)
#  video_shift index 7 at 21:05 , chapter title 6.3 Communication Networks ( index 2)
#  video_shift index 8 at 24:27 , chapter title 6.3 Communication Networks ( index 2)
#  video_shift index 9 at 27:18 , chapter title 6.3 Communication Networks ( index 2)
#  video_shift index 10 at 28:53 , chapter title 6.3 Communication Networks ( index 2)
#  video_shift index 11 at 31:13 , chapter title 6.3 Communication Networks ( index 2)
#  video_shift index 12 at 34:12 , chapter title 6.3 Communication Networks ( index 2)
#  video_shift index 13 at 36:44 , chapter title 6.3 Communication Networks ( index 2)
#  video_shift index 14 at 39:18 , chapter title 6.3 Communication Networks ( index 2)
#  video_shift index 15 at 42:18 , chapter title 6.3 Communication Networks ( index 2)
#  video_shift index 16 at 45:11 , chapter title 6.3 Communication Networks ( index 2)
#  video_shift index 17 at 48:09 , chapter title 6.3 Communication Networks ( index 2)
#  video_shift index 18 at 51:28 , chapter title 6.3 Communication Networks ( index 2)
#  video_shift index 19 at 54:00 , chapter title 6.3 Communication Networks ( index 2)
#  video_shift index 20 at 57:17 , chapter title 6.3 Communication Networks ( index 2)
#  video_shift index 21 at 60:08 , chapter title 6.3 Communication Networks ( index 2)
#  video_shift index 22 at 63:16 , chapter title 6.3 Communication Networks ( index 2)
#  video_shift index 23 at 68:29 , chapter title 6.3 Communication Networks ( index 2)
#  video_shift index 24 at 73:02 , chapter title 6.3 Communication Networks ( index 2)
#  video_shift index 25 at 76:50 , chapter title 6.3 Communication Networks ( index 2)
#  video_shift index 26 at 83:04 , chapter title 6.3 Communication Networks ( index 2)
#  video_shift index 27 at 83:24 , chapter title 6.3 Communication Networks ( index 2)
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Video Shift</th>
#       <th>Founded Title</th>
#       <th>Chapter Section</th>
#       <th>Prelabeled Title</th>
#       <th>Nearest Groundbase</th>
#       <th>Labeling Confidence</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>01:53</td>
#       <td>6.3 Communication Networks</td>
#       <td>6.3</td>
#       <td>Communication Networks</td>
#       <td>01:30</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>03:10</td>
#       <td>6.3.2 The Complete Binary Tree</td>
#       <td>6.3</td>
#       <td>Communication Networks</td>
#       <td>01:30</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>05:32</td>
#       <td>6.3.2 The Complete Binary Tree</td>
#       <td>6.3.2</td>
#       <td>The Complete Binary Tree</td>
#       <td>06:00</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>07:13</td>
#       <td>6.3.3 Network Diameter</td>
#       <td>6.3.2</td>
#       <td>The Complete Binary Tree</td>
#       <td>06:00</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>10:33</td>
#       <td>6.3.3 Network Diameter</td>
#       <td>6.3.3</td>
#       <td>Network Diameter</td>
#       <td>11:05</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>14:00</td>
#       <td>6.3.3 Network Diameter</td>
#       <td>6.3.4</td>
#       <td>Switch Size</td>
#       <td>14:45</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>16:51</td>
#       <td>6.3.5 Switch Count</td>
#       <td>6.3.5</td>
#       <td>Switch Count</td>
#       <td>16:25</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>21:05</td>
#       <td>6.3.6 Congestion</td>
#       <td>6.3.5</td>
#       <td>Switch Count</td>
#       <td>16:25</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>24:27</td>
#       <td>6.3.6 Congestion</td>
#       <td>6.3.6</td>
#       <td>Congestion</td>
#       <td>27:00</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>27:18</td>
#       <td>6.3.6 Congestion</td>
#       <td>6.3.6</td>
#       <td>Congestion</td>
#       <td>27:00</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>28:53</td>
#       <td>6.3.3 Network Diameter</td>
#       <td>6.3.6</td>
#       <td>Congestion</td>
#       <td>27:00</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>31:13</td>
#       <td>6.3.6 Congestion</td>
#       <td>6.3.6</td>
#       <td>Congestion</td>
#       <td>27:00</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>34:12</td>
#       <td>6.3.6 Congestion</td>
#       <td>6.3.7</td>
#       <td>The 2-d Array</td>
#       <td>37:13</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>36:44</td>
#       <td>6.3.6 Congestion</td>
#       <td>6.3.7</td>
#       <td>The 2-d Array</td>
#       <td>37:13</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>39:18</td>
#       <td>6.3.2 The Complete Binary Tree</td>
#       <td>6.3.7</td>
#       <td>The 2-d Array</td>
#       <td>37:13</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>42:18</td>
#       <td>6.3.8 The Butterfly</td>
#       <td>6.3.7</td>
#       <td>The 2-d Array</td>
#       <td>37:13</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>45:11</td>
#       <td>6.3.8 The Butterfly</td>
#       <td>6.3.7</td>
#       <td>The 2-d Array</td>
#       <td>37:13</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>48:09</td>
#       <td>6.3.8 The Butterfly</td>
#       <td>6.3.8</td>
#       <td>The Butterfly</td>
#       <td>53:40</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>51:28</td>
#       <td>6.3.1 Packet Routing</td>
#       <td>6.3.8</td>
#       <td>The Butterfly</td>
#       <td>53:40</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>54:00</td>
#       <td>6.3.6 Congestion</td>
#       <td>6.3.8</td>
#       <td>The Butterfly</td>
#       <td>53:40</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>57:17</td>
#       <td>6.3.1 Packet Routing</td>
#       <td>6.3.8</td>
#       <td>The Butterfly</td>
#       <td>53:40</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>60:08</td>
#       <td>6.3.9 Benesˇ Network</td>
#       <td>6.3.8</td>
#       <td>The Butterfly</td>
#       <td>53:40</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>63:16</td>
#       <td>6.3.9 Benesˇ Network</td>
#       <td>6.3.8</td>
#       <td>The Butterfly</td>
#       <td>53:40</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>68:29</td>
#       <td>6.3.6 Congestion</td>
#       <td>6.3.8</td>
#       <td>The Butterfly</td>
#       <td>53:40</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>73:02</td>
#       <td>6.3.9 Benesˇ Network</td>
#       <td>6.3.9</td>
#       <td>Benes Network</td>
#       <td>83:24</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>76:50</td>
#       <td>6.3.9 Benesˇ Network</td>
#       <td>6.3.9</td>
#       <td>Benes Network</td>
#       <td>83:24</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>83:04</td>
#       <td>6.3.9 Benesˇ Network</td>
#       <td>6.3.9</td>
#       <td>Benes Network</td>
#       <td>83:24</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>83:24</td>
#       <td>6.3.9 Benesˇ Network</td>
#       <td>6.3.9</td>
#       <td>Benes Network</td>
#       <td>83:24</td>
#       <td>None</td>
#     </tr>
#   </tbody>
# </table>
#      shift index topic shifts(ends) label video     video id chapter section  \
# 93             0           00:01:30  None  None  bTyxpoi2dmM             6.3
# 94             1           00:06:00  None  None  bTyxpoi2dmM           6.3.2
# 95             2           00:11:05  None  None  bTyxpoi2dmM           6.3.3
# 96             3           00:14:45  None  None  bTyxpoi2dmM           6.3.4
# 97             4           00:16:25  None  None  bTyxpoi2dmM           6.3.5
# 98             5           00:27:00  None  None  bTyxpoi2dmM           6.3.6
# 99             6           00:37:13  None  None  bTyxpoi2dmM           6.3.7
# 100            7           00:53:40  None  None  bTyxpoi2dmM           6.3.8
# 101            8           01:23:24  None  None  bTyxpoi2dmM           6.3.9
#
#                 chapter title chapter confidence notes
# 93     Communication Networks               None  None
# 94   The Complete Binary Tree               None  None
# 95           Network Diameter               None  None
# 96                Switch Size               None  None
# 97               Switch Count               None  None
# 98                 Congestion               None  None
# 99              The 2-d Array               None  None
# 100             The Butterfly               None  None
# 101             Benes Network               None  None
# ################ GJpt_3ie4WU ################
#  video_shift index 0 at 02:08 , chapter title Graph Theory ( index 4)
#  video_shift index 1 at 04:58 , chapter title Graph Theory ( index 4)
#  video_shift index 2 at 07:55 , chapter title Graph Theory ( index 4)
#  video_shift index 3 at 12:18 , chapter title Graph Theory ( index 4)
#  video_shift index 4 at 14:52 , chapter title Graph Theory ( index 4)
#  video_shift index 5 at 16:42 , chapter title Graph Theory ( index 4)
#  video_shift index 6 at 18:39 , chapter title Graph Theory ( index 4)
#  video_shift index 7 at 21:02 , chapter title Graph Theory ( index 4)
#  video_shift index 8 at 23:27 , chapter title Graph Theory ( index 4)
#  video_shift index 9 at 25:26 , chapter title Induction ( index 2)
#  video_shift index 10 at 28:18 , chapter title Graph Theory ( index 4)
#  video_shift index 11 at 31:59 , chapter title Graph Theory ( index 4)
#  video_shift index 12 at 36:06 , chapter title Graph Theory ( index 4)
#  video_shift index 13 at 39:53 , chapter title Graph Theory ( index 4)
#  video_shift index 14 at 42:25 , chapter title Graph Theory ( index 4)
#  video_shift index 15 at 45:13 , chapter title Graph Theory ( index 4)
#  video_shift index 16 at 46:51 , chapter title Graph Theory ( index 4)
#  video_shift index 17 at 48:53 , chapter title Graph Theory ( index 4)
#  video_shift index 18 at 51:35 , chapter title Graph Theory ( index 4)
#  video_shift index 19 at 55:50 , chapter title Graph Theory ( index 4)
#  video_shift index 20 at 59:59 , chapter title Graph Theory ( index 4)
#  video_shift index 21 at 63:37 , chapter title Graph Theory ( index 4)
#  video_shift index 22 at 67:53 , chapter title Induction ( index 2)
#  video_shift index 23 at 70:35 , chapter title Graph Theory ( index 4)
#  video_shift index 24 at 73:11 , chapter title Graph Theory ( index 4)
#  video_shift index 25 at 76:45 , chapter title Graph Theory ( index 4)
#  video_shift index 26 at 80:21 , chapter title Number Theory ( index 3)
#  video_shift index 27 at 83:25 , chapter title Number Theory ( index 3)
# By the majority vote, the dominent chapter choosed is Graph Theory
# 4
#  video_shift index 0 at 02:08 , chapter title 5.4 Getting from A to B in a Graph ( index 3)
#  video_shift index 1 at 04:58 , chapter title 5.4 Getting from A to B in a Graph ( index 3)
#  video_shift index 2 at 07:55 , chapter title 5.4 Getting from A to B in a Graph ( index 3)
#  video_shift index 3 at 12:18 , chapter title 5.4 Getting from A to B in a Graph ( index 3)
#  video_shift index 4 at 14:52 , chapter title 5.5 Connectivity ( index 4)
#  video_shift index 5 at 16:42 , chapter title 5.4 Getting from A to B in a Graph ( index 3)
#  video_shift index 6 at 18:39 , chapter title 5.5 Connectivity ( index 4)
#  video_shift index 7 at 21:02 , chapter title 5.7 Trees ( index 6)
#  video_shift index 8 at 23:27 , chapter title 5.7 Trees ( index 6)
#  video_shift index 9 at 25:26 , chapter title 5.7 Trees ( index 6)
#  video_shift index 10 at 28:18 , chapter title 5.7 Trees ( index 6)
#  video_shift index 11 at 31:59 , chapter title 5.7 Trees ( index 6)
#  video_shift index 12 at 36:06 , chapter title 5.7 Trees ( index 6)
#  video_shift index 13 at 39:53 , chapter title 5.7 Trees ( index 6)
#  video_shift index 14 at 42:25 , chapter title 5.7 Trees ( index 6)
#  video_shift index 15 at 45:13 , chapter title 5.7 Trees ( index 6)
#  video_shift index 16 at 46:51 , chapter title 5.7 Trees ( index 6)
#  video_shift index 17 at 48:53 , chapter title 5.3 Coloring ( index 2)
#  video_shift index 18 at 51:35 , chapter title 5.7 Trees ( index 6)
#  video_shift index 19 at 55:50 , chapter title 5.7 Trees ( index 6)
#  video_shift index 20 at 59:59 , chapter title 5.7 Trees ( index 6)
#  video_shift index 21 at 63:37 , chapter title 5.7 Trees ( index 6)
#  video_shift index 22 at 67:53 , chapter title 5.7 Trees ( index 6)
#  video_shift index 23 at 70:35 , chapter title 5.7 Trees ( index 6)
#  video_shift index 24 at 73:11 , chapter title 5.7 Trees ( index 6)
#  video_shift index 25 at 76:45 , chapter title 5.7 Trees ( index 6)
#  video_shift index 26 at 80:21 , chapter title 5.7 Trees ( index 6)
#  video_shift index 27 at 83:25 , chapter title 5.7 Trees ( index 6)
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Video Shift</th>
#       <th>Founded Title</th>
#       <th>Chapter Section</th>
#       <th>Prelabeled Title</th>
#       <th>Nearest Groundbase</th>
#       <th>Labeling Confidence</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>02:08</td>
#       <td>5.4.1 Paths and Walks</td>
#       <td>5.4.1</td>
#       <td>Paths and Walks</td>
#       <td>05:24</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>04:58</td>
#       <td>5.4.1 Paths and Walks</td>
#       <td>5.4.1</td>
#       <td>Paths and Walks</td>
#       <td>05:24</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>07:55</td>
#       <td>5.4.1 Paths and Walks</td>
#       <td>5.4.1</td>
#       <td>Paths and Walks</td>
#       <td>05:24</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>12:18</td>
#       <td>5.4.1 Paths and Walks</td>
#       <td>5.4.2</td>
#       <td>Finding a Path</td>
#       <td>12:13</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>14:52</td>
#       <td>5.5.2</td>
#       <td>5.5</td>
#       <td>Connectivity</td>
#       <td>14:15</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>16:42</td>
#       <td>5.4.1 Paths and Walks</td>
#       <td>5.6.1</td>
#       <td>Cycles and Closed Walks</td>
#       <td>16:55</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>18:39</td>
#       <td>5.5.1 Connected Components</td>
#       <td>5.7.1</td>
#       <td>Definitions</td>
#       <td>18:55</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>21:02</td>
#       <td>5.7.4 Minimum Weight Spanning Trees</td>
#       <td>5.7.1</td>
#       <td>Definitions</td>
#       <td>18:55</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>23:27</td>
#       <td>5.7.4 Minimum Weight Spanning Trees</td>
#       <td>5.7.1</td>
#       <td>Definitions</td>
#       <td>18:55</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>25:26</td>
#       <td>5.7.4 Minimum Weight Spanning Trees</td>
#       <td>5.7.2</td>
#       <td>Properties</td>
#       <td>30:20</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>28:18</td>
#       <td>5.7.2 Properties</td>
#       <td>5.7.2</td>
#       <td>Properties</td>
#       <td>30:20</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>31:59</td>
#       <td>5.7.4 Minimum Weight Spanning Trees</td>
#       <td>5.7.2</td>
#       <td>Properties</td>
#       <td>30:20</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>36:06</td>
#       <td>5.7.3 Spanning Trees</td>
#       <td>5.7.2</td>
#       <td>Properties</td>
#       <td>30:20</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>39:53</td>
#       <td>5.7.3 Spanning Trees</td>
#       <td>5.7.3</td>
#       <td>Spanning Trees</td>
#       <td>44:33</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>42:25</td>
#       <td>5.7.2 Properties</td>
#       <td>5.7.3</td>
#       <td>Spanning Trees</td>
#       <td>44:33</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>45:13</td>
#       <td>5.7.4 Minimum Weight Spanning Trees</td>
#       <td>5.7.3</td>
#       <td>Spanning Trees</td>
#       <td>44:33</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>46:51</td>
#       <td>5.7.4 Minimum Weight Spanning Trees</td>
#       <td>5.7.3</td>
#       <td>Spanning Trees</td>
#       <td>44:33</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>48:53</td>
#       <td>5.3.1 An Exam Scheduling Problem</td>
#       <td>5.7.3</td>
#       <td>Spanning Trees</td>
#       <td>44:33</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>51:35</td>
#       <td>5.7.4 Minimum Weight Spanning Trees</td>
#       <td>5.7.3</td>
#       <td>Spanning Trees</td>
#       <td>44:33</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>55:50</td>
#       <td>5.7.4 Minimum Weight Spanning Trees</td>
#       <td>5.7.3</td>
#       <td>Spanning Trees</td>
#       <td>44:33</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>59:59</td>
#       <td>5.7.4 Minimum Weight Spanning Trees</td>
#       <td>5.7.3</td>
#       <td>Spanning Trees</td>
#       <td>44:33</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>63:37</td>
#       <td>5.7.4 Minimum Weight Spanning Trees</td>
#       <td>5.7.3</td>
#       <td>Spanning Trees</td>
#       <td>44:33</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>67:53</td>
#       <td>5.7.4 Minimum Weight Spanning Trees</td>
#       <td>5.7.4</td>
#       <td>Minimum Weight Spanning Trees</td>
#       <td>83:25</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>70:35</td>
#       <td>5.7.4 Minimum Weight Spanning Trees</td>
#       <td>5.7.4</td>
#       <td>Minimum Weight Spanning Trees</td>
#       <td>83:25</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>73:11</td>
#       <td>5.7.4 Minimum Weight Spanning Trees</td>
#       <td>5.7.4</td>
#       <td>Minimum Weight Spanning Trees</td>
#       <td>83:25</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>76:45</td>
#       <td>5.7.2 Properties</td>
#       <td>5.7.4</td>
#       <td>Minimum Weight Spanning Trees</td>
#       <td>83:25</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>80:21</td>
#       <td>5.7.4 Minimum Weight Spanning Trees</td>
#       <td>5.7.4</td>
#       <td>Minimum Weight Spanning Trees</td>
#       <td>83:25</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>83:25</td>
#       <td>5.7.4 Minimum Weight Spanning Trees</td>
#       <td>5.7.4</td>
#       <td>Minimum Weight Spanning Trees</td>
#       <td>83:25</td>
#       <td>None</td>
#     </tr>
#   </tbody>
# </table>
#     shift index topic shifts(ends) label video     video id chapter section  \
# 85            0           00:05:24  None  None  GJpt_3ie4WU           5.4.1
# 86            1           00:12:13  None  None  GJpt_3ie4WU           5.4.2
# 87            2           00:14:15  None  None  GJpt_3ie4WU             5.5
# 88            3           00:16:55  None  None  GJpt_3ie4WU           5.6.1
# 89            4           00:18:55  None  None  GJpt_3ie4WU           5.7.1
# 90            5           00:30:20  None  None  GJpt_3ie4WU           5.7.2
# 91            6           00:44:33  None  None  GJpt_3ie4WU           5.7.3
# 92            7           01:23:25  None  None  GJpt_3ie4WU           5.7.4
#
#                     chapter title chapter confidence notes
# 85                Paths and Walks               None  None
# 86                 Finding a Path               None  None
# 87                   Connectivity               None  None
# 88        Cycles and Closed Walks               None  None
# 89                    Definitions               None  None
# 90                     Properties               None  None
# 91                 Spanning Trees               None  None
# 92  Minimum Weight Spanning Trees               None  None
# ################ h9wxtqoa1jY ################
#  video_shift index 0 at 01:56 , chapter title Graph Theory ( index 4)
#  video_shift index 1 at 05:03 , chapter title Graph Theory ( index 4)
#  video_shift index 2 at 08:12 , chapter title Graph Theory ( index 4)
#  video_shift index 3 at 12:00 , chapter title Graph Theory ( index 4)
#  video_shift index 4 at 16:07 , chapter title Graph Theory ( index 4)
#  video_shift index 5 at 19:23 , chapter title Graph Theory ( index 4)
#  video_shift index 6 at 25:37 , chapter title Graph Theory ( index 4)
#  video_shift index 7 at 28:21 , chapter title Graph Theory ( index 4)
#  video_shift index 8 at 32:29 , chapter title Graph Theory ( index 4)
#  video_shift index 9 at 37:14 , chapter title Graph Theory ( index 4)
#  video_shift index 10 at 40:07 , chapter title Graph Theory ( index 4)
#  video_shift index 11 at 42:59 , chapter title Graph Theory ( index 4)
#  video_shift index 12 at 46:50 , chapter title Graph Theory ( index 4)
#  video_shift index 13 at 49:57 , chapter title Graph Theory ( index 4)
#  video_shift index 14 at 52:26 , chapter title Induction ( index 2)
#  video_shift index 15 at 55:54 , chapter title Graph Theory ( index 4)
#  video_shift index 16 at 61:12 , chapter title Number Theory ( index 3)
#  video_shift index 17 at 65:33 , chapter title Graph Theory ( index 4)
#  video_shift index 18 at 69:40 , chapter title Graph Theory ( index 4)
#  video_shift index 19 at 73:33 , chapter title Graph Theory ( index 4)
#  video_shift index 20 at 77:03 , chapter title Graph Theory ( index 4)
#  video_shift index 21 at 79:55 , chapter title Graph Theory ( index 4)
#  video_shift index 22 at 82:50 , chapter title Graph Theory ( index 4)
# By the majority vote, the dominent chapter choosed is Graph Theory
# 4
#  video_shift index 0 at 01:56 , chapter title 5.2 Matching Problems ( index 1)
#  video_shift index 1 at 05:03 , chapter title 5.2 Matching Problems ( index 1)
#  video_shift index 2 at 08:12 , chapter title 5.2 Matching Problems ( index 1)
#  video_shift index 3 at 12:00 , chapter title 5.1 Definitions ( index 0)
#  video_shift index 4 at 16:07 , chapter title 5.1 Definitions ( index 0)
#  video_shift index 5 at 19:23 , chapter title 5.2 Matching Problems ( index 1)
#  video_shift index 6 at 25:37 , chapter title 5.2 Matching Problems ( index 1)
#  video_shift index 7 at 28:21 , chapter title 5.2 Matching Problems ( index 1)
#  video_shift index 8 at 32:29 , chapter title 5.3 Coloring ( index 2)
#  video_shift index 9 at 37:14 , chapter title 5.3 Coloring ( index 2)
#  video_shift index 10 at 40:07 , chapter title 5.3 Coloring ( index 2)
#  video_shift index 11 at 42:59 , chapter title 5.3 Coloring ( index 2)
#  video_shift index 12 at 46:50 , chapter title 5.3 Coloring ( index 2)
#  video_shift index 13 at 49:57 , chapter title 5.3 Coloring ( index 2)
#  video_shift index 14 at 52:26 , chapter title 5.3 Coloring ( index 2)
#  video_shift index 15 at 55:54 , chapter title 5.3 Coloring ( index 2)
#  video_shift index 16 at 61:12 , chapter title 5.3 Coloring ( index 2)
#  video_shift index 17 at 65:33 , chapter title 5.3 Coloring ( index 2)
#  video_shift index 18 at 69:40 , chapter title 5.3 Coloring ( index 2)
#  video_shift index 19 at 73:33 , chapter title 5.3 Coloring ( index 2)
#  video_shift index 20 at 77:03 , chapter title 5.3 Coloring ( index 2)
#  video_shift index 21 at 79:55 , chapter title 5.3 Coloring ( index 2)
#  video_shift index 22 at 82:50 , chapter title 5.3 Coloring ( index 2)
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Video Shift</th>
#       <th>Founded Title</th>
#       <th>Chapter Section</th>
#       <th>Prelabeled Title</th>
#       <th>Nearest Groundbase</th>
#       <th>Labeling Confidence</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>01:56</td>
#       <td>5.2.1 Sex in America</td>
#       <td>5.2.1</td>
#       <td>Sex in America</td>
#       <td>08:29</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>05:03</td>
#       <td>5.2.1 Sex in America</td>
#       <td>5.2.1</td>
#       <td>Sex in America</td>
#       <td>08:29</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>08:12</td>
#       <td>5.2.1 Sex in America</td>
#       <td>5.2.1</td>
#       <td>Sex in America</td>
#       <td>08:29</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>12:00</td>
#       <td>5.1 Definitions</td>
#       <td>5</td>
#       <td>Graph Theory</td>
#       <td>12:00</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>16:07</td>
#       <td>5.1.1 Simple Graphs</td>
#       <td>5.1.1</td>
#       <td>Simple Graphs</td>
#       <td>16:20</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>19:23</td>
#       <td>5.2.1 Bipartite Matchings</td>
#       <td>5.1.1</td>
#       <td>Simple Graphs</td>
#       <td>16:20</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>25:37</td>
#       <td>5.2.1 Sex in America</td>
#       <td>5.2.1</td>
#       <td>Sex in America</td>
#       <td>27:40</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>28:21</td>
#       <td>5.2.1 Sex in America</td>
#       <td>5.2.1</td>
#       <td>Sex in America</td>
#       <td>27:40</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>32:29</td>
#       <td>5.3.1 An Exam Scheduling Problem</td>
#       <td>5.3.1</td>
#       <td>An Exam Scheduling Problem</td>
#       <td>33:00</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>37:14</td>
#       <td>5.3.1 An Exam Scheduling Problem</td>
#       <td>5.3.1</td>
#       <td>An Exam Scheduling Problem</td>
#       <td>33:00</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>40:07</td>
#       <td>5.3.1 An Exam Scheduling Problem</td>
#       <td>5.3.3</td>
#       <td>Why Coloring?</td>
#       <td>42:50</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>42:59</td>
#       <td>5.3.2 Degree-Bounded Coloring</td>
#       <td>5.3.3</td>
#       <td>Why Coloring?</td>
#       <td>42:50</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>46:50</td>
#       <td>5.3.1 An Exam Scheduling Problem</td>
#       <td>5.3.1</td>
#       <td>An Exam Scheduling Problem</td>
#       <td>49:40</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>49:57</td>
#       <td>5.3.1 An Exam Scheduling Problem</td>
#       <td>5.3.1</td>
#       <td>An Exam Scheduling Problem</td>
#       <td>49:40</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>52:26</td>
#       <td>5.3.2 Degree-Bounded Coloring</td>
#       <td>5.3.1</td>
#       <td>An Exam Scheduling Problem</td>
#       <td>49:40</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>55:54</td>
#       <td>5.3.2 Degree-Bounded Coloring</td>
#       <td>5.3.1</td>
#       <td>An Exam Scheduling Problem</td>
#       <td>49:40</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>61:12</td>
#       <td>5.3.2 Degree-Bounded Coloring</td>
#       <td>5.3.1</td>
#       <td>An Exam Scheduling Problem</td>
#       <td>49:40</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>65:33</td>
#       <td>5.3.2 Degree-Bounded Coloring</td>
#       <td>5.3.2</td>
#       <td>Degree-Bounded Coloring</td>
#       <td>76:00</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>69:40</td>
#       <td>5.3.2 Degree-Bounded Coloring</td>
#       <td>5.3.2</td>
#       <td>Degree-Bounded Coloring</td>
#       <td>76:00</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>73:33</td>
#       <td>5.3.2 Degree-Bounded Coloring</td>
#       <td>5.3.2</td>
#       <td>Degree-Bounded Coloring</td>
#       <td>76:00</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>77:03</td>
#       <td>5.3.2 Degree-Bounded Coloring</td>
#       <td>5.2.2</td>
#       <td>Bipartite Matchings</td>
#       <td>77:42</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>79:55</td>
#       <td>5.3.3 Why coloring?</td>
#       <td>5.2.2</td>
#       <td>Bipartite Matchings</td>
#       <td>77:42</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>82:50</td>
#       <td>5.3.3 Why coloring?</td>
#       <td>5.3.3</td>
#       <td>Why Coloring?</td>
#       <td>82:50</td>
#       <td>None</td>
#     </tr>
#   </tbody>
# </table>
#     shift index topic shifts(ends)                       label video  \
# 74            0           00:08:29                        None  None
# 75            1           00:12:00                        None  None
# 76            2           00:12:47  talk about the empty graph  None
# 77            3           00:16:20                   Def 5.1.2  None
# 78            4           00:27:40                        None  None
# 79            5           00:33:00                        None  None
# 80            6           00:42:50                        None  None
# 81            7           00:49:40                        None  None
# 82            8           01:16:00                        None  None
# 83            9           01:17:42                        None  None
# 84           10           01:22:50                        None  None
#
#        video id chapter section               chapter title  \
# 74  h9wxtqoa1jY           5.2.1              Sex in America
# 75  h9wxtqoa1jY               5                Graph Theory
# 76  h9wxtqoa1jY           5.1.2          Some Common Graphs
# 77  h9wxtqoa1jY           5.1.1               Simple Graphs
# 78  h9wxtqoa1jY           5.2.1              Sex in America
# 79  h9wxtqoa1jY           5.3.1  An Exam Scheduling Problem
# 80  h9wxtqoa1jY           5.3.3               Why Coloring?
# 81  h9wxtqoa1jY           5.3.1  An Exam Scheduling Problem
# 82  h9wxtqoa1jY           5.3.2     Degree-Bounded Coloring
# 83  h9wxtqoa1jY           5.2.2         Bipartite Matchings
# 84  h9wxtqoa1jY           5.3.3               Why Coloring?
#
#    chapter confidence notes
# 74               None  None
# 75               None  None
# 76               None  None
# 77               None  None
# 78               None  None
# 79               None  None
# 80               None  None
# 81               None  None
# 82               None  None
# 83               None  None
# 84               None  None
# ################ NuY7szYSXSw ################
#  video_shift index 0 at 02:43 , chapter title Number Theory ( index 3)
#  video_shift index 1 at 04:04 , chapter title Number Theory ( index 3)
#  video_shift index 2 at 05:48 , chapter title Number Theory ( index 3)
#  video_shift index 3 at 07:59 , chapter title Cardinality Rules ( index 10)
#  video_shift index 4 at 10:24 , chapter title Induction ( index 2)
#  video_shift index 5 at 13:11 , chapter title Patterns of Proof ( index 1)
#  video_shift index 6 at 16:27 , chapter title Number Theory ( index 3)
#  video_shift index 7 at 19:38 , chapter title Number Theory ( index 3)
#  video_shift index 8 at 21:51 , chapter title Induction ( index 2)
#  video_shift index 9 at 25:10 , chapter title Induction ( index 2)
#  video_shift index 10 at 28:36 , chapter title Number Theory ( index 3)
#  video_shift index 11 at 30:43 , chapter title Graph Theory ( index 4)
#  video_shift index 12 at 33:14 , chapter title Number Theory ( index 3)
#  video_shift index 13 at 35:57 , chapter title Number Theory ( index 3)
#  video_shift index 14 at 37:33 , chapter title Number Theory ( index 3)
#  video_shift index 15 at 40:22 , chapter title Number Theory ( index 3)
#  video_shift index 16 at 42:37 , chapter title Number Theory ( index 3)
#  video_shift index 17 at 45:10 , chapter title Number Theory ( index 3)
#  video_shift index 18 at 48:56 , chapter title Number Theory ( index 3)
#  video_shift index 19 at 51:33 , chapter title Number Theory ( index 3)
#  video_shift index 20 at 55:01 , chapter title Expectation ( index 17)
#  video_shift index 21 at 58:27 , chapter title Number Theory ( index 3)
#  video_shift index 22 at 60:55 , chapter title Number Theory ( index 3)
#  video_shift index 23 at 66:19 , chapter title Number Theory ( index 3)
#  video_shift index 24 at 69:24 , chapter title Number Theory ( index 3)
#  video_shift index 25 at 72:28 , chapter title Number Theory ( index 3)
#  video_shift index 26 at 76:11 , chapter title Number Theory ( index 3)
#  video_shift index 27 at 80:10 , chapter title Number Theory ( index 3)
#  video_shift index 28 at 80:24 , chapter title Number Theory ( index 3)
# By the majority vote, the dominent chapter choosed is Number Theory
# 3
#  video_shift index 0 at 02:43 , chapter title 4.1 Divisibility ( index 0)
#  video_shift index 1 at 04:04 , chapter title 4.1 Divisibility ( index 0)
#  video_shift index 2 at 05:48 , chapter title 4.1 Divisibility ( index 0)
#  video_shift index 3 at 07:59 , chapter title 4.1 Divisibility ( index 0)
#  video_shift index 4 at 10:24 , chapter title 4.1 Divisibility ( index 0)
#  video_shift index 5 at 13:11 , chapter title 4.8 The RSA Algorithm ( index 7)
#  video_shift index 6 at 16:27 , chapter title 4.1 Divisibility ( index 0)
#  video_shift index 7 at 19:38 , chapter title 4.1 Divisibility ( index 0)
#  video_shift index 8 at 21:51 , chapter title 4.1 Divisibility ( index 0)
#  video_shift index 9 at 25:10 , chapter title 4.2 The Greatest Common Divisor ( index 1)
#  video_shift index 10 at 28:36 , chapter title 4.1 Divisibility ( index 0)
#  video_shift index 11 at 30:43 , chapter title 4.1 Divisibility ( index 0)
#  video_shift index 12 at 33:14 , chapter title 4.1 Divisibility ( index 0)
#  video_shift index 13 at 35:57 , chapter title 4.6 Arithmetic with a Prime Modulus ( index 5)
#  video_shift index 14 at 37:33 , chapter title 4.2 The Greatest Common Divisor ( index 1)
#  video_shift index 15 at 40:22 , chapter title 4.2 The Greatest Common Divisor ( index 1)
#  video_shift index 16 at 42:37 , chapter title 4.4 The man pictured in Figure  ( index 3)
#  video_shift index 17 at 45:10 , chapter title 4.8 The RSA Algorithm ( index 7)
#  video_shift index 18 at 48:56 , chapter title 4.8 The RSA Algorithm ( index 7)
#  video_shift index 19 at 51:33 , chapter title 4.1 Divisibility ( index 0)
#  video_shift index 20 at 55:01 , chapter title 4.6 Arithmetic with a Prime Modulus ( index 5)
#  video_shift index 21 at 58:27 , chapter title 4.2 The Greatest Common Divisor ( index 1)
#  video_shift index 22 at 60:55 , chapter title 4.2 The Greatest Common Divisor ( index 1)
#  video_shift index 23 at 66:19 , chapter title 4.2 The Greatest Common Divisor ( index 1)
#  video_shift index 24 at 69:24 , chapter title 4.2 The Greatest Common Divisor ( index 1)
#  video_shift index 25 at 72:28 , chapter title 4.1 Divisibility ( index 0)
#  video_shift index 26 at 76:11 , chapter title 4.2 The Greatest Common Divisor ( index 1)
#  video_shift index 27 at 80:10 , chapter title 4.2 The Greatest Common Divisor ( index 1)
#  video_shift index 28 at 80:24 , chapter title 4.2 The Greatest Common Divisor ( index 1)
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Video Shift</th>
#       <th>Founded Title</th>
#       <th>Chapter Section</th>
#       <th>Prelabeled Title</th>
#       <th>Nearest Groundbase</th>
#       <th>Labeling Confidence</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>02:43</td>
#       <td>4.1.2 When Divisibility Goes Bad</td>
#       <td>4</td>
#       <td>Number Theory</td>
#       <td>08:40</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>04:04</td>
#       <td>4.1.3 Die Hard</td>
#       <td>4</td>
#       <td>Number Theory</td>
#       <td>08:40</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>05:48</td>
#       <td>4.1.3 Die Hard</td>
#       <td>4</td>
#       <td>Number Theory</td>
#       <td>08:40</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>07:59</td>
#       <td>4.1.3 Die Hard</td>
#       <td>4</td>
#       <td>Number Theory</td>
#       <td>08:40</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>10:24</td>
#       <td>4.1.2 When Divisibility Goes Bad</td>
#       <td>4.1</td>
#       <td>Divisibility</td>
#       <td>09:50</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>13:11</td>
#       <td>4.8 The RSA Algorithm</td>
#       <td>4.1</td>
#       <td>Divisibility</td>
#       <td>09:50</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>16:27</td>
#       <td>4.1.3 Die Hard</td>
#       <td>4.1</td>
#       <td>Divisibility</td>
#       <td>09:50</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>19:38</td>
#       <td>4.1.3 Die Hard</td>
#       <td>4.1</td>
#       <td>Divisibility</td>
#       <td>09:50</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>21:51</td>
#       <td>4.1.3 Die Hard</td>
#       <td>4.1.3</td>
#       <td>Die Hard</td>
#       <td>30:35</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>25:10</td>
#       <td>4.2 The Greatest Common Divisor</td>
#       <td>4.1.3</td>
#       <td>Die Hard</td>
#       <td>30:35</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>28:36</td>
#       <td>4.1 Divisibility</td>
#       <td>4.1.3</td>
#       <td>Die Hard</td>
#       <td>30:35</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>30:43</td>
#       <td>4.1.3 Die Hard</td>
#       <td>4.1.3</td>
#       <td>Die Hard</td>
#       <td>30:35</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>33:14</td>
#       <td>4.1.3 Die Hard</td>
#       <td>4.2</td>
#       <td>The Greatest Common Divisor</td>
#       <td>33:48</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>35:57</td>
#       <td>4.6 Arithmetic with a Prime Modulus</td>
#       <td>4.7.1</td>
#       <td>Relative Primality</td>
#       <td>34:50</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>37:33</td>
#       <td>4.2.1 Linear Combinations and the GCD</td>
#       <td>4.7.1</td>
#       <td>Relative Primality</td>
#       <td>34:50</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>40:22</td>
#       <td>4.2.1 Linear Combinations and the GCD</td>
#       <td>4.2.1</td>
#       <td>Linear Combinations and the GCD</td>
#       <td>42:50</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>42:37</td>
#       <td>4.4 The man pictured in Figure</td>
#       <td>4.2.1</td>
#       <td>Linear Combinations and the GCD</td>
#       <td>42:50</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>45:10</td>
#       <td>4.8 The RSA Algorithm</td>
#       <td>4.2.1</td>
#       <td>Linear Combinations and the GCD</td>
#       <td>42:50</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>48:56</td>
#       <td>4.8 The RSA Algorithm</td>
#       <td>4.2.1</td>
#       <td>Linear Combinations and the GCD</td>
#       <td>42:50</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>51:33</td>
#       <td>4.1.3 Die Hard</td>
#       <td>4.2.4</td>
#       <td>None</td>
#       <td>57:50</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>55:01</td>
#       <td>4.6.2 Cancellation</td>
#       <td>4.2.4</td>
#       <td>None</td>
#       <td>57:50</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>58:27</td>
#       <td>4.2.1 Linear Combinations and the GCD</td>
#       <td>4.2.4</td>
#       <td>None</td>
#       <td>57:50</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>60:55</td>
#       <td>4.2.3 Euclid’s Algorithm</td>
#       <td>4.2.4</td>
#       <td>None</td>
#       <td>57:50</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>66:19</td>
#       <td>4.2.5 The Pulverizer</td>
#       <td>4.2.5</td>
#       <td>The Pulverizer</td>
#       <td>72:00</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>69:24</td>
#       <td>4.2.3 Euclid’s Algorithm</td>
#       <td>4.2.5</td>
#       <td>The Pulverizer</td>
#       <td>72:00</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>72:28</td>
#       <td>4.1.1 Facts about Divisibility</td>
#       <td>4.2.5</td>
#       <td>The Pulverizer</td>
#       <td>72:00</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>76:11</td>
#       <td>4.2.3 Euclid’s Algorithm</td>
#       <td>4.2.5</td>
#       <td>The Pulverizer</td>
#       <td>72:00</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>80:10</td>
#       <td>4.2.1 Linear Combinations and the GCD</td>
#       <td>4.2.1</td>
#       <td>Linear Combinations and the GCD</td>
#       <td>80:24</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td>80:24</td>
#       <td>4.2.1 Linear Combinations and the GCD</td>
#       <td>4.2.1</td>
#       <td>Linear Combinations and the GCD</td>
#       <td>80:24</td>
#       <td>None</td>
#     </tr>
#   </tbody>
# </table>
#     shift index topic shifts(ends)             label video     video id  \
# 54            0           00:08:40      introduction  None  NuY7szYSXSw
# 55            1           00:09:50  basic definition  None  NuY7szYSXSw
# 56            2           00:30:35              None  None  NuY7szYSXSw
# 57            3           00:33:48              None  None  NuY7szYSXSw
# 58            4           00:34:50              None  None  NuY7szYSXSw
# 59            5           00:42:50              None  None  NuY7szYSXSw
# 60            6           00:57:50              None  None  NuY7szYSXSw
# 61            7           01:12:00              None  None  NuY7szYSXSw
# 62            8           01:20:24              None  None  NuY7szYSXSw
#
#    chapter section                    chapter title chapter confidence notes
# 54               4                    Number Theory               None  None
# 55             4.1                     Divisibility               None  None
# 56           4.1.3                         Die Hard               None  None
# 57             4.2      The Greatest Common Divisor               None  None
# 58           4.7.1               Relative Primality               None  None
# 59           4.2.1  Linear Combinations and the GCD               None  None
# 60           4.2.4                             None               None  None
# 61           4.2.5                   The Pulverizer               None  None
# 62           4.2.1  Linear Combinations and the GCD               None  None
# ################ XX7ePR21Ook ################
#  video_shift index 0 at 02:04 , chapter title Number Theory ( index 3)
#  video_shift index 1 at 04:19 , chapter title Number Theory ( index 3)
#  video_shift index 2 at 06:28 , chapter title Number Theory ( index 3)
#  video_shift index 3 at 08:40 , chapter title Number Theory ( index 3)
#  video_shift index 4 at 11:42 , chapter title Number Theory ( index 3)
#  video_shift index 5 at 13:24 , chapter title Number Theory ( index 3)
#  video_shift index 6 at 15:17 , chapter title Number Theory ( index 3)
#  video_shift index 7 at 18:06 , chapter title Number Theory ( index 3)
#  video_shift index 8 at 22:20 , chapter title Number Theory ( index 3)
#  video_shift index 9 at 24:40 , chapter title Number Theory ( index 3)
#  video_shift index 10 at 27:15 , chapter title Number Theory ( index 3)
#  video_shift index 11 at 30:05 , chapter title Number Theory ( index 3)
#  video_shift index 12 at 32:40 , chapter title Number Theory ( index 3)
#  video_shift index 13 at 34:52 , chapter title Number Theory ( index 3)
#  video_shift index 14 at 37:27 , chapter title Number Theory ( index 3)
#  video_shift index 15 at 39:54 , chapter title Number Theory ( index 3)
#  video_shift index 16 at 43:48 , chapter title Number Theory ( index 3)
#  video_shift index 17 at 47:02 , chapter title Number Theory ( index 3)
#  video_shift index 18 at 51:14 , chapter title Patterns of Proof ( index 1)
#  video_shift index 19 at 56:26 , chapter title Number Theory ( index 3)
#  video_shift index 20 at 60:13 , chapter title Number Theory ( index 3)
#  video_shift index 21 at 61:58 , chapter title Number Theory ( index 3)
#  video_shift index 22 at 64:21 , chapter title Number Theory ( index 3)
#  video_shift index 23 at 67:13 , chapter title Number Theory ( index 3)
#  video_shift index 24 at 68:51 , chapter title Number Theory ( index 3)
#  video_shift index 25 at 72:39 , chapter title Number Theory ( index 3)
#  video_shift index 26 at 75:47 , chapter title Number Theory ( index 3)
#  video_shift index 27 at 78:34 , chapter title Number Theory ( index 3)
#  video_shift index 28 at 78:44 , chapter title Expectation ( index 17)
# By the majority vote, the dominent chapter choosed is Number Theory
# 3
#  video_shift index 0 at 02:04 , chapter title 4.2 The Greatest Common Divisor ( index 1)
#  video_shift index 1 at 04:19 , chapter title 4.8 The RSA Algorithm ( index 7)
#  video_shift index 2 at 06:28 , chapter title 4.4 The man pictured in Figure  ( index 3)
#  video_shift index 3 at 08:40 , chapter title 4.8 The RSA Algorithm ( index 7)
#  video_shift index 4 at 11:42 , chapter title 4.5 Modular Arithmetic ( index 4)
#  video_shift index 5 at 13:24 , chapter title 4.5 Modular Arithmetic ( index 4)
#  video_shift index 6 at 15:17 , chapter title 4.2 The Greatest Common Divisor ( index 1)
#  video_shift index 7 at 18:06 , chapter title 4.7 Arithmetic with an Arbitrary Modulus ( index 6)
#  video_shift index 8 at 22:20 , chapter title 4.7 Arithmetic with an Arbitrary Modulus ( index 6)
#  video_shift index 9 at 24:40 , chapter title 4.8 The RSA Algorithm ( index 7)
#  video_shift index 10 at 27:15 , chapter title 4.2 The Greatest Common Divisor ( index 1)
#  video_shift index 11 at 30:05 , chapter title 4.7 Arithmetic with an Arbitrary Modulus ( index 6)
#  video_shift index 12 at 32:40 , chapter title 4.3 The Fundamental Theorem of Arithmetic ( index 2)
#  video_shift index 13 at 34:52 , chapter title 4.3 The Fundamental Theorem of Arithmetic ( index 2)
#  video_shift index 14 at 37:27 , chapter title 4.7 Arithmetic with an Arbitrary Modulus ( index 6)
#  video_shift index 15 at 39:54 , chapter title 4.8 The RSA Algorithm ( index 7)
#  video_shift index 16 at 43:48 , chapter title 4.2 The Greatest Common Divisor ( index 1)
#  video_shift index 17 at 47:02 , chapter title 4.7 Arithmetic with an Arbitrary Modulus ( index 6)
#  video_shift index 18 at 51:14 , chapter title 4.6 Arithmetic with a Prime Modulus ( index 5)
#  video_shift index 19 at 56:26 , chapter title 4.2 The Greatest Common Divisor ( index 1)
#  video_shift index 20 at 60:13 , chapter title 4.8 The RSA Algorithm ( index 7)
#  video_shift index 21 at 61:58 , chapter title 4.7 Arithmetic with an Arbitrary Modulus ( index 6)
#  video_shift index 22 at 64:21 , chapter title 4.8 The RSA Algorithm ( index 7)
#  video_shift index 23 at 67:13 , chapter title 4.8 The RSA Algorithm ( index 7)
#  video_shift index 24 at 68:51 , chapter title 4.8 The RSA Algorithm ( index 7)
#  video_shift index 25 at 72:39 , chapter title 4.3 The Fundamental Theorem of Arithmetic ( index 2)
#  video_shift index 26 at 75:47 , chapter title 4.6 Arithmetic with a Prime Modulus ( index 5)
#  video_shift index 27 at 78:34 , chapter title 4.3 The Fundamental Theorem of Arithmetic ( index 2)
#  video_shift index 28 at 78:44 , chapter title 4.4 The man pictured in Figure  ( index 3)
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Video Shift</th>
#       <th>Founded Title</th>
#       <th>Chapter Section</th>
#       <th>Prelabeled Title</th>
#       <th>Nearest Groundbase</th>
#       <th>Labeling Confidence</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>02:04</td>
#       <td>4.2 The Greatest Common Divisor</td>
#       <td>4.4</td>
#       <td>Alan Turing</td>
#       <td>05:00</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>04:19</td>
#       <td>4.8 The RSA Algorithm</td>
#       <td>4.4</td>
#       <td>Alan Turing</td>
#       <td>05:00</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>06:28</td>
#       <td>4.4.1 Turing</td>
#       <td>4.4</td>
#       <td>Alan Turing</td>
#       <td>05:00</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>08:40</td>
#       <td>4.8 The RSA Algorithm</td>
#       <td>4.4.1</td>
#       <td>Turing’s Code (Version 1.0)</td>
#       <td>09:12</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>11:42</td>
#       <td>4.5 Modular Arithmetic</td>
#       <td>4.4.2</td>
#       <td>Breaking Turing’s Code</td>
#       <td>11:05</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>13:24</td>
#       <td>4.5 Modular Arithmetic</td>
#       <td>4.5.1</td>
#       <td>Turing’s Code (Version 2.0)</td>
#       <td>13:45</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>15:17</td>
#       <td>4.2.2 Properties of the Greatest Common Divisor</td>
#       <td>4.7.1</td>
#       <td>Relative Primality</td>
#       <td>15:45</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>18:06</td>
#       <td>4.7.1 Relative Primality</td>
#       <td>4.5</td>
#       <td>Modular Arithmetic</td>
#       <td>17:52</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>22:20</td>
#       <td>4.7.1 Relative Primality</td>
#       <td>4.6.1</td>
#       <td>Multiplicative Invers</td>
#       <td>25:35</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>24:40</td>
#       <td>4.8 The RSA Algorithm</td>
#       <td>4.6.1</td>
#       <td>Multiplicative Invers</td>
#       <td>25:35</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>27:15</td>
#       <td>4.2.4 One Solution for All Water Jug Problems</td>
#       <td>4.6.1</td>
#       <td>Multiplicative Invers</td>
#       <td>25:35</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>30:05</td>
#       <td>4.7 Arithmetic with an Arbitrary Modulus</td>
#       <td>4.6.4</td>
#       <td>Breaking Turing’s Code—Again</td>
#       <td>32:00</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>32:40</td>
#       <td>4.3 The Fundamental Theorem of Arithmetic</td>
#       <td>4.6.4</td>
#       <td>Breaking Turing’s Code—Again</td>
#       <td>32:00</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>34:52</td>
#       <td>4.3 The Fundamental Theorem of Arithmetic</td>
#       <td>4.6.4</td>
#       <td>Breaking Turing’s Code—Again</td>
#       <td>32:00</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>37:27</td>
#       <td>4.7.1 Relative Primality</td>
#       <td>4.6.4</td>
#       <td>Breaking Turing’s Code—Again</td>
#       <td>32:00</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>39:54</td>
#       <td>4.8 The RSA Algorithm</td>
#       <td>4.6.4</td>
#       <td>Breaking Turing’s Code—Again</td>
#       <td>32:00</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>43:48</td>
#       <td>4.2.4 One Solution for All Water Jug Problems</td>
#       <td>4.6.4</td>
#       <td>Breaking Turing’s Code—Again</td>
#       <td>32:00</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>47:02</td>
#       <td>4.7.1 Relative Primality</td>
#       <td>4.7.2</td>
#       <td>Euler’s Theorm</td>
#       <td>59:30</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>51:14</td>
#       <td>4.6.2 Cancellation</td>
#       <td>4.7.2</td>
#       <td>Euler’s Theorm</td>
#       <td>59:30</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>56:26</td>
#       <td>4.2.3 Euclid’s Algorithm</td>
#       <td>4.7.2</td>
#       <td>Euler’s Theorm</td>
#       <td>59:30</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>60:13</td>
#       <td>4.8 The RSA Algorithm</td>
#       <td>4.7.2</td>
#       <td>Euler’s Theorm</td>
#       <td>59:30</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>61:58</td>
#       <td>4.7.2 Euler’s Theorem</td>
#       <td>4.6.3</td>
#       <td>Fermat’s Little Theorem</td>
#       <td>63:30</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>64:21</td>
#       <td>4.8 The RSA Algorithm</td>
#       <td>4.6.3</td>
#       <td>Fermat’s Little Theorem</td>
#       <td>63:30</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>67:13</td>
#       <td>4.8 The RSA Algorithm</td>
#       <td>4.6.3</td>
#       <td>Fermat’s Little Theorem</td>
#       <td>63:30</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>68:51</td>
#       <td>4.8 The RSA Algorithm</td>
#       <td>4.6.3</td>
#       <td>Fermat’s Little Theorem</td>
#       <td>63:30</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>72:39</td>
#       <td>4.3 The Fundamental Theorem of Arithmetic</td>
#       <td>4.8</td>
#       <td>The RSA Algorith</td>
#       <td>78:44</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>75:47</td>
#       <td>4.6.3 Fermat’s Little Theorem</td>
#       <td>4.8</td>
#       <td>The RSA Algorith</td>
#       <td>78:44</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>78:34</td>
#       <td>4.3 The Fundamental Theorem of Arithmetic</td>
#       <td>4.8</td>
#       <td>The RSA Algorith</td>
#       <td>78:44</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td>78:44</td>
#       <td>4.4 The man pictured in Figure</td>
#       <td>4.8</td>
#       <td>The RSA Algorith</td>
#       <td>78:44</td>
#       <td>None</td>
#     </tr>
#   </tbody>
# </table>
#     shift index topic shifts(ends) label video     video id chapter section  \
# 63            0           00:05:00  None  None  XX7ePR21Ook             4.4
# 64            1           00:09:12  None  None  XX7ePR21Ook           4.4.1
# 65            2           00:11:05  None  None  XX7ePR21Ook           4.4.2
# 66            3           00:13:45  None  None  XX7ePR21Ook           4.5.1
# 67            4           00:15:45  None  None  XX7ePR21Ook           4.7.1
# 68            5           00:17:52  None  None  XX7ePR21Ook             4.5
# 69            6           00:25:35  None  None  XX7ePR21Ook           4.6.1
# 70            7           00:32:00  None  None  XX7ePR21Ook           4.6.4
# 71            8           00:59:30  None  None  XX7ePR21Ook           4.7.2
# 72            9           01:03:30  None  None  XX7ePR21Ook           4.6.3
# 73           10           01:18:44  None  None  XX7ePR21Ook             4.8
#
#                    chapter title chapter confidence notes
# 63                   Alan Turing               None  None
# 64   Turing’s Code (Version 1.0)               None  None
# 65        Breaking Turing’s Code               None  None
# 66   Turing’s Code (Version 2.0)               None  None
# 67            Relative Primality               None  None
# 68            Modular Arithmetic               None  None
# 69         Multiplicative Invers               None  None
# 70  Breaking Turing’s Code—Again               None  None
# 71                Euler’s Theorm               None  None
# 72       Fermat’s Little Theorem               None  None
# 73              The RSA Algorith               None  None
