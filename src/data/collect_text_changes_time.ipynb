# %%
import cv2
import os
import glob
from pytube import YouTube
#pip install fuzzywuzzy
from fuzzywuzzy import fuzz
import pytesseract

curr_url = "https://www.youtube.com/watch?v=VO5vKowfMOQ&t=7s"

# %%
def extract_images_from_video(video, target_path, frequency=15, name="file", max_images=20, silent=False):  
    vidcap = cv2.VideoCapture(video)
    frame_count = 0
    time_sec = 0
    num_images = 0
    folder = target_path
    label = 0
    success = True
    fps = int(vidcap.get(cv2.CAP_PROP_FPS))

    list = []
    success, image = vidcap.read()
    while success and num_images < max_images:
        num_images += 1
        label += 1
        file_name = name + "_" + str(num_images) + ".jpg"
        list.append((file_name,time_sec))
        path = os.path.join(folder, file_name)
        print(path)
        cv2.imwrite(path, image)
        if cv2.imread(path) is None:
            os.remove(path)
        else:
            if not silent:
                print(f'Image successfully written at {path}')
        frame_count += frequency * fps #skips secends
        time_sec += frequency
        vidcap.set(1, frame_count)
        success, image = vidcap.read()
    return (list);

# %%
import pytesseract
# download from here https://github.com/UB-Mannheim/tesseract/wiki
pytesseract.pytesseract.tesseract_cmd = r"C:\Program Files\Tesseract-OCR\tesseract.exe"

# %%
def extract_time_titles_changed(listi):
    wantedTimes=[]
    index = 0
    (file_name,time) = listi[index]
    img = cv2.imread(file_name)
    last_text = pytesseract.image_to_string(img)
    index += 1
    while index < len(listi):
        (file_name,time) = listi[index]
        img = cv2.imread(file_name)
        text = pytesseract.image_to_string(img)
        if text:
            # compare similarity between the last text and the new one
            if fuzz.ratio(text.lower(),last_text.lower()) > 75:
                wantedTimes.append(time)
            
        index+=1
        last_text = text
    return wantedTimes

# %%
def get_time_titles_changed_with_downlode(video_url, target_path, wanted_frequency, fileName ):
    print(video_url)
    youtube = YouTube(video_url)
    # download youtube video
    
    youtube.streams.first().download(target_path,filename=fileName)
    arr = []
    #videoPath = "C:/Users/Sarit/Desktop/final_proj/The Apriori algorithm.mp4"
    wanted_file_path=target_path+'/'+fileName+'.mp4'
    print(wanted_file_path)
    arr = extract_images_from_video(wanted_file_path,target_path, frequency=wanted_frequency, name="The Apriori algorithm.mp4", max_images=1500, silent=False)
    print(extract_time_titles_changed(arr))

# %%
def get_time_titles_changed(video_path, target_path, wanted_frequency, video_name):
    images = extract_images_from_video(video_path, target_path, frequency = wanted_frequency, name=video_name, max_images=1500, silent=False)
    return extract_time_titles_changed(images)

# %%
get_time_titles_changed_with_downlode('https://www.youtube.com/watch?v=2mC1uqwEmWQ','C:/Users/sarit/Desktop/final_proj',30,'The Apriori algorithm')
# Out:
# https://www.youtube.com/watch?v=2mC1uqwEmWQ
# C:/Users/sarit/Desktop/final_proj/The Apriori algorithm.mp4
# C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_1.jpg
# Image successfully written at C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_1.jpg
# C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_2.jpg
# Image successfully written at C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_2.jpg
# C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_3.jpg
# Image successfully written at C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_3.jpg
# C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_4.jpg
# Image successfully written at C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_4.jpg
# C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_5.jpg
# Image successfully written at C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_5.jpg
# C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_6.jpg
# Image successfully written at C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_6.jpg
# C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_7.jpg
# Image successfully written at C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_7.jpg
# C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_8.jpg
# Image successfully written at C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_8.jpg
# C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_9.jpg
# Image successfully written at C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_9.jpg
# C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_10.jpg
# Image successfully written at C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_10.jpg
# C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_11.jpg
# Image successfully written at C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_11.jpg
# C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_12.jpg
# Image successfully written at C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_12.jpg
# C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_13.jpg
# Image successfully written at C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_13.jpg
# C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_14.jpg
# Image successfully written at C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_14.jpg
# C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_15.jpg
# Image successfully written at C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_15.jpg
# C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_16.jpg
# Image successfully written at C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_16.jpg
# C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_17.jpg
# Image successfully written at C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_17.jpg
# C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_18.jpg
# Image successfully written at C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_18.jpg
# C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_19.jpg
# Image successfully written at C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_19.jpg
# C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_20.jpg
# Image successfully written at C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_20.jpg
# C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_21.jpg
# Image successfully written at C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_21.jpg
# C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_22.jpg
# Image successfully written at C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_22.jpg
# C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_23.jpg
# Image successfully written at C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_23.jpg
# C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_24.jpg
# Image successfully written at C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_24.jpg
# C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_25.jpg
# Image successfully written at C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_25.jpg
# C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_26.jpg
# Image successfully written at C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_26.jpg
# C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_27.jpg
# Image successfully written at C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_27.jpg
# C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_28.jpg
# Image successfully written at C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_28.jpg
# C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_29.jpg
# Image successfully written at C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_29.jpg
# C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_30.jpg
# Image successfully written at C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_30.jpg
# C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_31.jpg
# Image successfully written at C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_31.jpg
# C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_32.jpg
# Image successfully written at C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_32.jpg
# C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_33.jpg
# Image successfully written at C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_33.jpg
# C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_34.jpg
# Image successfully written at C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_34.jpg
# C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_35.jpg
# Image successfully written at C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_35.jpg
# C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_36.jpg
# Image successfully written at C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_36.jpg
# C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_37.jpg
# Image successfully written at C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_37.jpg
# C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_38.jpg
# Image successfully written at C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_38.jpg
# C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_39.jpg
# Image successfully written at C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_39.jpg
# C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_40.jpg
# Image successfully written at C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_40.jpg
# C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_41.jpg
# Image successfully written at C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_41.jpg
# C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_42.jpg
# Image successfully written at C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_42.jpg
# C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_43.jpg
# Image successfully written at C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_43.jpg
# C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_44.jpg
# Image successfully written at C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_44.jpg
# C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_45.jpg
# Image successfully written at C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_45.jpg
# C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_46.jpg
# Image successfully written at C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_46.jpg
# C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_47.jpg
# Image successfully written at C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_47.jpg
# C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_48.jpg
# Image successfully written at C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_48.jpg
# C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_49.jpg
# Image successfully written at C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_49.jpg
# C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_50.jpg
# Image successfully written at C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_50.jpg
# C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_51.jpg
# Image successfully written at C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_51.jpg
# C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_52.jpg
# Image successfully written at C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_52.jpg
# C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_53.jpg
# Image successfully written at C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_53.jpg
# C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_54.jpg
# Image successfully written at C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_54.jpg
# C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_55.jpg
# Image successfully written at C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_55.jpg
# C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_56.jpg
# Image successfully written at C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_56.jpg
# [60, 120, 150, 240, 270, 330, 450, 540, 570, 630, 660, 750, 810, 840, 900, 930, 960, 990, 1050, 1080, 1140, 1170, 1230, 1290, 1350, 1380, 1410, 1440, 1560, 1590]

# %%
get_time_titles_changed('C:/Users/sarit/Desktop/final_proj/The Apriori algorithm.mp4', 'C:/Users/sarit/Desktop/final_proj', 30, 'The Apriori algorithm')
# Out:
# C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_1.jpg
# Image successfully written at C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_1.jpg
# C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_2.jpg
# Image successfully written at C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_2.jpg
# C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_3.jpg
# Image successfully written at C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_3.jpg
# C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_4.jpg
# Image successfully written at C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_4.jpg
# C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_5.jpg
# Image successfully written at C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_5.jpg
# C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_6.jpg
# Image successfully written at C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_6.jpg
# C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_7.jpg
# Image successfully written at C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_7.jpg
# C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_8.jpg
# Image successfully written at C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_8.jpg
# C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_9.jpg
# Image successfully written at C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_9.jpg
# C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_10.jpg
# Image successfully written at C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_10.jpg
# C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_11.jpg
# Image successfully written at C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_11.jpg
# C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_12.jpg
# Image successfully written at C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_12.jpg
# C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_13.jpg
# Image successfully written at C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_13.jpg
# C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_14.jpg
# Image successfully written at C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_14.jpg
# C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_15.jpg
# Image successfully written at C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_15.jpg
# C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_16.jpg
# Image successfully written at C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_16.jpg
# C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_17.jpg
# Image successfully written at C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_17.jpg
# C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_18.jpg
# Image successfully written at C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_18.jpg
# C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_19.jpg
# Image successfully written at C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_19.jpg
# C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_20.jpg
# Image successfully written at C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_20.jpg
# C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_21.jpg
# Image successfully written at C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_21.jpg
# C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_22.jpg
# Image successfully written at C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_22.jpg
# C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_23.jpg
# Image successfully written at C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_23.jpg
# C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_24.jpg
# Image successfully written at C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_24.jpg
# C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_25.jpg
# Image successfully written at C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_25.jpg
# C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_26.jpg
# Image successfully written at C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_26.jpg
# C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_27.jpg
# Image successfully written at C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_27.jpg
# C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_28.jpg
# Image successfully written at C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_28.jpg
# C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_29.jpg
# Image successfully written at C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_29.jpg
# C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_30.jpg
# Image successfully written at C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_30.jpg
# C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_31.jpg
# Image successfully written at C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_31.jpg
# C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_32.jpg
# Image successfully written at C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_32.jpg
# C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_33.jpg
# Image successfully written at C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_33.jpg
# C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_34.jpg
# Image successfully written at C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_34.jpg
# C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_35.jpg
# Image successfully written at C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_35.jpg
# C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_36.jpg
# Image successfully written at C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_36.jpg
# C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_37.jpg
# Image successfully written at C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_37.jpg
# C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_38.jpg
# Image successfully written at C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_38.jpg
# C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_39.jpg
# Image successfully written at C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_39.jpg
# C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_40.jpg
# Image successfully written at C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_40.jpg
# C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_41.jpg
# Image successfully written at C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_41.jpg
# C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_42.jpg
# Image successfully written at C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_42.jpg
# C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_43.jpg
# Image successfully written at C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_43.jpg
# C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_44.jpg
# Image successfully written at C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_44.jpg
# C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_45.jpg
# Image successfully written at C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_45.jpg
# C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_46.jpg
# Image successfully written at C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_46.jpg
# C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_47.jpg
# Image successfully written at C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_47.jpg
# C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_48.jpg
# Image successfully written at C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_48.jpg
# C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_49.jpg
# Image successfully written at C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_49.jpg
# C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_50.jpg
# Image successfully written at C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_50.jpg
# C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_51.jpg
# Image successfully written at C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_51.jpg
# C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_52.jpg
# Image successfully written at C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_52.jpg
# C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_53.jpg
# Image successfully written at C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_53.jpg
# C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_54.jpg
# Image successfully written at C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_54.jpg
# C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_55.jpg
# Image successfully written at C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_55.jpg
# C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_56.jpg
# Image successfully written at C:/Users/sarit/Desktop/final_proj\The Apriori algorithm.mp4_56.jpg
# [60,
#  120,
#  150,
#  240,
#  270,
#  330,
#  450,
#  540,
#  570,
#  630,
#  660,
#  750,
#  810,
#  840,
#  900,
#  930,
#  960,
#  990,
#  1050,
#  1080,
#  1140,
#  1170,
#  1230,
#  1290,
#  1350,
#  1380,
#  1410,
#  1440,
#  1560,
#  1590]
